# %%
#Imports
import pybedtools as pybed
import pandas as pd
import csv
import numpy as np
import glob
import math

# %%
####
#Function for calling promoters
####

#awk '{print $0}' /index/hg19/Homo_sapiens.GRCh37.87.chr.gtf | grep "protein_coding" | awk '{if ($3 == "gene") print "chr"$1"\t"$4"\t"$5"\t"$7"\t"$14 }' > /home/darragh/Annotation_reg_elements/hg19_protein_coding_minimal.gtf

#awk '{print $0}' /index/hg19/Homo_sapiens.GRCh37.87.chr.gtf | awk '{if ($3 == "gene") print "chr"$1"\t"$4"\t"$5"\t"$7"\t"$14 }' > /home/darragh/Annotation_reg_elements/hg19_minimal.gtf

gtf = "/home/darragh/Annotation_reg_elements/hg19_minimal.gtf"

def Identify_coding_promoters(gtf):
    """Creating a TSS box region for each promoter"""
    hg19_gtf = pd.read_table(gtf)
    hg19_gtf.columns = ["seqname","start","end","strand", "gene"]
    seqnames_we_like = ["chr1","chr2","chr3","chr4","chr5","chr6","chr7","chr8","chr9","chr10","chr11","chr12","chr13","chr14","chr15","chr16","chr17","chr18","chr19","chr20","chr21","chr22","chrX"]
    hg19_gtf = hg19_gtf[hg19_gtf['seqname'].isin(seqnames_we_like)]
    hg19_gtf.loc[hg19_gtf['strand'] == "+", ['start']] = hg19_gtf['start']-2500
    hg19_gtf.loc[hg19_gtf['strand'] == "+", ['end']] = hg19_gtf['start']+5000
    hg19_gtf.loc[hg19_gtf['strand'] == "-", ['start']] = hg19_gtf['end']-2500
    hg19_gtf.loc[hg19_gtf['strand'] == "-", ['end']] = hg19_gtf['start']+5000

    return(hg19_gtf)

Coding_promoter_df = Identify_coding_promoters(gtf)
Coding_promoter_df.to_csv("/home/darragh/hg19_promoters.bed", sep="\t", index=False)
Coding_promoter = pybed.BedTool.from_dataframe(Coding_promoter_df)

# %%
#Call HCC1954 reg-elements

pd.options.display.float_format = '{:,.0f}'.format

# HCC1954_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/HCC1954/HCC1954_Gateway_SuperEnhancers.bed",header=None)
# HCC1954_Super_enhancers_df = HCC1954_Super_enhancers_df.iloc[:, [0,1,2]]
# HCC1954_Super_enhancers_df.columns = ["chr", "start", "end"]
# HCC1954_Super_enhancers_df['Annotation'] = "HCC1954_super_enhancer"
# HCC1954_Super_enhancers = pybed.BedTool.from_dataframe(HCC1954_Super_enhancers_df)

ATAC_peak_HCC1954 = pd.read_table("/home/darragh/New/ATAC-seq/HCC1954/naive/HCC1954_peaks.preprocessed.bed")
ATAC_peak_HCC1954_df = ATAC_peak_HCC1954.iloc[:, [0,1,2]]
ATAC_peak_HCC1954_df.columns = ["chr", "start", "end"]
ATAC_peak_HCC1954_df['Annotation'] = "HCC1954_ATAC_peak"
ATAC_peak_HCC1954 = pybed.BedTool.from_dataframe(ATAC_peak_HCC1954_df)
ATAC_peak_HCC1954 = ATAC_peak_HCC1954.sort()

H3K27ac_peak_HCC1954 = pd.read_table("/home/darragh/New/ChIP-seq/HCC1954/H3K27ac/results/Peak/H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_HCC1954_df = H3K27ac_peak_HCC1954.iloc[:, [0,1,2]]
H3K27ac_peak_HCC1954_df.columns = ["chr", "start", "end"]
H3K27ac_peak_HCC1954_df['Annotation'] = "HCC1954_H3K27ac_peak"
H3K27ac_peak_HCC1954 = pybed.BedTool.from_dataframe(H3K27ac_peak_HCC1954_df)
H3K27ac_peak_HCC1954 = H3K27ac_peak_HCC1954.sort()

H3K27me3_peak_HCC1954 = pd.read_table("/home/darragh/New/ChIP-seq/HCC1954/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_HCC1954_df = H3K27me3_peak_HCC1954.iloc[:, [0,1,2]]
H3K27me3_peak_HCC1954_df.columns = ["chr", "start", "end"]
H3K27me3_peak_HCC1954_df['Annotation'] = "HCC1954_H3K27me3_peak"
H3K27me3_peak_HCC1954 = pybed.BedTool.from_dataframe(H3K27me3_peak_HCC1954_df)
H3K27me3_peak_HCC1954 = H3K27me3_peak_HCC1954.sort()

H3K4me3_peak_HCC1954 = pd.read_table("/home/darragh/New/ChIP-seq/HCC1954/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_HCC1954_df = H3K4me3_peak_HCC1954.iloc[:, [0,1,2]]
H3K4me3_peak_HCC1954_df.columns = ["chr", "start", "end"]
H3K4me3_peak_HCC1954_df['Annotation'] = "HCC1954_H3K4me3_peak"
H3K4me3_peak_HCC1954 = pybed.BedTool.from_dataframe(H3K4me3_peak_HCC1954_df)
H3K4me3_peak_HCC1954 = H3K4me3_peak_HCC1954.sort()

H3K4me1_peak_HCC1954 = pd.read_table("/home/darragh/New/ChIP-seq/HCC1954/H3K4me1/results/Peak/H3K4me1_peaks.preprocessed.bed")
H3K4me1_peak_HCC1954_df = H3K4me1_peak_HCC1954.iloc[:, [0,1,2]]
H3K4me1_peak_HCC1954_df.columns = ["chr", "start", "end"]
H3K4me1_peak_HCC1954_df['Annotation'] = "HCC1954_H3K4me1_peak"
H3K4me1_peak_HCC1954 = pybed.BedTool.from_dataframe(H3K4me1_peak_HCC1954_df)
H3K4me1_peak_HCC1954 = H3K4me1_peak_HCC1954.sort()

###########################################

# #Active-enhancers
# Distal_ATAC_HMEC = ATAC_peak_HMEC.subtract(Coding_promoter, A=True)
# Distal_H3K27ac_HMEC = H3K27ac_peak_HMEC.subtract(Coding_promoter, A=True)
# HMEC_active_enhancer = Distal_H3K27ac_HMEC.intersect(Distal_ATAC_HMEC, wa=True, wb=True, f=0.1, r=True)
# HMEC_active_enhancer_df = pd.read_table(HMEC_active_enhancer.fn,header=None)
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.drop(HMEC_active_enhancer_df.columns[[3, 7]],axis = 1)
# HMEC_active_enhancer_df_1 = HMEC_active_enhancer_df.iloc[:,0:3]
# HMEC_active_enhancer_df_1.columns = ["chr", "start", "end"]
# HMEC_active_enhancer_df_1["id"] = range(1, 1 + len(HMEC_active_enhancer_df_1))
# HMEC_active_enhancer_df_1["id"] = "AE_" + HMEC_active_enhancer_df_1["id"].astype(str)
# HMEC_active_enhancer_df_2 = HMEC_active_enhancer_df.iloc[:,3:]
# HMEC_active_enhancer_df_2.columns = ["chr", "start", "end"]
# HMEC_active_enhancer_df_2["id"] = range(1, 1 + len(HMEC_active_enhancer_df_2))
# HMEC_active_enhancer_df_2["id"] = "AE_" + HMEC_active_enhancer_df_2["id"].astype(str)
# HMEC_active_enhancer_df = pd.concat([HMEC_active_enhancer_df_1,HMEC_active_enhancer_df_2])
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.sort_values(by='id')
# HMEC_active_enhancer = pybed.BedTool.from_dataframe(HMEC_active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# HMEC_active_enhancer = HMEC_active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# HMEC_active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# HMEC_active_enhancer_df.columns = ["chr", "name", "start", "end"]
# HMEC_active_enhancer_df = HMEC_active_enhancer_df[["chr", "start", "end"]]
# HMEC_active_enhancer_df["annotation"] = "HMEC_active_enhancer"
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.drop_duplicates()

# Distal_ATAC_HCC1954 = ATAC_peak_HCC1954.subtract(Coding_promoter, A=True)
# Distal_H3K27ac_HCC1954 = H3K27ac_peak_HCC1954.subtract(Coding_promoter, A=True)
# HCC1954_active_enhancer = Distal_H3K27ac_HCC1954.intersect(Distal_ATAC_HCC1954, wb=True, f=0.1, r=True)
# HCC1954_active_enhancer = HCC1954_active_enhancer.subtract(H3K27me3_peak_HCC1954, A=True)
# HCC1954_active_enhancer_df = pd.read_table(HCC1954_active_enhancer.fn,header=None)
# HCC1954_active_enhancer_df = HCC1954_active_enhancer_df.iloc[:, [4,5,6,7]]
# HCC1954_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
# HCC1954_active_enhancer_df["annotation"] = "HCC1954_active_enhancer"
# HCC1954_active_enhancer_df = HCC1954_active_enhancer_df.drop_duplicates()


# #####################################

# #H3K27me3 silencers
# Distal_ATAC_HCC1954 = ATAC_peak_HCC1954.subtract(Coding_promoter, A=True)
# Distal_H3K27me3_HCC1954 = H3K27me3_peak_HCC1954.subtract(Coding_promoter, A=True)
# HCC1954_H3K27me3_silencer = Distal_H3K27me3_HCC1954.intersect(Distal_ATAC_HCC1954, wb=True, f=0.1, r=True)
# HCC1954_H3K27me3_silencer = HCC1954_H3K27me3_silencer.subtract(Distal_H3K27ac_HCC1954, A=True)
# HCC1954_H3K27me3_silencer_df = pd.read_table(HCC1954_H3K27me3_silencer.fn,header=None)
# HCC1954_H3K27me3_silencer_df = HCC1954_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# HCC1954_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# HCC1954_H3K27me3_silencer_df["annotation"] = "HCC1954_H3K27me3_silencer"
# HCC1954_H3K27me3_silencer_df = HCC1954_H3K27me3_silencer_df.drop_duplicates()

#####################################

#REST silencers

# Distal_ATAC_HMEC = ATAC_peak_HMEC.subtract(Coding_promoter, A=True)
# HMEC_REST_silencer = REST_peak_HMEC.intersect(Distal_ATAC_HMEC, wb=True, f=0.1, r=True)
# HMEC_REST_silencer = HMEC_REST_silencer.subtract(Distal_H3K27ac_HMEC, A=True)
# HMEC_REST_silencer = HMEC_REST_silencer.subtract(Distal_H3K27me3_HMEC, A=True)
# HMEC_REST_silencer_df = pd.read_table(HMEC_REST_silencer.fn,header=None)
# HMEC_REST_silencer_df = HMEC_REST_silencer_df.iloc[:, [4,5,6,7]]
# HMEC_REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# HMEC_REST_silencer_df["annotation"] = "HMEC_REST_silencer"
# HMEC_REST_silencer_df = HMEC_REST_silencer_df.drop_duplicates()

#####################################

# #Polycomb-promoters
# H3K4me3_peak_HMEC_proximal = H3K4me3_peak_HMEC.intersect(Coding_promoter, wa=True)
# Polycomb_promoter_HMEC = H3K4me3_peak_HMEC_proximal.intersect(SUZ12_peak_HMEC, wa=True, wb=True) 
# Polycomb_promoter_HMEC_df = pd.read_table(Polycomb_promoter_HMEC.fn,header=None)
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.drop(Polycomb_promoter_HMEC_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_HMEC_df_1 = Polycomb_promoter_HMEC_df.iloc[:,0:3]
# Polycomb_promoter_HMEC_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_HMEC_df_1["id"] = range(1, 1 + len(Polycomb_promoter_HMEC_df_1))
# Polycomb_promoter_HMEC_df_1["id"] = "AE_" + Polycomb_promoter_HMEC_df_1["id"].astype(str)
# Polycomb_promoter_HMEC_df_2 = Polycomb_promoter_HMEC_df.iloc[:,3:]
# Polycomb_promoter_HMEC_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_HMEC_df_2["id"] = range(1, 1 + len(Polycomb_promoter_HMEC_df_2))
# Polycomb_promoter_HMEC_df_2["id"] = "AE_" + Polycomb_promoter_HMEC_df_2["id"].astype(str)
# Polycomb_promoter_HMEC_df = pd.concat([Polycomb_promoter_HMEC_df_1,Polycomb_promoter_HMEC_df_2])
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.sort_values(by='id')
# Polycomb_promoter_HMEC = pybed.BedTool.from_dataframe(Polycomb_promoter_HMEC_df)
# Polycomb_promoter_HMEC = Polycomb_promoter_HMEC.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_HMEC_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_HMEC_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df[["chr", "start", "end"]]
# Polycomb_promoter_HMEC_df["annotation"] = "HMEC_polycomb_promoter"
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.drop_duplicates()

#Active-promoters
# H3K4me3_peak_HMEC_proximal = H3K4me3_peak_HMEC.intersect(Coding_promoter, wa=True)
# Active_promoter_HMEC = H3K4me3_peak_HMEC_proximal.intersect(H3K27ac_peak_HMEC, wa=True, wb=True) 
# Active_promoter_HMEC_df = pd.read_table(Active_promoter_HMEC.fn,header=None)
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.drop(Active_promoter_HMEC_df.columns[[3, 7]],axis = 1)
# Active_promoter_HMEC_df_1 = Active_promoter_HMEC_df.iloc[:,0:3]
# Active_promoter_HMEC_df_1.columns = ["chr", "start", "end"]
# Active_promoter_HMEC_df_1["id"] = range(1, 1 + len(Active_promoter_HMEC_df_1))
# Active_promoter_HMEC_df_1["id"] = "AE_" + Active_promoter_HMEC_df_1["id"].astype(str)
# Active_promoter_HMEC_df_2 = Active_promoter_HMEC_df.iloc[:,3:]
# Active_promoter_HMEC_df_2.columns = ["chr", "start", "end"]
# Active_promoter_HMEC_df_2["id"] = range(1, 1 + len(Active_promoter_HMEC_df_2))
# Active_promoter_HMEC_df_2["id"] = "AE_" + Active_promoter_HMEC_df_2["id"].astype(str)
# Active_promoter_HMEC_df = pd.concat([Active_promoter_HMEC_df_1,Active_promoter_HMEC_df_2])
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.sort_values(by='id')
# Active_promoter_HMEC = pybed.BedTool.from_dataframe(Active_promoter_HMEC_df)
# Active_promoter_HMEC = Active_promoter_HMEC.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_HMEC_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_HMEC_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_HMEC_df = Active_promoter_HMEC_df[["chr", "start", "end"]]
# Active_promoter_HMEC_df["annotation"] = "HMEC_active_promoter"
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.drop_duplicates()

#active enhancer
Distal_ATAC_HCC1954 = ATAC_peak_HCC1954.subtract(Coding_promoter, A=True)
Distal_H3K27ac_HCC1954 = H3K27ac_peak_HCC1954.subtract(Coding_promoter, A=True)
HCC1954_active_enhancer = Distal_H3K27ac_HCC1954.intersect(Distal_ATAC_HCC1954, wb=True, f=0.1, r=True)
HCC1954_active_enhancer = HCC1954_active_enhancer.subtract(H3K27me3_peak_HCC1954, A=True)
HCC1954_active_enhancer_df = pd.read_table(HCC1954_active_enhancer.fn,header=None)
HCC1954_active_enhancer_df = HCC1954_active_enhancer_df.iloc[:, [4,5,6,7]]
HCC1954_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
HCC1954_active_enhancer_df["annotation"] = "HCC1954_active_enhancer"
HCC1954_active_enhancer_df = HCC1954_active_enhancer_df.drop_duplicates()
#
# HCC1954_active_enhancer = pybed.BedTool.from_dataframe(HCC1954_active_enhancer_df)
# Active_promoter_HCC1954_enh = HCC1954_active_enhancer.intersect(H3K4me3_peak_HCC1954, wa=True, f=0.1, r=True)
# Active_promoter_HCC1954_enh_df = pd.read_table(Active_promoter_HCC1954_enh.fn, header=None)
# Active_promoter_HCC1954_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_HCC1954_enh_df['annotation'] = 'HCC1954_active_promoter'
# HCC1954_active_enhancer = HCC1954_active_enhancer.subtract(H3K4me3_peak_HCC1954, A=True)
# HCC1954_active_enhancer_df = pd.read_table(HCC1954_active_enhancer.fn, header=None)
# HCC1954_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_HCC1954 = ATAC_peak_HCC1954.subtract(Coding_promoter, A=True)
Distal_H3K27me3_HCC1954 = H3K27me3_peak_HCC1954.subtract(Coding_promoter, A=True)
HCC1954_H3K27me3_silencer = Distal_H3K27me3_HCC1954.intersect(Distal_ATAC_HCC1954, wb=True, f=0.1, r=True)
HCC1954_H3K27me3_silencer = HCC1954_H3K27me3_silencer.subtract(Distal_H3K27ac_HCC1954, A=True)
HCC1954_H3K27me3_silencer_df = pd.read_table(HCC1954_H3K27me3_silencer.fn,header=None)
HCC1954_H3K27me3_silencer_df = HCC1954_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
HCC1954_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
HCC1954_H3K27me3_silencer_df["annotation"] = "HCC1954_H3K27me3_silencer"
HCC1954_H3K27me3_silencer_df = HCC1954_H3K27me3_silencer_df.drop_duplicates()
#

# HCC1954_H3K27me3_silencer = pybed.BedTool.from_dataframe(HCC1954_H3K27me3_silencer_df)
# HCC1954_H3K27me3_silencer = HCC1954_H3K27me3_silencer.subtract(H3K4me3_peak_HCC1954, A=True)
# HCC1954_H3K27me3_silencer_df = pd.read_table(HCC1954_H3K27me3_silencer.fn, header=None)
# HCC1954_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_HCC1954_proximal = ATAC_peak_HCC1954.intersect(Coding_promoter, wa=True)
Active_promoter_HCC1954 = ATAC_peak_HCC1954_proximal.intersect(H3K27ac_peak_HCC1954, wa=True)
Active_promoter_HCC1954 = Active_promoter_HCC1954.subtract(H3K27me3_peak_HCC1954, A=True)
Active_promoter_HCC1954_df = pd.read_table(Active_promoter_HCC1954.fn,header=None) 
Active_promoter_HCC1954_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_HCC1954_df["annotation"] = "HCC1954_active_promoter"
Active_promoter_HCC1954_df = Active_promoter_HCC1954_df.drop_duplicates()
#
# Active_promoter_HCC1954 = pybed.BedTool.from_dataframe(Active_promoter_HCC1954_df)
# Active_enhancer_HCC1954_prom = Active_promoter_HCC1954.intersect(H3K4me1_peak_HCC1954, wa=True)
# Active_enhancer_HCC1954_prom_df = pd.read_table(Active_enhancer_HCC1954_prom.fn, header=None)
# Active_enhancer_HCC1954_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_HCC1954_prom_df['annotation'] = 'HCC1954_active_enhancer'
# Active_promoter_HCC1954 = Active_promoter_HCC1954.intersect(H3K4me1_peak_HCC1954, v=True)
# Active_promoter_HCC1954_df = pd.read_table(Active_promoter_HCC1954.fn, header=None)
# Active_promoter_HCC1954_df.columns = ['chr', 'start', 'end', 'annotation']

HCC1954_reg_elements = pd.concat([ HCC1954_active_enhancer_df, HCC1954_H3K27me3_silencer_df , Active_promoter_HCC1954_df ])
HCC1954_reg_elements = HCC1954_reg_elements.drop_duplicates()
display(HCC1954_reg_elements)

HCC1954_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/HCC1954_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/4121029933.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_HCC1954_df['Annotation'] = "HCC1954_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/4121029933.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#Call SKBR3 reg-elements

pd.options.display.float_format = '{:,.0f}'.format

ATAC_peak_SKBR3 = pd.read_table("/home/darragh/New/ATAC-seq/SKBR3/naive/SKBR3_peaks.preprocessed.bed")
ATAC_peak_SKBR3_df = ATAC_peak_SKBR3.iloc[:, [0,1,2]]
ATAC_peak_SKBR3_df.columns = ["chr", "start", "end"]
ATAC_peak_SKBR3_df['Annotation'] = "SKBR3_ATAC_peak"
ATAC_peak_SKBR3 = pybed.BedTool.from_dataframe(ATAC_peak_SKBR3_df)
ATAC_peak_SKBR3 = ATAC_peak_SKBR3.sort()

H3K27ac_peak_SKBR3 = pd.read_table("/home/darragh/New/ChIP-seq/SKBR3/H3K27ac/results/Peak/SRR3997283_peaks.preprocessed.bed")
H3K27ac_peak_SKBR3_df = H3K27ac_peak_SKBR3.iloc[:, [0,1,2]]
H3K27ac_peak_SKBR3_df.columns = ["chr", "start", "end"]
H3K27ac_peak_SKBR3_df['Annotation'] = "SKBR3_H3K27ac_peak"
H3K27ac_peak_SKBR3 = pybed.BedTool.from_dataframe(H3K27ac_peak_SKBR3_df)
H3K27ac_peak_SKBR3 = H3K27ac_peak_SKBR3.sort()

H3K27me3_peak_SKBR3 = pd.read_table("/home/darragh/New/ChIP-seq/SKBR3/H3K27me3/results/Peak/SRR3997285_peaks.preprocessed.bed")
H3K27me3_peak_SKBR3_df = H3K27me3_peak_SKBR3.iloc[:, [0,1,2]]
H3K27me3_peak_SKBR3_df.columns = ["chr", "start", "end"]
H3K27me3_peak_SKBR3_df['Annotation'] = "SKBR3_H3K27me3_peak"
H3K27me3_peak_SKBR3 = pybed.BedTool.from_dataframe(H3K27me3_peak_SKBR3_df)
H3K27me3_peak_SKBR3 = H3K27me3_peak_SKBR3.sort()

H3K4me3_peak_SKBR3 = pd.read_table("/home/darragh/New/ChIP-seq/SKBR3/H3K4me3/results/Peak/SRR3997291_peaks.preprocessed.bed")
H3K4me3_peak_SKBR3_df = H3K4me3_peak_SKBR3.iloc[:, [0,1,2]]
H3K4me3_peak_SKBR3_df.columns = ["chr", "start", "end"]
H3K4me3_peak_SKBR3_df['Annotation'] = "SKBR3_H3K4me3_peak"
H3K4me3_peak_SKBR3 = pybed.BedTool.from_dataframe(H3K4me3_peak_SKBR3_df)
H3K4me3_peak_SKBR3 = H3K4me3_peak_SKBR3.sort()

H3K4me1_peak_SKBR3 = pd.read_table("/home/darragh/New/ChIP-seq/SKBR3/H3K4me1/results/Peak/SRR3997289_peaks.preprocessed.bed")
H3K4me1_peak_SKBR3_df = H3K4me1_peak_SKBR3.iloc[:, [0,1,2]]
H3K4me1_peak_SKBR3_df.columns = ["chr", "start", "end"]
H3K4me1_peak_SKBR3_df['Annotation'] = "SKBR3_H3K4me1_peak"
H3K4me1_peak_SKBR3 = pybed.BedTool.from_dataframe(H3K4me1_peak_SKBR3_df)
H3K4me1_peak_SKBR3 = H3K4me1_peak_SKBR3.sort()




###########################################

# #Active-enhancers
# Distal_ATAC_HMEC = ATAC_peak_HMEC.subtract(Coding_promoter, A=True)
# Distal_H3K27ac_HMEC = H3K27ac_peak_HMEC.subtract(Coding_promoter, A=True)
# HMEC_active_enhancer = Distal_H3K27ac_HMEC.intersect(Distal_ATAC_HMEC, wa=True, wb=True, f=0.1, r=True)
# HMEC_active_enhancer_df = pd.read_table(HMEC_active_enhancer.fn,header=None)
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.drop(HMEC_active_enhancer_df.columns[[3, 7]],axis = 1)
# HMEC_active_enhancer_df_1 = HMEC_active_enhancer_df.iloc[:,0:3]
# HMEC_active_enhancer_df_1.columns = ["chr", "start", "end"]
# HMEC_active_enhancer_df_1["id"] = range(1, 1 + len(HMEC_active_enhancer_df_1))
# HMEC_active_enhancer_df_1["id"] = "AE_" + HMEC_active_enhancer_df_1["id"].astype(str)
# HMEC_active_enhancer_df_2 = HMEC_active_enhancer_df.iloc[:,3:]
# HMEC_active_enhancer_df_2.columns = ["chr", "start", "end"]
# HMEC_active_enhancer_df_2["id"] = range(1, 1 + len(HMEC_active_enhancer_df_2))
# HMEC_active_enhancer_df_2["id"] = "AE_" + HMEC_active_enhancer_df_2["id"].astype(str)
# HMEC_active_enhancer_df = pd.concat([HMEC_active_enhancer_df_1,HMEC_active_enhancer_df_2])
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.sort_values(by='id')
# HMEC_active_enhancer = pybed.BedTool.from_dataframe(HMEC_active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# HMEC_active_enhancer = HMEC_active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# HMEC_active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# HMEC_active_enhancer_df.columns = ["chr", "name", "start", "end"]
# HMEC_active_enhancer_df = HMEC_active_enhancer_df[["chr", "start", "end"]]
# HMEC_active_enhancer_df["annotation"] = "HMEC_active_enhancer"
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.drop_duplicates()

# Distal_ATAC_SKBR3 = ATAC_peak_SKBR3.subtract(Coding_promoter, A=True)
# Distal_H3K27ac_SKBR3 = H3K27ac_peak_SKBR3.subtract(Coding_promoter, A=True)
# SKBR3_active_enhancer = Distal_H3K27ac_SKBR3.intersect(Distal_ATAC_SKBR3, wb=True, f=0.1, r=True)
# SKBR3_active_enhancer = SKBR3_active_enhancer.subtract(H3K27me3_peak_SKBR3, A=True)
# SKBR3_active_enhancer_df = pd.read_table(SKBR3_active_enhancer.fn,header=None)
# SKBR3_active_enhancer_df = SKBR3_active_enhancer_df.iloc[:, [4,5,6,7]]
# SKBR3_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
# SKBR3_active_enhancer_df["annotation"] = "SKBR3_active_enhancer"
# SKBR3_active_enhancer_df = SKBR3_active_enhancer_df.drop_duplicates()


# #####################################

# #H3K27me3 silencers
# Distal_ATAC_SKBR3 = ATAC_peak_SKBR3.subtract(Coding_promoter, A=True)
# Distal_H3K27me3_SKBR3 = H3K27me3_peak_SKBR3.subtract(Coding_promoter, A=True)
# SKBR3_H3K27me3_silencer = Distal_H3K27me3_SKBR3.intersect(Distal_ATAC_SKBR3, wb=True, f=0.1, r=True)
# SKBR3_H3K27me3_silencer = SKBR3_H3K27me3_silencer.subtract(Distal_H3K27ac_SKBR3, A=True)
# SKBR3_H3K27me3_silencer_df = pd.read_table(SKBR3_H3K27me3_silencer.fn,header=None)
# SKBR3_H3K27me3_silencer_df = SKBR3_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# SKBR3_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# SKBR3_H3K27me3_silencer_df["annotation"] = "SKBR3_H3K27me3_silencer"
# SKBR3_H3K27me3_silencer_df = SKBR3_H3K27me3_silencer_df.drop_duplicates()

#####################################

#REST silencers

# Distal_ATAC_HMEC = ATAC_peak_HMEC.subtract(Coding_promoter, A=True)
# HMEC_REST_silencer = REST_peak_HMEC.intersect(Distal_ATAC_HMEC, wb=True, f=0.1, r=True)
# HMEC_REST_silencer = HMEC_REST_silencer.subtract(Distal_H3K27ac_HMEC, A=True)
# HMEC_REST_silencer = HMEC_REST_silencer.subtract(Distal_H3K27me3_HMEC, A=True)
# HMEC_REST_silencer_df = pd.read_table(HMEC_REST_silencer.fn,header=None)
# HMEC_REST_silencer_df = HMEC_REST_silencer_df.iloc[:, [4,5,6,7]]
# HMEC_REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# HMEC_REST_silencer_df["annotation"] = "HMEC_REST_silencer"
# HMEC_REST_silencer_df = HMEC_REST_silencer_df.drop_duplicates()

#####################################

# #Polycomb-promoters
# H3K4me3_peak_HMEC_proximal = H3K4me3_peak_HMEC.intersect(Coding_promoter, wa=True)
# Polycomb_promoter_HMEC = H3K4me3_peak_HMEC_proximal.intersect(SUZ12_peak_HMEC, wa=True, wb=True) 
# Polycomb_promoter_HMEC_df = pd.read_table(Polycomb_promoter_HMEC.fn,header=None)
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.drop(Polycomb_promoter_HMEC_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_HMEC_df_1 = Polycomb_promoter_HMEC_df.iloc[:,0:3]
# Polycomb_promoter_HMEC_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_HMEC_df_1["id"] = range(1, 1 + len(Polycomb_promoter_HMEC_df_1))
# Polycomb_promoter_HMEC_df_1["id"] = "AE_" + Polycomb_promoter_HMEC_df_1["id"].astype(str)
# Polycomb_promoter_HMEC_df_2 = Polycomb_promoter_HMEC_df.iloc[:,3:]
# Polycomb_promoter_HMEC_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_HMEC_df_2["id"] = range(1, 1 + len(Polycomb_promoter_HMEC_df_2))
# Polycomb_promoter_HMEC_df_2["id"] = "AE_" + Polycomb_promoter_HMEC_df_2["id"].astype(str)
# Polycomb_promoter_HMEC_df = pd.concat([Polycomb_promoter_HMEC_df_1,Polycomb_promoter_HMEC_df_2])
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.sort_values(by='id')
# Polycomb_promoter_HMEC = pybed.BedTool.from_dataframe(Polycomb_promoter_HMEC_df)
# Polycomb_promoter_HMEC = Polycomb_promoter_HMEC.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_HMEC_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_HMEC_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df[["chr", "start", "end"]]
# Polycomb_promoter_HMEC_df["annotation"] = "HMEC_polycomb_promoter"
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.drop_duplicates()

#Active-promoters
# H3K4me3_peak_HMEC_proximal = H3K4me3_peak_HMEC.intersect(Coding_promoter, wa=True)
# Active_promoter_HMEC = H3K4me3_peak_HMEC_proximal.intersect(H3K27ac_peak_HMEC, wa=True, wb=True) 
# Active_promoter_HMEC_df = pd.read_table(Active_promoter_HMEC.fn,header=None)
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.drop(Active_promoter_HMEC_df.columns[[3, 7]],axis = 1)
# Active_promoter_HMEC_df_1 = Active_promoter_HMEC_df.iloc[:,0:3]
# Active_promoter_HMEC_df_1.columns = ["chr", "start", "end"]
# Active_promoter_HMEC_df_1["id"] = range(1, 1 + len(Active_promoter_HMEC_df_1))
# Active_promoter_HMEC_df_1["id"] = "AE_" + Active_promoter_HMEC_df_1["id"].astype(str)
# Active_promoter_HMEC_df_2 = Active_promoter_HMEC_df.iloc[:,3:]
# Active_promoter_HMEC_df_2.columns = ["chr", "start", "end"]
# Active_promoter_HMEC_df_2["id"] = range(1, 1 + len(Active_promoter_HMEC_df_2))
# Active_promoter_HMEC_df_2["id"] = "AE_" + Active_promoter_HMEC_df_2["id"].astype(str)
# Active_promoter_HMEC_df = pd.concat([Active_promoter_HMEC_df_1,Active_promoter_HMEC_df_2])
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.sort_values(by='id')
# Active_promoter_HMEC = pybed.BedTool.from_dataframe(Active_promoter_HMEC_df)
# Active_promoter_HMEC = Active_promoter_HMEC.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_HMEC_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_HMEC_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_HMEC_df = Active_promoter_HMEC_df[["chr", "start", "end"]]
# Active_promoter_HMEC_df["annotation"] = "HMEC_active_promoter"
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.drop_duplicates()

#active enhancer
Distal_ATAC_SKBR3 = ATAC_peak_SKBR3.subtract(Coding_promoter, A=True)
Distal_H3K27ac_SKBR3 = H3K27ac_peak_SKBR3.subtract(Coding_promoter, A=True)
SKBR3_active_enhancer = Distal_H3K27ac_SKBR3.intersect(Distal_ATAC_SKBR3, wb=True, f=0.1, r=True)
SKBR3_active_enhancer = SKBR3_active_enhancer.subtract(H3K27me3_peak_SKBR3, A=True)
SKBR3_active_enhancer_df = pd.read_table(SKBR3_active_enhancer.fn,header=None)
SKBR3_active_enhancer_df = SKBR3_active_enhancer_df.iloc[:, [4,5,6,7]]
SKBR3_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
SKBR3_active_enhancer_df["annotation"] = "SKBR3_active_enhancer"
SKBR3_active_enhancer_df = SKBR3_active_enhancer_df.drop_duplicates()
#
# SKBR3_active_enhancer = pybed.BedTool.from_dataframe(SKBR3_active_enhancer_df)
# Active_promoter_SKBR3_enh = SKBR3_active_enhancer.intersect(H3K4me3_peak_SKBR3, wa=True)
# Active_promoter_SKBR3_enh_df = pd.read_table(Active_promoter_SKBR3_enh.fn, header=None)
# Active_promoter_SKBR3_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_SKBR3_enh_df['annotation'] = 'SKBR3_active_promoter'
# SKBR3_active_enhancer = SKBR3_active_enhancer.subtract(H3K4me3_peak_SKBR3, A=True)
# SKBR3_active_enhancer_df = pd.read_table(SKBR3_active_enhancer.fn, header=None)
# SKBR3_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_SKBR3 = ATAC_peak_SKBR3.subtract(Coding_promoter, A=True)
Distal_H3K27me3_SKBR3 = H3K27me3_peak_SKBR3.subtract(Coding_promoter, A=True)
SKBR3_H3K27me3_silencer = Distal_H3K27me3_SKBR3.intersect(Distal_ATAC_SKBR3, wb=True, f=0.1, r=True)
SKBR3_H3K27me3_silencer = SKBR3_H3K27me3_silencer.subtract(Distal_H3K27ac_SKBR3, A=True)
SKBR3_H3K27me3_silencer_df = pd.read_table(SKBR3_H3K27me3_silencer.fn,header=None)
SKBR3_H3K27me3_silencer_df = SKBR3_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
SKBR3_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
SKBR3_H3K27me3_silencer_df["annotation"] = "SKBR3_H3K27me3_silencer"
SKBR3_H3K27me3_silencer_df = SKBR3_H3K27me3_silencer_df.drop_duplicates()
#
# SKBR3_H3K27me3_silencer = pybed.BedTool.from_dataframe(SKBR3_H3K27me3_silencer_df)
# # Active_promoter_SKBR3_sil = SKBR3_H3K27me3_silencer.intersect(H3K4me3_peak_SKBR3, wa=True)
# # Active_promoter_SKBR3_sil_df = pd.read_table(Active_promoter_SKBR3_sil.fn, header=None)
# # Active_promoter_SKBR3_sil_df.columns = ['chr', 'start', 'end', 'annotation']
# # Active_promoter_SKBR3_sil_df['annotation'] = 'SKBR3_active_promoter'
# SKBR3_H3K27me3_silencer = SKBR3_H3K27me3_silencer.subtract(H3K4me3_peak_SKBR3, A=True)
# SKBR3_H3K27me3_silencer_df = pd.read_table(SKBR3_H3K27me3_silencer.fn, header=None)
# SKBR3_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_SKBR3_proximal = ATAC_peak_SKBR3.intersect(Coding_promoter, wa=True)
Active_promoter_SKBR3 = ATAC_peak_SKBR3_proximal.intersect(H3K27ac_peak_SKBR3, wa=True)
Active_promoter_SKBR3 = Active_promoter_SKBR3.subtract(H3K27me3_peak_SKBR3, A=True)
Active_promoter_SKBR3_df = pd.read_table(Active_promoter_SKBR3.fn,header=None) 
Active_promoter_SKBR3_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_SKBR3_df["annotation"] = "SKBR3_active_promoter"
Active_promoter_SKBR3_df = Active_promoter_SKBR3_df.drop_duplicates()

#

# Active_promoter_SKBR3 = pybed.BedTool.from_dataframe(Active_promoter_SKBR3_df)
# Active_enhancer_SKBR3_prom = Active_promoter_SKBR3.intersect(H3K4me1_peak_SKBR3, wa=True)
# Active_enhancer_SKBR3_prom_df = pd.read_table(Active_enhancer_SKBR3_prom.fn, header=None)
# Active_enhancer_SKBR3_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_SKBR3_prom_df['annotation'] = 'SKBR3_active_promoter'
# Active_promoter_SKBR3 = Active_promoter_SKBR3.subtract(H3K4me1_peak_SKBR3, A=True)
# Active_promoter_SKBR3_df = pd.read_table(Active_promoter_SKBR3.fn, header=None)
# Active_promoter_SKBR3_df.columns = ['chr', 'start', 'end', 'annotation']

SKBR3_reg_elements = pd.concat([ SKBR3_active_enhancer_df, SKBR3_H3K27me3_silencer_df , Active_promoter_SKBR3_df])
SKBR3_reg_elements = SKBR3_reg_elements.drop_duplicates()
display(SKBR3_reg_elements)

SKBR3_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/SKBR3_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/1296378015.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_SKBR3_df['Annotation'] = "SKBR3_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/1296378015.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_SKBR3_df['Annotation'] = "SKBR3_H3K27ac_peak"
# ...

# %%
#Call HMEC reg-elements

pd.options.display.float_format = '{:,.0f}'.format

# HMEC_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/HMEC/HMEC_Gateway_SuperEnhancers.bed",header=None)
# HMEC_Super_enhancers_df = HMEC_Super_enhancers_df.iloc[:, [0,1,2]]
# HMEC_Super_enhancers_df.columns = ["chr", "start", "end"]
# HMEC_Super_enhancers_df['Annotation'] = "HMEC_super_enhancer"
# HMEC_Super_enhancers = pybed.BedTool.from_dataframe(HMEC_Super_enhancers_df)

ATAC_peak_HMEC = pd.read_table("/home/darragh/New/ATAC-seq/HMEC/naive/HMEC_peaks.preprocessed.bed")
ATAC_peak_HMEC_df = ATAC_peak_HMEC.iloc[:, [0,1,2]]
ATAC_peak_HMEC_df.columns = ["chr", "start", "end"]
ATAC_peak_HMEC_df['Annotation'] = "HMEC_ATAC_peak"
ATAC_peak_HMEC = pybed.BedTool.from_dataframe(ATAC_peak_HMEC_df)
ATAC_peak_HMEC = ATAC_peak_HMEC.sort()

H3K27ac_peak_HMEC = pd.read_table("/home/darragh/New/ChIP-seq/HMEC/H3K27ac/results/Peak/HMEC_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_HMEC_df = H3K27ac_peak_HMEC.iloc[:, [0,1,2]]
H3K27ac_peak_HMEC_df.columns = ["chr", "start", "end"]
H3K27ac_peak_HMEC_df['Annotation'] = "HMEC_H3K27ac_peak"
H3K27ac_peak_HMEC = pybed.BedTool.from_dataframe(H3K27ac_peak_HMEC_df)
H3K27ac_peak_HMEC = H3K27ac_peak_HMEC.sort()

H3K27me3_peak_HMEC = pd.read_table("/home/darragh/New/ChIP-seq/HMEC/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_HMEC_df = H3K27me3_peak_HMEC.iloc[:, [0,1,2]]
H3K27me3_peak_HMEC_df.columns = ["chr", "start", "end"]
H3K27me3_peak_HMEC_df['Annotation'] = "HMEC_H3K27me3_peak"
H3K27me3_peak_HMEC = pybed.BedTool.from_dataframe(H3K27me3_peak_HMEC_df)
H3K27me3_peak_HMEC = H3K27me3_peak_HMEC.sort()

H3K4me3_peak_HMEC = pd.read_table("/home/darragh/New/ChIP-seq/HMEC/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_HMEC_df = H3K4me3_peak_HMEC.iloc[:, [0,1,2]]
H3K4me3_peak_HMEC_df.columns = ["chr", "start", "end"]
H3K4me3_peak_HMEC_df['Annotation'] = "HMEC_H3K4me3_peak"
H3K4me3_peak_HMEC = pybed.BedTool.from_dataframe(H3K4me3_peak_HMEC_df)
H3K4me3_peak_HMEC = H3K4me3_peak_HMEC.sort()


H3K4me1_peak_HMEC = pd.read_table("/home/darragh/New/ChIP-seq/HMEC/H3K4me1/results/Peak/H3K4me1_peaks.preprocessed.bed")
H3K4me1_peak_HMEC_df = H3K4me1_peak_HMEC.iloc[:, [0,1,2]]
H3K4me1_peak_HMEC_df.columns = ["chr", "start", "end"]
H3K4me1_peak_HMEC_df['Annotation'] = "HMEC_H3K4me1_peak"
H3K4me1_peak_HMEC = pybed.BedTool.from_dataframe(H3K4me1_peak_HMEC_df)
H3K4me1_peak_HMEC = H3K4me1_peak_HMEC.sort()


REST_peak_HMEC = pd.read_table("/home/darragh/New/ChIP-seq/HMEC/REST/results/Peak/REST_peaks.preprocessed.bed")
REST_peak_HMEC_df = REST_peak_HMEC.iloc[:, [0,1,2]]
REST_peak_HMEC_df.columns = ["chr", "start", "end"]
REST_peak_HMEC_df['Annotation'] = "HMEC_REST_peak"
REST_peak_HMEC = pybed.BedTool.from_dataframe(REST_peak_HMEC_df)
REST_peak_HMEC = REST_peak_HMEC.sort()

###########################################

# #Active-enhancers
# Distal_ATAC_HMEC = ATAC_peak_HMEC.subtract(Coding_promoter, A=True)
# Distal_H3K27ac_HMEC = H3K27ac_peak_HMEC.subtract(Coding_promoter, A=True)
# HMEC_active_enhancer = Distal_H3K27ac_HMEC.intersect(Distal_ATAC_HMEC, wa=True, wb=True, f=0.1, r=True)
# HMEC_active_enhancer_df = pd.read_table(HMEC_active_enhancer.fn,header=None)
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.drop(HMEC_active_enhancer_df.columns[[3, 7]],axis = 1)
# HMEC_active_enhancer_df_1 = HMEC_active_enhancer_df.iloc[:,0:3]
# HMEC_active_enhancer_df_1.columns = ["chr", "start", "end"]
# HMEC_active_enhancer_df_1["id"] = range(1, 1 + len(HMEC_active_enhancer_df_1))
# HMEC_active_enhancer_df_1["id"] = "AE_" + HMEC_active_enhancer_df_1["id"].astype(str)
# HMEC_active_enhancer_df_2 = HMEC_active_enhancer_df.iloc[:,3:]
# HMEC_active_enhancer_df_2.columns = ["chr", "start", "end"]
# HMEC_active_enhancer_df_2["id"] = range(1, 1 + len(HMEC_active_enhancer_df_2))
# HMEC_active_enhancer_df_2["id"] = "AE_" + HMEC_active_enhancer_df_2["id"].astype(str)
# HMEC_active_enhancer_df = pd.concat([HMEC_active_enhancer_df_1,HMEC_active_enhancer_df_2])
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.sort_values(by='id')
# HMEC_active_enhancer = pybed.BedTool.from_dataframe(HMEC_active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# HMEC_active_enhancer = HMEC_active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# HMEC_active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# HMEC_active_enhancer_df.columns = ["chr", "name", "start", "end"]
# HMEC_active_enhancer_df = HMEC_active_enhancer_df[["chr", "start", "end"]]
# HMEC_active_enhancer_df["annotation"] = "HMEC_active_enhancer"
# HMEC_active_enhancer_df = HMEC_active_enhancer_df.drop_duplicates()

#####################################

#REST silencers

# Distal_ATAC_HMEC = ATAC_peak_HMEC.subtract(Coding_promoter, A=True)
# HMEC_REST_silencer = REST_peak_HMEC.intersect(Distal_ATAC_HMEC, wb=True, f=0.1, r=True)
# HMEC_REST_silencer = HMEC_REST_silencer.subtract(Distal_H3K27ac_HMEC, A=True)
# HMEC_REST_silencer = HMEC_REST_silencer.subtract(Distal_H3K27me3_HMEC, A=True)
# HMEC_REST_silencer_df = pd.read_table(HMEC_REST_silencer.fn,header=None)
# HMEC_REST_silencer_df = HMEC_REST_silencer_df.iloc[:, [4,5,6,7]]
# HMEC_REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# HMEC_REST_silencer_df["annotation"] = "HMEC_REST_silencer"
# HMEC_REST_silencer_df = HMEC_REST_silencer_df.drop_duplicates()

#####################################

# #Polycomb-promoters
# H3K4me3_peak_HMEC_proximal = H3K4me3_peak_HMEC.intersect(Coding_promoter, wa=True)
# Polycomb_promoter_HMEC = H3K4me3_peak_HMEC_proximal.intersect(SUZ12_peak_HMEC, wa=True, wb=True) 
# Polycomb_promoter_HMEC_df = pd.read_table(Polycomb_promoter_HMEC.fn,header=None)
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.drop(Polycomb_promoter_HMEC_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_HMEC_df_1 = Polycomb_promoter_HMEC_df.iloc[:,0:3]
# Polycomb_promoter_HMEC_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_HMEC_df_1["id"] = range(1, 1 + len(Polycomb_promoter_HMEC_df_1))
# Polycomb_promoter_HMEC_df_1["id"] = "AE_" + Polycomb_promoter_HMEC_df_1["id"].astype(str)
# Polycomb_promoter_HMEC_df_2 = Polycomb_promoter_HMEC_df.iloc[:,3:]
# Polycomb_promoter_HMEC_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_HMEC_df_2["id"] = range(1, 1 + len(Polycomb_promoter_HMEC_df_2))
# Polycomb_promoter_HMEC_df_2["id"] = "AE_" + Polycomb_promoter_HMEC_df_2["id"].astype(str)
# Polycomb_promoter_HMEC_df = pd.concat([Polycomb_promoter_HMEC_df_1,Polycomb_promoter_HMEC_df_2])
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.sort_values(by='id')
# Polycomb_promoter_HMEC = pybed.BedTool.from_dataframe(Polycomb_promoter_HMEC_df)
# Polycomb_promoter_HMEC = Polycomb_promoter_HMEC.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_HMEC_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_HMEC_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df[["chr", "start", "end"]]
# Polycomb_promoter_HMEC_df["annotation"] = "HMEC_polycomb_promoter"
# Polycomb_promoter_HMEC_df = Polycomb_promoter_HMEC_df.drop_duplicates()

#Active-promoters
# H3K4me3_peak_HMEC_proximal = H3K4me3_peak_HMEC.intersect(Coding_promoter, wa=True)
# Active_promoter_HMEC = H3K4me3_peak_HMEC_proximal.intersect(H3K27ac_peak_HMEC, wa=True, wb=True) 
# Active_promoter_HMEC_df = pd.read_table(Active_promoter_HMEC.fn,header=None)
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.drop(Active_promoter_HMEC_df.columns[[3, 7]],axis = 1)
# Active_promoter_HMEC_df_1 = Active_promoter_HMEC_df.iloc[:,0:3]
# Active_promoter_HMEC_df_1.columns = ["chr", "start", "end"]
# Active_promoter_HMEC_df_1["id"] = range(1, 1 + len(Active_promoter_HMEC_df_1))
# Active_promoter_HMEC_df_1["id"] = "AE_" + Active_promoter_HMEC_df_1["id"].astype(str)
# Active_promoter_HMEC_df_2 = Active_promoter_HMEC_df.iloc[:,3:]
# Active_promoter_HMEC_df_2.columns = ["chr", "start", "end"]
# Active_promoter_HMEC_df_2["id"] = range(1, 1 + len(Active_promoter_HMEC_df_2))
# Active_promoter_HMEC_df_2["id"] = "AE_" + Active_promoter_HMEC_df_2["id"].astype(str)
# Active_promoter_HMEC_df = pd.concat([Active_promoter_HMEC_df_1,Active_promoter_HMEC_df_2])
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.sort_values(by='id')
# Active_promoter_HMEC = pybed.BedTool.from_dataframe(Active_promoter_HMEC_df)
# Active_promoter_HMEC = Active_promoter_HMEC.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_HMEC_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_HMEC_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_HMEC_df = Active_promoter_HMEC_df[["chr", "start", "end"]]
# Active_promoter_HMEC_df["annotation"] = "HMEC_active_promoter"
# Active_promoter_HMEC_df = Active_promoter_HMEC_df.drop_duplicates()

#active enhancer
Distal_ATAC_HMEC = ATAC_peak_HMEC.subtract(Coding_promoter, A=True)
Distal_H3K27ac_HMEC = H3K27ac_peak_HMEC.subtract(Coding_promoter, A=True)
HMEC_active_enhancer = Distal_H3K27ac_HMEC.intersect(Distal_ATAC_HMEC, wb=True, f=0.1, r=True)
HMEC_active_enhancer = HMEC_active_enhancer.subtract(H3K27me3_peak_HMEC, A=True)
HMEC_active_enhancer_df = pd.read_table(HMEC_active_enhancer.fn,header=None)
HMEC_active_enhancer_df = HMEC_active_enhancer_df.iloc[:, [4,5,6,7]]
HMEC_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
HMEC_active_enhancer_df["annotation"] = "HMEC_active_enhancer"
HMEC_active_enhancer_df = HMEC_active_enhancer_df.drop_duplicates()
#
# HMEC_active_enhancer = pybed.BedTool.from_dataframe(HMEC_active_enhancer_df)
# Active_promoter_HMEC_enh = HMEC_active_enhancer.intersect(H3K4me3_peak_HMEC, wa=True)
# Active_promoter_HMEC_enh_df = pd.read_table(Active_promoter_HMEC_enh.fn, header=None)
# Active_promoter_HMEC_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_HMEC_enh_df['annotation'] = 'HMEC_active_promoter'
# HMEC_active_enhancer = HMEC_active_enhancer.subtract(H3K4me3_peak_HMEC, A=True)
# HMEC_active_enhancer_df = pd.read_table(HMEC_active_enhancer.fn, header=None)
# HMEC_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_HMEC = ATAC_peak_HMEC.subtract(Coding_promoter, A=True)
Distal_H3K27me3_HMEC = H3K27me3_peak_HMEC.subtract(Coding_promoter, A=True)
HMEC_H3K27me3_silencer = Distal_H3K27me3_HMEC.intersect(Distal_ATAC_HMEC, wb=True, f=0.1, r=True)
HMEC_H3K27me3_silencer = HMEC_H3K27me3_silencer.subtract(Distal_H3K27ac_HMEC, A=True)
HMEC_H3K27me3_silencer_df = pd.read_table(HMEC_H3K27me3_silencer.fn,header=None)
HMEC_H3K27me3_silencer_df = HMEC_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
HMEC_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
HMEC_H3K27me3_silencer_df["annotation"] = "HMEC_H3K27me3_silencer"
HMEC_H3K27me3_silencer_df = HMEC_H3K27me3_silencer_df.drop_duplicates()
#
# HMEC_H3K27me3_silencer = pybed.BedTool.from_dataframe(HMEC_H3K27me3_silencer_df)
# # Active_promoter_HMEC_sil = HMEC_H3K27me3_silencer.intersect(H3K4me3_peak_HMEC, wa=True)
# # Active_promoter_HMEC_sil_df = pd.read_table(Active_promoter_HMEC_sil.fn, header=None)
# # Active_promoter_HMEC_sil_df.columns = ['chr', 'start', 'end', 'annotation']
# # Active_promoter_HMEC_sil_df['annotation'] = 'HMEC_active_promoter'
# HMEC_H3K27me3_silencer = HMEC_H3K27me3_silencer.subtract(H3K4me3_peak_HMEC, A=True)
# HMEC_H3K27me3_silencer_df = pd.read_table(HMEC_H3K27me3_silencer.fn, header=None)
# HMEC_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_HMEC_proximal = ATAC_peak_HMEC.intersect(Coding_promoter, wa=True)
Active_promoter_HMEC = ATAC_peak_HMEC_proximal.intersect(H3K27ac_peak_HMEC, wa=True)
Active_promoter_HMEC = Active_promoter_HMEC.subtract(H3K27me3_peak_HMEC, A=True)
Active_promoter_HMEC_df = pd.read_table(Active_promoter_HMEC.fn,header=None) 
Active_promoter_HMEC_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_HMEC_df["annotation"] = "HMEC_active_promoter"
Active_promoter_HMEC_df = Active_promoter_HMEC_df.drop_duplicates()

#

# Active_promoter_HMEC = pybed.BedTool.from_dataframe(Active_promoter_HMEC_df)
# Active_enhancer_HMEC_prom = Active_promoter_HMEC.intersect(H3K4me1_peak_HMEC, wa=True)
# Active_enhancer_HMEC_prom_df = pd.read_table(Active_enhancer_HMEC_prom.fn, header=None)
# Active_enhancer_HMEC_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_HMEC_prom_df['annotation'] = 'HMEC_active_promoter'
# Active_promoter_HMEC = Active_promoter_HMEC.subtract(H3K4me1_peak_HMEC, A=True)
# Active_promoter_HMEC_df = pd.read_table(Active_promoter_HMEC.fn, header=None)
# Active_promoter_HMEC_df.columns = ['chr', 'start', 'end', 'annotation']

HMEC_reg_elements = pd.concat([ HMEC_active_enhancer_df, HMEC_H3K27me3_silencer_df , Active_promoter_HMEC_df ])
HMEC_reg_elements = HMEC_reg_elements.drop_duplicates()
display(HMEC_reg_elements)

HMEC_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/HMEC_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/2089067331.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_HMEC_df['Annotation'] = "HMEC_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/2089067331.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_HMEC_df['Annotation'] = "HMEC_H3K27ac_peak"
# ...

# %%
display(Polycomb_promoter_HMEC_df)
# Out:
#         chr      start        end              annotation
# 0      chr1     839368     841117  HMEC_polycomb_promoter
# 1      chr1     933050     936689  HMEC_polycomb_promoter
# 2      chr1   38509703   38514071  HMEC_polycomb_promoter
# 3     chr12    1638948    1641463  HMEC_polycomb_promoter
# 5     chr12    4377341    4382220  HMEC_polycomb_promoter
# ...     ...        ...        ...                     ...
# 4790  chr11  134281113  134282896  HMEC_polycomb_promoter
# 4791  chr11  134281496  134283158  HMEC_polycomb_promoter
# 4792  chr12     175933     176220  HMEC_polycomb_promoter
# 4793  chr12     312475     313418  HMEC_polycomb_promoter
# 4794  chr12     859904     866313  HMEC_polycomb_promoter
#
# [2883 rows x 4 columns]

# %% [markdown]
# # Add super-enhancers

# %%
HMEC_reg_elements = pybed.BedTool.from_dataframe(HMEC_reg_elements)
HMEC_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/HMEC/HMEC_Gateway_SuperEnhancers.bed",header=None)
HMEC_Super_enhancers_df = HMEC_Super_enhancers_df.iloc[:, [0,1,2]]
HMEC_Super_enhancers_df.columns = ["chr", "start", "end"]
HMEC_Super_enhancers_df['Annotation'] = "HMEC_super_enhancer"
HMEC_Super_enhancers = pybed.BedTool.from_dataframe(HMEC_Super_enhancers_df)
HMEC_reg_elements = HMEC_reg_elements.subtract(HMEC_Super_enhancers)

HMEC_reg_elements = pd.read_table(HMEC_reg_elements.fn, header=None)
HMEC_Super_enhancers = pd.read_table(HMEC_Super_enhancers.fn, header=None)

HMEC_reg_elements = pybed.BedTool.from_dataframe(pd.concat([HMEC_reg_elements,HMEC_Super_enhancers]))
HMEC_reg_elements = HMEC_reg_elements.sort()
HMEC_reg_elements = pd.read_table(HMEC_reg_elements.fn, header=None)
HMEC_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/HMEC_reg_elements.txt", sep='\t', index=False, header=None)

# %%
#Call MCF10A reg-elements

pd.options.display.float_format = '{:,.0f}'.format

ATAC_peak = pd.read_table("/home/darragh/New/ATAC-seq/MCF10A/naive/MCF10A_peaks.preprocessed.bed")
ATAC_peak_df = ATAC_peak.iloc[:, [0,1,2]]
ATAC_peak_df.columns = ["chr", "start", "end"]
ATAC_peak_df['Annotation'] = "MCF10A_ATAC_peak"
ATAC_peak = pybed.BedTool.from_dataframe(ATAC_peak_df)
ATAC_peak_MCF10A = ATAC_peak.sort()

H3K27ac_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF10A/H3K27ac/results/Peak/MCF10A_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_df = H3K27ac_peak.iloc[:, [0,1,2]]
H3K27ac_peak_df.columns = ["chr", "start", "end"]
H3K27ac_peak_df['Annotation'] = "MCF10A_H3K27ac_peak"
H3K27ac_peak = pybed.BedTool.from_dataframe(H3K27ac_peak_df)
H3K27ac_peak_MCF10A = H3K27ac_peak.sort()

H3K27me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF10A/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_df = H3K27me3_peak.iloc[:, [0,1,2]]
H3K27me3_peak_df.columns = ["chr", "start", "end"]
H3K27me3_peak_df['Annotation'] = "MCF10A_H3K27me3_peak"
H3K27me3_peak = pybed.BedTool.from_dataframe(H3K27me3_peak_df)
H3K27me3_peak_MCF10A = H3K27me3_peak.sort()

H3K4me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF10A/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_df = H3K4me3_peak.iloc[:, [0,1,2]]
H3K4me3_peak_df.columns = ["chr", "start", "end"]
H3K4me3_peak_df['Annotation'] = "MCF10A_H3K4me3_peak"
H3K4me3_peak = pybed.BedTool.from_dataframe(H3K4me3_peak_df)
H3K4me3_peak_MCF10A = H3K4me3_peak.sort()

H3K4me1_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF10A/H3K4me1/results/Peak/H3K4me1_peaks.preprocessed.bed")
H3K4me1_peak_df = H3K4me1_peak.iloc[:, [0,1,2]]
H3K4me1_peak_df.columns = ["chr", "start", "end"]
H3K4me1_peak_df['Annotation'] = "MCF10A_H3K4me1_peak"
H3K4me1_peak = pybed.BedTool.from_dataframe(H3K4me1_peak_df)
H3K4me1_peak_MCF10A = H3K4me1_peak.sort()

SUZ12_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF10A/SUZ12/SUZ12_peaks.preprocessed.bed")
SUZ12_peak_df = SUZ12_peak.iloc[:, [0,1,2]]
SUZ12_peak_df.columns = ["chr", "start", "end"]
SUZ12_peak_df['Annotation'] = "MCF10A_SUZ12_peak"
SUZ12_peak = pybed.BedTool.from_dataframe(SUZ12_peak_df)
SUZ12_peak = SUZ12_peak.sort()

REST_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF10A/REST/results/Peak/REST_peaks.preprocessed.bed")
REST_peak_df = REST_peak.iloc[:, [0,1,2]]
REST_peak_df.columns = ["chr", "start", "end"]
REST_peak_df['Annotation'] = "MCF10A_REST_peak"
REST_peak = pybed.BedTool.from_dataframe(REST_peak_df)
REST_peak = REST_peak.sort()

# ###########################################

# #Active-enhancers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27ac = H3K27ac_peak.subtract(Coding_promoter, A=True)
# active_enhancer = Distal_H3K27ac.intersect(Distal_ATAC, wa=True, wb=True, f=0.1, r=True)
# active_enhancer_df = pd.read_table(active_enhancer.fn,header=None)
# active_enhancer_df = active_enhancer_df.drop(active_enhancer_df.columns[[3, 7]],axis = 1)
# active_enhancer_df_1 = active_enhancer_df.iloc[:,0:3]
# active_enhancer_df_1.columns = ["chr", "start", "end"]
# active_enhancer_df_1["id"] = range(1, 1 + len(active_enhancer_df_1))
# active_enhancer_df_1["id"] = "AE_" + active_enhancer_df_1["id"].astype(str)
# active_enhancer_df_2 = active_enhancer_df.iloc[:,3:]
# active_enhancer_df_2.columns = ["chr", "start", "end"]
# active_enhancer_df_2["id"] = range(1, 1 + len(active_enhancer_df_2))
# active_enhancer_df_2["id"] = "AE_" + active_enhancer_df_2["id"].astype(str)
# active_enhancer_df = pd.concat([active_enhancer_df_1,active_enhancer_df_2])
# active_enhancer_df = active_enhancer_df.sort_values(by='id')
# active_enhancer = pybed.BedTool.from_dataframe(active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# active_enhancer = active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# active_enhancer_df.columns = ["chr", "name", "start", "end"]
# active_enhancer_df = active_enhancer_df[["chr", "start", "end"]]
# active_enhancer_df["annotation"] = "MCF10A_active_enhancer"
# active_enhancer_df = active_enhancer_df.drop_duplicates()


#####################################

# #H3K27me3 silencers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27me3 = H3K27me3_peak.subtract(Coding_promoter, A=True)
# H3K27me3_silencer = Distal_H3K27me3.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# H3K27me3_silencer = H3K27me3_silencer.subtract(Distal_H3K27ac, A=True)
# H3K27me3_silencer_df = pd.read_table(H3K27me3_silencer.fn,header=None)
# H3K27me3_silencer_df = H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# H3K27me3_silencer_df["annotation"] = "MCF10A_H3K27me3_silencer"
# H3K27me3_silencer_df = H3K27me3_silencer_df.drop_duplicates()

# #####################################

# #REST silencers

# # Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# # REST_silencer = REST_peak.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# # REST_silencer = REST_silencer.subtract(Distal_H3K27ac, A=True)
# # REST_silencer = REST_silencer.subtract(Distal_H3K27me3, A=True)
# # REST_silencer_df = pd.read_table(REST_silencer.fn,header=None)
# # REST_silencer_df = REST_silencer_df.iloc[:, [4,5,6,7]]
# # REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# # REST_silencer_df["annotation"] = "MCF10A_REST_silencer"
# # REST_silencer_df = REST_silencer_df.drop_duplicates()

# #####################################

# #Polycomb-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Polycomb_promoter = H3K4me3_peak_proximal.intersect(SUZ12_peak, wa=True, wb=True) 
# Polycomb_promoter_df = pd.read_table(Polycomb_promoter.fn,header=None)
# Polycomb_promoter_df = Polycomb_promoter_df.drop(Polycomb_promoter_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_df_1 = Polycomb_promoter_df.iloc[:,0:3]
# Polycomb_promoter_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_1["id"] = range(1, 1 + len(Polycomb_promoter_df_1))
# Polycomb_promoter_df_1["id"] = "AE_" + Polycomb_promoter_df_1["id"].astype(str)
# Polycomb_promoter_df_2 = Polycomb_promoter_df.iloc[:,3:]
# Polycomb_promoter_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_2["id"] = range(1, 1 + len(Polycomb_promoter_df_2))
# Polycomb_promoter_df_2["id"] = "AE_" + Polycomb_promoter_df_2["id"].astype(str)
# Polycomb_promoter_df = pd.concat([Polycomb_promoter_df_1,Polycomb_promoter_df_2])
# Polycomb_promoter_df = Polycomb_promoter_df.sort_values(by='id')
# Polycomb_promoter = pybed.BedTool.from_dataframe(Polycomb_promoter_df)
# Polycomb_promoter = Polycomb_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_df = Polycomb_promoter_df[["chr", "start", "end"]]
# Polycomb_promoter_df["annotation"] = "MCF10A_polycomb_promoter"
# Polycomb_promoter_df = Polycomb_promoter_df.drop_duplicates()

# #Active-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Active_promoter = H3K4me3_peak_proximal.intersect(H3K27ac_peak, wa=True, wb=True) 
# Active_promoter_df = pd.read_table(Active_promoter.fn,header=None)
# Active_promoter_df = Active_promoter_df.drop(Active_promoter_df.columns[[3, 7]],axis = 1)
# Active_promoter_df_1 = Active_promoter_df.iloc[:,0:3]
# Active_promoter_df_1.columns = ["chr", "start", "end"]
# Active_promoter_df_1["id"] = range(1, 1 + len(Active_promoter_df_1))
# Active_promoter_df_1["id"] = "AE_" + Active_promoter_df_1["id"].astype(str)
# Active_promoter_df_2 = Active_promoter_df.iloc[:,3:]
# Active_promoter_df_2.columns = ["chr", "start", "end"]
# Active_promoter_df_2["id"] = range(1, 1 + len(Active_promoter_df_2))
# Active_promoter_df_2["id"] = "AE_" + Active_promoter_df_2["id"].astype(str)
# Active_promoter_df = pd.concat([Active_promoter_df_1,Active_promoter_df_2])
# Active_promoter_df = Active_promoter_df.sort_values(by='id')
# Active_promoter = pybed.BedTool.from_dataframe(Active_promoter_df)
# Active_promoter = Active_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_df = Active_promoter_df[["chr", "start", "end"]]
# Active_promoter_df["annotation"] = "MCF10A_active_promoter"
# Active_promoter_df = Active_promoter_df.drop_duplicates()

# reg_elements = pd.concat([ active_enhancer_df, H3K27me3_silencer_df , Polycomb_promoter_df, Active_promoter_df ])
# display(reg_elements)

#active enhancer
Distal_ATAC_MCF10A = ATAC_peak_MCF10A.subtract(Coding_promoter, A=True)
Distal_H3K27ac_MCF10A = H3K27ac_peak_MCF10A.subtract(Coding_promoter, A=True)
MCF10A_active_enhancer = Distal_H3K27ac_MCF10A.intersect(Distal_ATAC_MCF10A, wb=True, f=0.1, r=True)
MCF10A_active_enhancer = MCF10A_active_enhancer.subtract(H3K27me3_peak_MCF10A, A=True)
MCF10A_active_enhancer_df = pd.read_table(MCF10A_active_enhancer.fn,header=None)
MCF10A_active_enhancer_df = MCF10A_active_enhancer_df.iloc[:, [4,5,6,7]]
MCF10A_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
MCF10A_active_enhancer_df["annotation"] = "MCF10A_active_enhancer"
MCF10A_active_enhancer_df = MCF10A_active_enhancer_df.drop_duplicates()
#
# MCF10A_active_enhancer = pybed.BedTool.from_dataframe(MCF10A_active_enhancer_df)
# Active_promoter_MCF10A_enh = MCF10A_active_enhancer.intersect(H3K4me3_peak_MCF10A, wa=True)
# Active_promoter_MCF10A_enh_df = pd.read_table(Active_promoter_MCF10A_enh.fn, header=None)
# Active_promoter_MCF10A_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_MCF10A_enh_df['annotation'] = 'MCF10A_active_promoter'
# MCF10A_active_enhancer = MCF10A_active_enhancer.subtract(H3K4me3_peak_MCF10A, A=True)
# MCF10A_active_enhancer_df = pd.read_table(MCF10A_active_enhancer.fn, header=None)
# MCF10A_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_MCF10A = ATAC_peak_MCF10A.subtract(Coding_promoter, A=True)
Distal_H3K27me3_MCF10A = H3K27me3_peak_MCF10A.subtract(Coding_promoter, A=True)
MCF10A_H3K27me3_silencer = Distal_H3K27me3_MCF10A.intersect(Distal_ATAC_MCF10A, wb=True, f=0.1, r=True)
MCF10A_H3K27me3_silencer = MCF10A_H3K27me3_silencer.subtract(Distal_H3K27ac_MCF10A, A=True)
MCF10A_H3K27me3_silencer_df = pd.read_table(MCF10A_H3K27me3_silencer.fn,header=None)
MCF10A_H3K27me3_silencer_df = MCF10A_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
MCF10A_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
MCF10A_H3K27me3_silencer_df["annotation"] = "MCF10A_H3K27me3_silencer"
MCF10A_H3K27me3_silencer_df = MCF10A_H3K27me3_silencer_df.drop_duplicates()
#
# MCF10A_H3K27me3_silencer = pybed.BedTool.from_dataframe(MCF10A_H3K27me3_silencer_df)
# # Active_promoter_MCF10A_sil = MCF10A_H3K27me3_silencer.intersect(H3K4me3_peak_MCF10A, wa=True)
# # Active_promoter_MCF10A_sil_df = pd.read_table(Active_promoter_MCF10A_sil.fn, header=None)
# # Active_promoter_MCF10A_sil_df.columns = ['chr', 'start', 'end', 'annotation']
# # Active_promoter_MCF10A_sil_df['annotation'] = 'MCF10A_active_promoter'
# MCF10A_H3K27me3_silencer = MCF10A_H3K27me3_silencer.subtract(H3K4me3_peak_MCF10A, A=True)
# MCF10A_H3K27me3_silencer_df = pd.read_table(MCF10A_H3K27me3_silencer.fn, header=None)
# MCF10A_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_MCF10A_proximal = ATAC_peak_MCF10A.intersect(Coding_promoter, wa=True)
Active_promoter_MCF10A = ATAC_peak_MCF10A_proximal.intersect(H3K27ac_peak_MCF10A, wa=True)
Active_promoter_MCF10A = Active_promoter_MCF10A.subtract(H3K27me3_peak_MCF10A, A=True)
Active_promoter_MCF10A_df = pd.read_table(Active_promoter_MCF10A.fn,header=None) 
Active_promoter_MCF10A_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_MCF10A_df["annotation"] = "MCF10A_active_promoter"
Active_promoter_MCF10A_df = Active_promoter_MCF10A_df.drop_duplicates()

#

# Active_promoter_MCF10A = pybed.BedTool.from_dataframe(Active_promoter_MCF10A_df)
# Active_enhancer_MCF10A_prom = Active_promoter_MCF10A.intersect(H3K4me1_peak_MCF10A, wa=True)
# Active_enhancer_MCF10A_prom_df = pd.read_table(Active_enhancer_MCF10A_prom.fn, header=None)
# Active_enhancer_MCF10A_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_MCF10A_prom_df['annotation'] = 'MCF10A_active_promoter'
# Active_promoter_MCF10A = Active_promoter_MCF10A.subtract(H3K4me1_peak_MCF10A, A=True)
# Active_promoter_MCF10A_df = pd.read_table(Active_promoter_MCF10A.fn, header=None)
# Active_promoter_MCF10A_df.columns = ['chr', 'start', 'end', 'annotation']

MCF10A_reg_elements = pd.concat([MCF10A_active_enhancer_df, MCF10A_H3K27me3_silencer_df , Active_promoter_MCF10A_df ])
MCF10A_reg_elements = MCF10A_reg_elements.drop_duplicates()
display(MCF10A_reg_elements)

MCF10A_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MCF10A_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/492932653.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_df['Annotation'] = "MCF10A_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/492932653.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_df['Annotation'] = "MCF10A_H3K27ac_peak"
# ...

# %%
display(Polycomb_promoter_df)
# Out:
#        chr     start       end                annotation
# 0     chr1   3568346   3569397  MCF10A_polycomb_promoter
# 1     chr1  31712061  31712960  MCF10A_polycomb_promoter
# 2    chr11  57282169  57283631  MCF10A_polycomb_promoter
# 3    chr11  57415303  57417215  MCF10A_polycomb_promoter
# 5    chr11  61347627  61349057  MCF10A_polycomb_promoter
# ..     ...       ...       ...                       ...
# 663  chr11  43599838  43601964  MCF10A_polycomb_promoter
# 664  chr11  43964058  43966533  MCF10A_polycomb_promoter
# 665  chr11  45686079  45687385  MCF10A_polycomb_promoter
# 666  chr11  57226257  57227658  MCF10A_polycomb_promoter
# 667  chr11  57226257  57228748  MCF10A_polycomb_promoter
#
# [512 rows x 4 columns]

# %% [markdown]
# # Add super-enhancers

# %%
MCF10A_reg_elements = pybed.BedTool.from_dataframe(MCF10A_reg_elements)
MCF10A_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/MCF10A/MCF10A_Gateway_SuperEnhancers.bed",header=None)
MCF10A_Super_enhancers_df = MCF10A_Super_enhancers_df.iloc[:, [0,1,2]]
MCF10A_Super_enhancers_df.columns = ["chr", "start", "end"]
MCF10A_Super_enhancers_df['Annotation'] = "MCF10A_super_enhancer"
MCF10A_Super_enhancers = pybed.BedTool.from_dataframe(MCF10A_Super_enhancers_df)
MCF10A_reg_elements = MCF10A_reg_elements.subtract(MCF10A_Super_enhancers)

MCF10A_reg_elements = pd.read_table(MCF10A_reg_elements.fn, header=None)
MCF10A_Super_enhancers = pd.read_table(MCF10A_Super_enhancers.fn, header=None)

MCF10A_reg_elements = pybed.BedTool.from_dataframe(pd.concat([MCF10A_reg_elements,MCF10A_Super_enhancers]))
MCF10A_reg_elements = MCF10A_reg_elements.sort()
MCF10A_reg_elements = pd.read_table(MCF10A_reg_elements.fn, header=None)
MCF10A_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MCF10A_reg_elements.txt", sep='\t', index=False, header=None)

# %%
#Call MCF7 reg-elements

pd.options.display.float_format = '{:,.0f}'.format

ATAC_peak = pd.read_table("/home/darragh/New/ATAC-seq/MCF7/naive/MCF7_peaks.preprocessed.bed")
ATAC_peak_df = ATAC_peak.iloc[:, [0,1,2]]
ATAC_peak_df.columns = ["chr", "start", "end"]
ATAC_peak_df['Annotation'] = "MCF7_ATAC_peak"
ATAC_peak = pybed.BedTool.from_dataframe(ATAC_peak_df)
ATAC_peak_MCF7 = ATAC_peak.sort()

H3K27ac_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF7/H3K27ac/results/Peak/MCF7_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_df = H3K27ac_peak.iloc[:, [0,1,2]]
H3K27ac_peak_df.columns = ["chr", "start", "end"]
H3K27ac_peak_df['Annotation'] = "MCF7_H3K27ac_peak"
H3K27ac_peak = pybed.BedTool.from_dataframe(H3K27ac_peak_df)
H3K27ac_peak_MCF7 = H3K27ac_peak.sort()

H3K27me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF7/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_df = H3K27me3_peak.iloc[:, [0,1,2]]
H3K27me3_peak_df.columns = ["chr", "start", "end"]
H3K27me3_peak_df['Annotation'] = "MCF7_H3K27me3_peak"
H3K27me3_peak = pybed.BedTool.from_dataframe(H3K27me3_peak_df)
H3K27me3_peak_MCF7 = H3K27me3_peak.sort()

H3K4me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF7/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_df = H3K4me3_peak.iloc[:, [0,1,2]]
H3K4me3_peak_df.columns = ["chr", "start", "end"]
H3K4me3_peak_df['Annotation'] = "MCF7_H3K4me3_peak"
H3K4me3_peak = pybed.BedTool.from_dataframe(H3K4me3_peak_df)
H3K4me3_peak_MCF7 = H3K4me3_peak.sort()

H3K4me1_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF7/H3K4me1/results/Peak/H3K4me1_peaks.preprocessed.bed")
H3K4me1_peak_df = H3K4me1_peak.iloc[:, [0,1,2]]
H3K4me1_peak_df.columns = ["chr", "start", "end"]
H3K4me1_peak_df['Annotation'] = "MCF7_H3K4me1_peak"
H3K4me1_peak = pybed.BedTool.from_dataframe(H3K4me1_peak_df)
H3K4me1_peak_MCF7 = H3K4me1_peak.sort()

SUZ12_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF7/SUZ12/SUZ12_peaks.preprocessed.bed")
SUZ12_peak_df = SUZ12_peak.iloc[:, [0,1,2]]
SUZ12_peak_df.columns = ["chr", "start", "end"]
SUZ12_peak_df['Annotation'] = "MCF7_SUZ12_peak"
SUZ12_peak = pybed.BedTool.from_dataframe(SUZ12_peak_df)
SUZ12_peak = SUZ12_peak.sort()

REST_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF7/REST/results/Peak/REST_peaks.preprocessed.bed")
REST_peak_df = REST_peak.iloc[:, [0,1,2]]
REST_peak_df.columns = ["chr", "start", "end"]
REST_peak_df['Annotation'] = "MCF7_REST_peak"
REST_peak = pybed.BedTool.from_dataframe(REST_peak_df)
REST_peak = REST_peak.sort()

###########################################

#Active-enhancers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27ac = H3K27ac_peak.subtract(Coding_promoter, A=True)
# active_enhancer = Distal_H3K27ac.intersect(Distal_ATAC, wa=True, wb=True, f=0.1, r=True)
# active_enhancer_df = pd.read_table(active_enhancer.fn,header=None)
# active_enhancer_df = active_enhancer_df.drop(active_enhancer_df.columns[[3, 7]],axis = 1)
# active_enhancer_df_1 = active_enhancer_df.iloc[:,0:3]
# active_enhancer_df_1.columns = ["chr", "start", "end"]
# active_enhancer_df_1["id"] = range(1, 1 + len(active_enhancer_df_1))
# active_enhancer_df_1["id"] = "AE_" + active_enhancer_df_1["id"].astype(str)
# active_enhancer_df_2 = active_enhancer_df.iloc[:,3:]
# active_enhancer_df_2.columns = ["chr", "start", "end"]
# active_enhancer_df_2["id"] = range(1, 1 + len(active_enhancer_df_2))
# active_enhancer_df_2["id"] = "AE_" + active_enhancer_df_2["id"].astype(str)
# active_enhancer_df = pd.concat([active_enhancer_df_1,active_enhancer_df_2])
# active_enhancer_df = active_enhancer_df.sort_values(by='id')
# active_enhancer = pybed.BedTool.from_dataframe(active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# active_enhancer = active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# active_enhancer_df.columns = ["chr", "name", "start", "end"]
# active_enhancer_df = active_enhancer_df[["chr", "start", "end"]]
# active_enhancer_df["annotation"] = "MCF7_active_enhancer"
# active_enhancer_df = active_enhancer_df.drop_duplicates()


# #####################################

# #H3K27me3 silencers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27me3 = H3K27me3_peak.subtract(Coding_promoter, A=True)
# H3K27me3_silencer = Distal_H3K27me3.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# H3K27me3_silencer = H3K27me3_silencer.subtract(Distal_H3K27ac, A=True)
# H3K27me3_silencer_df = pd.read_table(H3K27me3_silencer.fn,header=None)
# H3K27me3_silencer_df = H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# H3K27me3_silencer_df["annotation"] = "MCF7_H3K27me3_silencer"
# H3K27me3_silencer_df = H3K27me3_silencer_df.drop_duplicates()
# display(H3K27me3_silencer_df)

#####################################

#REST silencers

# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# REST_silencer = REST_peak.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27ac, A=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27me3, A=True)
# REST_silencer_df = pd.read_table(REST_silencer.fn,header=None)
# REST_silencer_df = REST_silencer_df.iloc[:, [4,5,6,7]]
# REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# REST_silencer_df["annotation"] = "MCF7_REST_silencer"
# REST_silencer_df = REST_silencer_df.drop_duplicates()

#####################################

# #Polycomb-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Polycomb_promoter = H3K4me3_peak_proximal.intersect(SUZ12_peak, wa=True, wb=True) 
# Polycomb_promoter_df = pd.read_table(Polycomb_promoter.fn,header=None)
# Polycomb_promoter_df = Polycomb_promoter_df.drop(Polycomb_promoter_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_df_1 = Polycomb_promoter_df.iloc[:,0:3]
# Polycomb_promoter_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_1["id"] = range(1, 1 + len(Polycomb_promoter_df_1))
# Polycomb_promoter_df_1["id"] = "AE_" + Polycomb_promoter_df_1["id"].astype(str)
# Polycomb_promoter_df_2 = Polycomb_promoter_df.iloc[:,3:]
# Polycomb_promoter_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_2["id"] = range(1, 1 + len(Polycomb_promoter_df_2))
# Polycomb_promoter_df_2["id"] = "AE_" + Polycomb_promoter_df_2["id"].astype(str)
# Polycomb_promoter_df = pd.concat([Polycomb_promoter_df_1,Polycomb_promoter_df_2])
# Polycomb_promoter_df = Polycomb_promoter_df.sort_values(by='id')
# Polycomb_promoter = pybed.BedTool.from_dataframe(Polycomb_promoter_df)
# Polycomb_promoter = Polycomb_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_df = Polycomb_promoter_df[["chr", "start", "end"]]
# Polycomb_promoter_df["annotation"] = "MCF7_polycomb_promoter"
# Polycomb_promoter_df = Polycomb_promoter_df.drop_duplicates()

# #Active-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Active_promoter = H3K4me3_peak_proximal.intersect(H3K27ac_peak, wa=True, wb=True) 
# Active_promoter_df = pd.read_table(Active_promoter.fn,header=None)
# Active_promoter_df = Active_promoter_df.drop(Active_promoter_df.columns[[3, 7]],axis = 1)
# Active_promoter_df_1 = Active_promoter_df.iloc[:,0:3]
# Active_promoter_df_1.columns = ["chr", "start", "end"]
# Active_promoter_df_1["id"] = range(1, 1 + len(Active_promoter_df_1))
# Active_promoter_df_1["id"] = "AE_" + Active_promoter_df_1["id"].astype(str)
# Active_promoter_df_2 = Active_promoter_df.iloc[:,3:]
# Active_promoter_df_2.columns = ["chr", "start", "end"]
# Active_promoter_df_2["id"] = range(1, 1 + len(Active_promoter_df_2))
# Active_promoter_df_2["id"] = "AE_" + Active_promoter_df_2["id"].astype(str)
# Active_promoter_df = pd.concat([Active_promoter_df_1,Active_promoter_df_2])
# Active_promoter_df = Active_promoter_df.sort_values(by='id')
# Active_promoter = pybed.BedTool.from_dataframe(Active_promoter_df)
# Active_promoter = Active_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_df = Active_promoter_df[["chr", "start", "end"]]
# Active_promoter_df["annotation"] = "MCF7_active_promoter"
# Active_promoter_df = Active_promoter_df.drop_duplicates()


# reg_elements = pd.concat([ active_enhancer_df, H3K27me3_silencer_df , Polycomb_promoter_df, Active_promoter_df ])
# display(reg_elements)

#active enhancer
Distal_ATAC_MCF7 = ATAC_peak_MCF7.subtract(Coding_promoter, A=True)
Distal_H3K27ac_MCF7 = H3K27ac_peak_MCF7.subtract(Coding_promoter, A=True)
MCF7_active_enhancer = Distal_H3K27ac_MCF7.intersect(Distal_ATAC_MCF7, wb=True, f=0.1, r=True)
MCF7_active_enhancer = MCF7_active_enhancer.subtract(H3K27me3_peak_MCF7, A=True)
MCF7_active_enhancer_df = pd.read_table(MCF7_active_enhancer.fn,header=None)
MCF7_active_enhancer_df = MCF7_active_enhancer_df.iloc[:, [4,5,6,7]]
MCF7_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
MCF7_active_enhancer_df["annotation"] = "MCF7_active_enhancer"
MCF7_active_enhancer_df = MCF7_active_enhancer_df.drop_duplicates()
#
# MCF7_active_enhancer = pybed.BedTool.from_dataframe(MCF7_active_enhancer_df)
# Active_promoter_MCF7_enh = MCF7_active_enhancer.intersect(H3K4me3_peak_MCF7, wa=True)
# Active_promoter_MCF7_enh_df = pd.read_table(Active_promoter_MCF7_enh.fn, header=None)
# Active_promoter_MCF7_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_MCF7_enh_df['annotation'] = 'MCF7_active_promoter'
# MCF7_active_enhancer = MCF7_active_enhancer.subtract(H3K4me3_peak_MCF7, A=True)
# MCF7_active_enhancer_df = pd.read_table(MCF7_active_enhancer.fn, header=None)
# MCF7_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_MCF7 = ATAC_peak_MCF7.subtract(Coding_promoter, A=True)
Distal_H3K27me3_MCF7 = H3K27me3_peak_MCF7.subtract(Coding_promoter, A=True)
MCF7_H3K27me3_silencer = Distal_H3K27me3_MCF7.intersect(Distal_ATAC_MCF7, wb=True, f=0.1, r=True)
MCF7_H3K27me3_silencer = MCF7_H3K27me3_silencer.subtract(Distal_H3K27ac_MCF7, A=True)
MCF7_H3K27me3_silencer_df = pd.read_table(MCF7_H3K27me3_silencer.fn,header=None)
MCF7_H3K27me3_silencer_df = MCF7_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
MCF7_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
MCF7_H3K27me3_silencer_df["annotation"] = "MCF7_H3K27me3_silencer"
MCF7_H3K27me3_silencer_df = MCF7_H3K27me3_silencer_df.drop_duplicates()
#
# MCF7_H3K27me3_silencer = pybed.BedTool.from_dataframe(MCF7_H3K27me3_silencer_df)
# # Active_promoter_MCF7_sil = MCF7_H3K27me3_silencer.intersect(H3K4me3_peak_MCF7, wa=True)
# # Active_promoter_MCF7_sil_df = pd.read_table(Active_promoter_MCF7_sil.fn, header=None)
# # Active_promoter_MCF7_sil_df.columns = ['chr', 'start', 'end', 'annotation']
# # Active_promoter_MCF7_sil_df['annotation'] = 'MCF7_active_promoter'
# MCF7_H3K27me3_silencer = MCF7_H3K27me3_silencer.subtract(H3K4me3_peak_MCF7, A=True)
# MCF7_H3K27me3_silencer_df = pd.read_table(MCF7_H3K27me3_silencer.fn, header=None)
# MCF7_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_MCF7_proximal = ATAC_peak_MCF7.intersect(Coding_promoter, wa=True)
Active_promoter_MCF7 = ATAC_peak_MCF7_proximal.intersect(H3K27ac_peak_MCF7, wa=True)
Active_promoter_MCF7 = Active_promoter_MCF7.subtract(H3K27me3_peak_MCF7, A=True)
Active_promoter_MCF7_df = pd.read_table(Active_promoter_MCF7.fn,header=None) 
Active_promoter_MCF7_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_MCF7_df["annotation"] = "MCF7_active_promoter"
Active_promoter_MCF7_df = Active_promoter_MCF7_df.drop_duplicates()

#

# Active_promoter_MCF7 = pybed.BedTool.from_dataframe(Active_promoter_MCF7_df)
# Active_enhancer_MCF7_prom = Active_promoter_MCF7.intersect(H3K4me1_peak_MCF7, wa=True)
# Active_enhancer_MCF7_prom_df = pd.read_table(Active_enhancer_MCF7_prom.fn, header=None)
# Active_enhancer_MCF7_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_MCF7_prom_df['annotation'] = 'MCF7_active_promoter'
# Active_promoter_MCF7 = Active_promoter_MCF7.subtract(H3K4me1_peak_MCF7, A=True)
# Active_promoter_MCF7_df = pd.read_table(Active_promoter_MCF7.fn, header=None)
# Active_promoter_MCF7_df.columns = ['chr', 'start', 'end', 'annotation']

MCF7_reg_elements = pd.concat([MCF7_active_enhancer_df, MCF7_H3K27me3_silencer_df , Active_promoter_MCF7_df ])
MCF7_reg_elements = MCF7_reg_elements.drop_duplicates()
display(MCF7_reg_elements)

MCF7_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MCF7_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/2700650545.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_df['Annotation'] = "MCF7_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/2700650545.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_df['Annotation'] = "MCF7_H3K27ac_peak"
# ...

# %%
display(Polycomb_promoter_df)
# Out:
#        chr      start        end              annotation
# 0     chr1    4714431    4716507  MCF7_polycomb_promoter
# 1     chr1   61547132   61549686  MCF7_polycomb_promoter
# 2     chr1  226736042  226737378  MCF7_polycomb_promoter
# 3     chr4  105411664  105413357  MCF7_polycomb_promoter
# 5     chr4  105415845  105416920  MCF7_polycomb_promoter
# ...    ...        ...        ...                     ...
# 1468  chr1  220701000  220703353  MCF7_polycomb_promoter
# 1471  chr4   93226284   93227534  MCF7_polycomb_promoter
# 1473  chr4   95678110   95681074  MCF7_polycomb_promoter
# 1475  chr4   96468370   96472144  MCF7_polycomb_promoter
# 1477  chr4   99578290   99580711  MCF7_polycomb_promoter
#
# [967 rows x 4 columns]

# %% [markdown]
# # Add super-enhancers

# %%
MCF7_reg_elements = pybed.BedTool.from_dataframe(MCF7_reg_elements)
MCF7_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/MCF7/MCF7_Gateway_SuperEnhancers.bed",header=None)
MCF7_Super_enhancers_df = MCF7_Super_enhancers_df.iloc[:, [0,1,2]]
MCF7_Super_enhancers_df.columns = ["chr", "start", "end"]
MCF7_Super_enhancers_df['Annotation'] = "MCF7_super_enhancer"
MCF7_Super_enhancers = pybed.BedTool.from_dataframe(MCF7_Super_enhancers_df)
MCF7_reg_elements = MCF7_reg_elements.subtract(MCF7_Super_enhancers)

MCF7_reg_elements = pd.read_table(MCF7_reg_elements.fn, header=None)
MCF7_Super_enhancers = pd.read_table(MCF7_Super_enhancers.fn, header=None)

MCF7_reg_elements = pybed.BedTool.from_dataframe(pd.concat([MCF7_reg_elements,MCF7_Super_enhancers]))
MCF7_reg_elements = MCF7_reg_elements.sort()
MCF7_reg_elements = pd.read_table(MCF7_reg_elements.fn, header=None)
MCF7_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MCF7_reg_elements.txt", sep='\t', index=False, header=None)

# %%
#Call T47D reg-elements

pd.options.display.float_format = '{:,.0f}'.format

ATAC_peak = pd.read_table("/home/darragh/New/ATAC-seq/T47D/naive/T47D_peaks.preprocessed.bed")
ATAC_peak_df = ATAC_peak.iloc[:, [0,1,2]]
ATAC_peak_df.columns = ["chr", "start", "end"]
ATAC_peak_df['Annotation'] = "T47D_ATAC_peak"
ATAC_peak = pybed.BedTool.from_dataframe(ATAC_peak_df)
ATAC_peak_T47D = ATAC_peak.sort()

H3K27ac_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/H3K27ac/results/Peak/H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_df = H3K27ac_peak.iloc[:, [0,1,2]]
H3K27ac_peak_df.columns = ["chr", "start", "end"]
H3K27ac_peak_df['Annotation'] = "T47D_H3K27ac_peak"
H3K27ac_peak = pybed.BedTool.from_dataframe(H3K27ac_peak_df)
H3K27ac_peak_T47D = H3K27ac_peak.sort()

H3K27me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_df = H3K27me3_peak.iloc[:, [0,1,2]]
H3K27me3_peak_df.columns = ["chr", "start", "end"]
H3K27me3_peak_df['Annotation'] = "T47D_H3K27me3_peak"
H3K27me3_peak = pybed.BedTool.from_dataframe(H3K27me3_peak_df)
H3K27me3_peak_T47D = H3K27me3_peak.sort()

H3K4me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MCF7/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_df = H3K4me3_peak.iloc[:, [0,1,2]]
H3K4me3_peak_df.columns = ["chr", "start", "end"]
H3K4me3_peak_df['Annotation'] = "T47D_H3K4me3_peak"
H3K4me3_peak = pybed.BedTool.from_dataframe(H3K4me3_peak_df)
H3K4me3_peak = H3K4me3_peak.sort()

# SUZ12_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/SUZ12/SUZ12_peaks.preprocessed.bed")
# SUZ12_peak_df = SUZ12_peak.iloc[:, [0,1,2]]
# SUZ12_peak_df.columns = ["chr", "start", "end"]
# SUZ12_peak_df['Annotation'] = "T47D_SUZ12_peak"
# SUZ12_peak = pybed.BedTool.from_dataframe(SUZ12_peak_df)
# SUZ12_peak = SUZ12_peak.sort()

# REST_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/REST/results/Peak/REST_peaks.preprocessed.bed")
# REST_peak_df = REST_peak.iloc[:, [0,1,2]]
# REST_peak_df.columns = ["chr", "start", "end"]
# REST_peak_df['Annotation'] = "T47D_REST_peak"
# REST_peak = pybed.BedTool.from_dataframe(REST_peak_df)
# REST_peak = REST_peak.sort()

###########################################

# #Active-enhancers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27ac = H3K27ac_peak.subtract(Coding_promoter, A=True)
# active_enhancer = Distal_H3K27ac.intersect(Distal_ATAC, wa=True, wb=True, f=0.1, r=True)
# active_enhancer_df = pd.read_table(active_enhancer.fn,header=None)
# active_enhancer_df = active_enhancer_df.drop(active_enhancer_df.columns[[3, 7]],axis = 1)
# active_enhancer_df_1 = active_enhancer_df.iloc[:,0:3]
# active_enhancer_df_1.columns = ["chr", "start", "end"]
# active_enhancer_df_1["id"] = range(1, 1 + len(active_enhancer_df_1))
# active_enhancer_df_1["id"] = "AE_" + active_enhancer_df_1["id"].astype(str)
# active_enhancer_df_2 = active_enhancer_df.iloc[:,3:]
# active_enhancer_df_2.columns = ["chr", "start", "end"]
# active_enhancer_df_2["id"] = range(1, 1 + len(active_enhancer_df_2))
# active_enhancer_df_2["id"] = "AE_" + active_enhancer_df_2["id"].astype(str)
# active_enhancer_df = pd.concat([active_enhancer_df_1,active_enhancer_df_2])
# active_enhancer_df = active_enhancer_df.sort_values(by='id')
# active_enhancer = pybed.BedTool.from_dataframe(active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# active_enhancer = active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# active_enhancer_df.columns = ["chr", "name", "start", "end"]
# active_enhancer_df = active_enhancer_df[["chr", "start", "end"]]
# active_enhancer_df["annotation"] = "T47D_active_enhancer"
# active_enhancer_df = active_enhancer_df.drop_duplicates()


#####################################

# #H3K27me3 silencers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27me3 = H3K27me3_peak.subtract(Coding_promoter, A=True)
# H3K27me3_silencer = Distal_H3K27me3.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# H3K27me3_silencer = H3K27me3_silencer.subtract(Distal_H3K27ac, A=True)
# H3K27me3_silencer_df = pd.read_table(H3K27me3_silencer.fn,header=None)
# H3K27me3_silencer_df = H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# H3K27me3_silencer_df["annotation"] = "T47D_H3K27me3_silencer"
# H3K27me3_silencer_df = H3K27me3_silencer_df.drop_duplicates()

#####################################

#REST silencers

# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# REST_silencer = REST_peak.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27ac, A=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27me3, A=True)
# REST_silencer_df = pd.read_table(REST_silencer.fn,header=None)
# REST_silencer_df = REST_silencer_df.iloc[:, [4,5,6,7]]
# REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# REST_silencer_df["annotation"] = "T47D_REST_silencer"
# REST_silencer_df = REST_silencer_df.drop_duplicates()

#####################################

# #Polycomb-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Polycomb_promoter = H3K4me3_peak_proximal.intersect(SUZ12_peak, wa=True, wb=True) 
# Polycomb_promoter_df = pd.read_table(Polycomb_promoter.fn,header=None)
# Polycomb_promoter_df = Polycomb_promoter_df.drop(Polycomb_promoter_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_df_1 = Polycomb_promoter_df.iloc[:,0:3]
# Polycomb_promoter_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_1["id"] = range(1, 1 + len(Polycomb_promoter_df_1))
# Polycomb_promoter_df_1["id"] = "AE_" + Polycomb_promoter_df_1["id"].astype(str)
# Polycomb_promoter_df_2 = Polycomb_promoter_df.iloc[:,3:]
# Polycomb_promoter_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_2["id"] = range(1, 1 + len(Polycomb_promoter_df_2))
# Polycomb_promoter_df_2["id"] = "AE_" + Polycomb_promoter_df_2["id"].astype(str)
# Polycomb_promoter_df = pd.concat([Polycomb_promoter_df_1,Polycomb_promoter_df_2])
# Polycomb_promoter_df = Polycomb_promoter_df.sort_values(by='id')
# Polycomb_promoter = pybed.BedTool.from_dataframe(Polycomb_promoter_df)
# Polycomb_promoter = Polycomb_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_df = Polycomb_promoter_df[["chr", "start", "end"]]
# Polycomb_promoter_df["annotation"] = "T47D_polycomb_promoter"
# Polycomb_promoter_df = Polycomb_promoter_df.drop_duplicates()

# #Active-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Active_promoter = H3K4me3_peak_proximal.intersect(H3K27ac_peak, wa=True, wb=True) 
# Active_promoter_df = pd.read_table(Active_promoter.fn,header=None)
# Active_promoter_df = Active_promoter_df.drop(Active_promoter_df.columns[[3, 7]],axis = 1)
# Active_promoter_df_1 = Active_promoter_df.iloc[:,0:3]
# Active_promoter_df_1.columns = ["chr", "start", "end"]
# Active_promoter_df_1["id"] = range(1, 1 + len(Active_promoter_df_1))
# Active_promoter_df_1["id"] = "AE_" + Active_promoter_df_1["id"].astype(str)
# Active_promoter_df_2 = Active_promoter_df.iloc[:,3:]
# Active_promoter_df_2.columns = ["chr", "start", "end"]
# Active_promoter_df_2["id"] = range(1, 1 + len(Active_promoter_df_2))
# Active_promoter_df_2["id"] = "AE_" + Active_promoter_df_2["id"].astype(str)
# Active_promoter_df = pd.concat([Active_promoter_df_1,Active_promoter_df_2])
# Active_promoter_df = Active_promoter_df.sort_values(by='id')
# Active_promoter = pybed.BedTool.from_dataframe(Active_promoter_df)
# Active_promoter = Active_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_df = Active_promoter_df[["chr", "start", "end"]]
# Active_promoter_df["annotation"] = "T47D_active_promoter"
# Active_promoter_df = Active_promoter_df.drop_duplicates()

# reg_elements = pd.concat([ active_enhancer_df, H3K27me3_silencer_df , Active_promoter_df ])
# display(reg_elements)


#active enhancer
Distal_ATAC_T47D = ATAC_peak_T47D.subtract(Coding_promoter, A=True)
Distal_H3K27ac_T47D = H3K27ac_peak_T47D.subtract(Coding_promoter, A=True)
T47D_active_enhancer = Distal_H3K27ac_T47D.intersect(Distal_ATAC_T47D, wb=True, f=0.1, r=True)
T47D_active_enhancer = T47D_active_enhancer.subtract(H3K27me3_peak_T47D, A=True)
T47D_active_enhancer_df = pd.read_table(T47D_active_enhancer.fn,header=None)
T47D_active_enhancer_df = T47D_active_enhancer_df.iloc[:, [4,5,6,7]]
T47D_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
T47D_active_enhancer_df["annotation"] = "T47D_active_enhancer"
T47D_active_enhancer_df = T47D_active_enhancer_df.drop_duplicates()


#H3K27me3 silencer
Distal_ATAC_T47D = ATAC_peak_T47D.subtract(Coding_promoter, A=True)
Distal_H3K27me3_T47D = H3K27me3_peak_T47D.subtract(Coding_promoter, A=True)
T47D_H3K27me3_silencer = Distal_H3K27me3_T47D.intersect(Distal_ATAC_T47D, wb=True, f=0.1, r=True)
T47D_H3K27me3_silencer = T47D_H3K27me3_silencer.subtract(Distal_H3K27ac_T47D, A=True)
T47D_H3K27me3_silencer_df = pd.read_table(T47D_H3K27me3_silencer.fn,header=None)
T47D_H3K27me3_silencer_df = T47D_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
T47D_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
T47D_H3K27me3_silencer_df["annotation"] = "T47D_H3K27me3_silencer"
T47D_H3K27me3_silencer_df = T47D_H3K27me3_silencer_df.drop_duplicates()

#active promoter
ATAC_peak_T47D_proximal = ATAC_peak_T47D.intersect(Coding_promoter, wa=True)
Active_promoter_T47D = ATAC_peak_T47D_proximal.intersect(H3K27ac_peak_T47D, wa=True)
Active_promoter_T47D = Active_promoter_T47D.subtract(H3K27me3_peak_T47D, A=True)
Active_promoter_T47D_df = pd.read_table(Active_promoter_T47D.fn,header=None) 
Active_promoter_T47D_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_T47D_df["annotation"] = "T47D_active_promoter"
Active_promoter_T47D_df = Active_promoter_T47D_df.drop_duplicates()

T47D_reg_elements = pd.concat([ T47D_active_enhancer_df, T47D_H3K27me3_silencer_df , Active_promoter_T47D_df ])
display(T47D_reg_elements)

T47D_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/T47D_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_1591795/2858785765.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_df['Annotation'] = "T47D_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_1591795/2858785765.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_df['Annotation'] = "T47D_H3K27ac_peak"
# ...

# %%
display(active_enhancer_df)
# Out:
#         chr     start       end            annotation
# 0      chr1   1013935   1017114  T47D_active_enhancer
# 1      chr1   6445579   6445995  T47D_active_enhancer
# 2      chr1  42333958  42335224  T47D_active_enhancer
# 3     chr11  22306400  22306620  T47D_active_enhancer
# 4     chr11  22724269  22725208  T47D_active_enhancer
# ...     ...       ...       ...                   ...
# 6002  chr11  21573853  21575414  T47D_active_enhancer
# 6003  chr11  21696043  21696776  T47D_active_enhancer
# 6004  chr11  21774026  21775196  T47D_active_enhancer
# 6005  chr11  21774175  21775548  T47D_active_enhancer
# 6006  chr11  22042975  22043566  T47D_active_enhancer
#
# [5987 rows x 4 columns]

# %% [markdown]
# # Add super-enhancers

# %%
T47D_reg_elements = pybed.BedTool.from_dataframe(T47D_reg_elements)
T47D_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/T47D/T47D_Gateway_SuperEnhancers.bed",header=None)
T47D_Super_enhancers_df = T47D_Super_enhancers_df.iloc[:, [0,1,2]]
T47D_Super_enhancers_df.columns = ["chr", "start", "end"]
T47D_Super_enhancers_df['Annotation'] = "T47D_super_enhancer"
T47D_Super_enhancers = pybed.BedTool.from_dataframe(T47D_Super_enhancers_df)
T47D_reg_elements = T47D_reg_elements.subtract(T47D_Super_enhancers)

T47D_reg_elements = pd.read_table(T47D_reg_elements.fn, header=None)
T47D_Super_enhancers = pd.read_table(T47D_Super_enhancers.fn, header=None)

T47D_reg_elements = pybed.BedTool.from_dataframe(pd.concat([T47D_reg_elements,T47D_Super_enhancers]))
T47D_reg_elements = T47D_reg_elements.sort()
T47D_reg_elements = pd.read_table(T47D_reg_elements.fn, header=None)
T47D_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/T47D_reg_elements.txt", sep='\t', index=False, header=None)

# %%
#Call MDAMB361 reg-elements

pd.options.display.float_format = '{:,.0f}'.format

ATAC_peak = pd.read_table("/home/darragh/New/ATAC-seq/MDAMB361/naive/MDAMB361_peaks.preprocessed.bed")
ATAC_peak_df = ATAC_peak.iloc[:, [0,1,2]]
ATAC_peak_df.columns = ["chr", "start", "end"]
ATAC_peak_df['Annotation'] = "MDAMB361_ATAC_peak"
ATAC_peak = pybed.BedTool.from_dataframe(ATAC_peak_df)
ATAC_peak_MDAMB361 = ATAC_peak.sort()

H3K27ac_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB361/H3K27ac/results/Peak/H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_df = H3K27ac_peak.iloc[:, [0,1,2]]
H3K27ac_peak_df.columns = ["chr", "start", "end"]
H3K27ac_peak_df['Annotation'] = "MDAMB361_H3K27ac_peak"
H3K27ac_peak = pybed.BedTool.from_dataframe(H3K27ac_peak_df)
H3K27ac_peak_MDAMB361 = H3K27ac_peak.sort()

H3K27me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB361/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_df = H3K27me3_peak.iloc[:, [0,1,2]]
H3K27me3_peak_df.columns = ["chr", "start", "end"]
H3K27me3_peak_df['Annotation'] = "MDAMB361_H3K27me3_peak"
H3K27me3_peak = pybed.BedTool.from_dataframe(H3K27me3_peak_df)
H3K27me3_peak_MDAMB361 = H3K27me3_peak.sort()

H3K4me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB361/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_df = H3K4me3_peak.iloc[:, [0,1,2]]
H3K4me3_peak_df.columns = ["chr", "start", "end"]
H3K4me3_peak_df['Annotation'] = "MDAMB361_H3K4me3_peak"
H3K4me3_peak = pybed.BedTool.from_dataframe(H3K4me3_peak_df)
H3K4me3_peak_MDAMB361 = H3K4me3_peak.sort()

H3K4me1_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB361/H3K4me1/results/Peak/H3K4me1_peaks.preprocessed.bed")
H3K4me1_peak_df = H3K4me1_peak.iloc[:, [0,1,2]]
H3K4me1_peak_df.columns = ["chr", "start", "end"]
H3K4me1_peak_df['Annotation'] = "MDAMB361_H3K4me1_peak"
H3K4me1_peak = pybed.BedTool.from_dataframe(H3K4me1_peak_df)
H3K4me1_peak_MDAMB361 = H3K4me1_peak.sort()

# SUZ12_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/SUZ12/SUZ12_peaks.preprocessed.bed")
# SUZ12_peak_df = SUZ12_peak.iloc[:, [0,1,2]]
# SUZ12_peak_df.columns = ["chr", "start", "end"]
# SUZ12_peak_df['Annotation'] = "T47D_SUZ12_peak"
# SUZ12_peak = pybed.BedTool.from_dataframe(SUZ12_peak_df)
# SUZ12_peak = SUZ12_peak.sort()

# REST_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/REST/results/Peak/REST_peaks.preprocessed.bed")
# REST_peak_df = REST_peak.iloc[:, [0,1,2]]
# REST_peak_df.columns = ["chr", "start", "end"]
# REST_peak_df['Annotation'] = "T47D_REST_peak"
# REST_peak = pybed.BedTool.from_dataframe(REST_peak_df)
# REST_peak = REST_peak.sort()

###########################################

# #Active-enhancers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27ac = H3K27ac_peak.subtract(Coding_promoter, A=True)
# active_enhancer = Distal_H3K27ac.intersect(Distal_ATAC, wa=True, wb=True, f=0.1, r=True)
# active_enhancer_df = pd.read_table(active_enhancer.fn,header=None)
# active_enhancer_df = active_enhancer_df.drop(active_enhancer_df.columns[[3, 7]],axis = 1)
# active_enhancer_df_1 = active_enhancer_df.iloc[:,0:3]
# active_enhancer_df_1.columns = ["chr", "start", "end"]
# active_enhancer_df_1["id"] = range(1, 1 + len(active_enhancer_df_1))
# active_enhancer_df_1["id"] = "AE_" + active_enhancer_df_1["id"].astype(str)
# active_enhancer_df_2 = active_enhancer_df.iloc[:,3:]
# active_enhancer_df_2.columns = ["chr", "start", "end"]
# active_enhancer_df_2["id"] = range(1, 1 + len(active_enhancer_df_2))
# active_enhancer_df_2["id"] = "AE_" + active_enhancer_df_2["id"].astype(str)
# active_enhancer_df = pd.concat([active_enhancer_df_1,active_enhancer_df_2])
# active_enhancer_df = active_enhancer_df.sort_values(by='id')
# active_enhancer = pybed.BedTool.from_dataframe(active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# active_enhancer = active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# active_enhancer_df.columns = ["chr", "name", "start", "end"]
# active_enhancer_df = active_enhancer_df[["chr", "start", "end"]]
# active_enhancer_df["annotation"] = "MDAMB361_active_enhancer"
# active_enhancer_df = active_enhancer_df.drop_duplicates()


#####################################

# #H3K27me3 silencers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27me3 = H3K27me3_peak.subtract(Coding_promoter, A=True)
# H3K27me3_silencer = Distal_H3K27me3.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# H3K27me3_silencer = H3K27me3_silencer.subtract(Distal_H3K27ac, A=True)
# H3K27me3_silencer_df = pd.read_table(H3K27me3_silencer.fn,header=None)
# H3K27me3_silencer_df = H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# H3K27me3_silencer_df["annotation"] = "MDAMB361_H3K27me3_silencer"
# H3K27me3_silencer_df = H3K27me3_silencer_df.drop_duplicates()

#####################################

#REST silencers

# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# REST_silencer = REST_peak.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27ac, A=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27me3, A=True)
# REST_silencer_df = pd.read_table(REST_silencer.fn,header=None)
# REST_silencer_df = REST_silencer_df.iloc[:, [4,5,6,7]]
# REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# REST_silencer_df["annotation"] = "T47D_REST_silencer"
# REST_silencer_df = REST_silencer_df.drop_duplicates()

#####################################

# #Polycomb-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Polycomb_promoter = H3K4me3_peak_proximal.intersect(SUZ12_peak, wa=True, wb=True) 
# Polycomb_promoter_df = pd.read_table(Polycomb_promoter.fn,header=None)
# Polycomb_promoter_df = Polycomb_promoter_df.drop(Polycomb_promoter_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_df_1 = Polycomb_promoter_df.iloc[:,0:3]
# Polycomb_promoter_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_1["id"] = range(1, 1 + len(Polycomb_promoter_df_1))
# Polycomb_promoter_df_1["id"] = "AE_" + Polycomb_promoter_df_1["id"].astype(str)
# Polycomb_promoter_df_2 = Polycomb_promoter_df.iloc[:,3:]
# Polycomb_promoter_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_2["id"] = range(1, 1 + len(Polycomb_promoter_df_2))
# Polycomb_promoter_df_2["id"] = "AE_" + Polycomb_promoter_df_2["id"].astype(str)
# Polycomb_promoter_df = pd.concat([Polycomb_promoter_df_1,Polycomb_promoter_df_2])
# Polycomb_promoter_df = Polycomb_promoter_df.sort_values(by='id')
# Polycomb_promoter = pybed.BedTool.from_dataframe(Polycomb_promoter_df)
# Polycomb_promoter = Polycomb_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_df = Polycomb_promoter_df[["chr", "start", "end"]]
# Polycomb_promoter_df["annotation"] = "T47D_polycomb_promoter"
# Polycomb_promoter_df = Polycomb_promoter_df.drop_duplicates()

# #Active-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Active_promoter = H3K4me3_peak_proximal.intersect(H3K27ac_peak, wa=True, wb=True) 
# Active_promoter_df = pd.read_table(Active_promoter.fn,header=None)
# Active_promoter_df = Active_promoter_df.drop(Active_promoter_df.columns[[3, 7]],axis = 1)
# Active_promoter_df_1 = Active_promoter_df.iloc[:,0:3]
# Active_promoter_df_1.columns = ["chr", "start", "end"]
# Active_promoter_df_1["id"] = range(1, 1 + len(Active_promoter_df_1))
# Active_promoter_df_1["id"] = "AE_" + Active_promoter_df_1["id"].astype(str)
# Active_promoter_df_2 = Active_promoter_df.iloc[:,3:]
# Active_promoter_df_2.columns = ["chr", "start", "end"]
# Active_promoter_df_2["id"] = range(1, 1 + len(Active_promoter_df_2))
# Active_promoter_df_2["id"] = "AE_" + Active_promoter_df_2["id"].astype(str)
# Active_promoter_df = pd.concat([Active_promoter_df_1,Active_promoter_df_2])
# Active_promoter_df = Active_promoter_df.sort_values(by='id')
# Active_promoter = pybed.BedTool.from_dataframe(Active_promoter_df)
# Active_promoter = Active_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_df = Active_promoter_df[["chr", "start", "end"]]
# Active_promoter_df["annotation"] = "MDAMB361_active_promoter"
# Active_promoter_df = Active_promoter_df.drop_duplicates()

# reg_elements = pd.concat([ active_enhancer_df, H3K27me3_silencer_df , Active_promoter_df ])
# display(reg_elements)

#active enhancer
Distal_ATAC_MDAMB361 = ATAC_peak_MDAMB361.subtract(Coding_promoter, A=True)
Distal_H3K27ac_MDAMB361 = H3K27ac_peak_MDAMB361.subtract(Coding_promoter, A=True)
MDAMB361_active_enhancer = Distal_H3K27ac_MDAMB361.intersect(Distal_ATAC_MDAMB361, wb=True, f=0.1, r=True)
MDAMB361_active_enhancer = MDAMB361_active_enhancer.subtract(H3K27me3_peak_MDAMB361, A=True)
MDAMB361_active_enhancer_df = pd.read_table(MDAMB361_active_enhancer.fn,header=None)
MDAMB361_active_enhancer_df = MDAMB361_active_enhancer_df.iloc[:, [4,5,6,7]]
MDAMB361_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
MDAMB361_active_enhancer_df["annotation"] = "MDAMB361_active_enhancer"
MDAMB361_active_enhancer_df = MDAMB361_active_enhancer_df.drop_duplicates()
#
# MDAMB361_active_enhancer = pybed.BedTool.from_dataframe(MDAMB361_active_enhancer_df)
# Active_promoter_MDAMB361_enh = MDAMB361_active_enhancer.intersect(H3K4me3_peak_MDAMB361, wa=True)
# Active_promoter_MDAMB361_enh_df = pd.read_table(Active_promoter_MDAMB361_enh.fn, header=None)
# Active_promoter_MDAMB361_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_MDAMB361_enh_df['annotation'] = 'MDAMB361_active_promoter'
# MDAMB361_active_enhancer = MDAMB361_active_enhancer.subtract(H3K4me3_peak_MDAMB361, A=True)
# MDAMB361_active_enhancer_df = pd.read_table(MDAMB361_active_enhancer.fn, header=None)
# MDAMB361_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_MDAMB361 = ATAC_peak_MDAMB361.subtract(Coding_promoter, A=True)
Distal_H3K27me3_MDAMB361 = H3K27me3_peak_MDAMB361.subtract(Coding_promoter, A=True)
MDAMB361_H3K27me3_silencer = Distal_H3K27me3_MDAMB361.intersect(Distal_ATAC_MDAMB361, wb=True, f=0.1, r=True)
MDAMB361_H3K27me3_silencer = MDAMB361_H3K27me3_silencer.subtract(Distal_H3K27ac_MDAMB361, A=True)
MDAMB361_H3K27me3_silencer_df = pd.read_table(MDAMB361_H3K27me3_silencer.fn,header=None)
MDAMB361_H3K27me3_silencer_df = MDAMB361_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
MDAMB361_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
MDAMB361_H3K27me3_silencer_df["annotation"] = "MDAMB361_H3K27me3_silencer"
MDAMB361_H3K27me3_silencer_df = MDAMB361_H3K27me3_silencer_df.drop_duplicates()
#
# MDAMB361_H3K27me3_silencer = pybed.BedTool.from_dataframe(MDAMB361_H3K27me3_silencer_df)
# # Active_promoter_MDAMB361_sil = MDAMB361_H3K27me3_silencer.intersect(H3K4me3_peak_MDAMB361, wa=True)
# # Active_promoter_MDAMB361_sil_df = pd.read_table(Active_promoter_MDAMB361_sil.fn, header=None)
# # Active_promoter_MDAMB361_sil_df.columns = ['chr', 'start', 'end', 'annotation']
# # Active_promoter_MDAMB361_sil_df['annotation'] = 'MDAMB361_active_promoter'
# MDAMB361_H3K27me3_silencer = MDAMB361_H3K27me3_silencer.subtract(H3K4me3_peak_MDAMB361, A=True)
# MDAMB361_H3K27me3_silencer_df = pd.read_table(MDAMB361_H3K27me3_silencer.fn, header=None)
# MDAMB361_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_MDAMB361_proximal = ATAC_peak_MDAMB361.intersect(Coding_promoter, wa=True)
Active_promoter_MDAMB361 = ATAC_peak_MDAMB361_proximal.intersect(H3K27ac_peak_MDAMB361, wa=True)
Active_promoter_MDAMB361 = Active_promoter_MDAMB361.subtract(H3K27me3_peak_MDAMB361, A=True)
Active_promoter_MDAMB361_df = pd.read_table(Active_promoter_MDAMB361.fn,header=None) 
Active_promoter_MDAMB361_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_MDAMB361_df["annotation"] = "MDAMB361_active_promoter"
Active_promoter_MDAMB361_df = Active_promoter_MDAMB361_df.drop_duplicates()
#

# Active_promoter_MDAMB361 = pybed.BedTool.from_dataframe(Active_promoter_MDAMB361_df)
# Active_enhancer_MDAMB361_prom = Active_promoter_MDAMB361.intersect(H3K4me1_peak_MDAMB361, wa=True)
# Active_enhancer_MDAMB361_prom_df = pd.read_table(Active_enhancer_MDAMB361_prom.fn, header=None)
# Active_enhancer_MDAMB361_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_MDAMB361_prom_df['annotation'] = 'MDAMB361_active_promoter'
# Active_promoter_MDAMB361 = Active_promoter_MDAMB361.subtract(H3K4me1_peak_MDAMB361, A=True)
# Active_promoter_MDAMB361_df = pd.read_table(Active_promoter_MDAMB361.fn, header=None)
# Active_promoter_MDAMB361_df.columns = ['chr', 'start', 'end', 'annotation']

MDAMB361_reg_elements = pd.concat([MDAMB361_active_enhancer_df, MDAMB361_H3K27me3_silencer_df , Active_promoter_MDAMB361_df ])
MDAMB361_reg_elements = MDAMB361_reg_elements.drop_duplicates()
display(MDAMB361_reg_elements)

MDAMB361_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MDAMB361_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/3209106469.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_df['Annotation'] = "MDAMB361_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/3209106469.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_df['Annotation'] = "MDAMB361_H3K27ac_peak"
# ...

# %%
display(active_enhancer_df)
# Out:
#         chr      start        end                annotation
# 0      chr1     411844     412559  MDAMB361_active_enhancer
# 1      chr1    1013562    1016553  MDAMB361_active_enhancer
# 2      chr1    8931475    8931881  MDAMB361_active_enhancer
# 3      chr1  120285944  120287096  MDAMB361_active_enhancer
# 4      chr2   20312430   20315216  MDAMB361_active_enhancer
# ...     ...        ...        ...                       ...
# 21568  chr2   20208001   20209362  MDAMB361_active_enhancer
# 21569  chr2   20265921   20266539  MDAMB361_active_enhancer
# 21570  chr2   20270051   20273779  MDAMB361_active_enhancer
# 21571  chr2   20277231   20278071  MDAMB361_active_enhancer
# 21572  chr2   20293521   20294661  MDAMB361_active_enhancer
#
# [21307 rows x 4 columns]

# %%
#Call MDAMB231 reg-elements

pd.options.display.float_format = '{:,.0f}'.format

ATAC_peak = pd.read_table("/home/darragh/New/ATAC-seq/MDAMB231/naive/MDAMB231_peaks.preprocessed.bed")
ATAC_peak_df = ATAC_peak.iloc[:, [0,1,2]]
ATAC_peak_df.columns = ["chr", "start", "end"]
ATAC_peak_df['Annotation'] = "MDAMB231_ATAC_peak"
ATAC_peak = pybed.BedTool.from_dataframe(ATAC_peak_df)
ATAC_peak_MDAMB231 = ATAC_peak.sort()

H3K27ac_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB231/H3K27ac/results/Peak/MDAMB231_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_df = H3K27ac_peak.iloc[:, [0,1,2]]
H3K27ac_peak_df.columns = ["chr", "start", "end"]
H3K27ac_peak_df['Annotation'] = "MDAMB231_H3K27ac_peak"
H3K27ac_peak = pybed.BedTool.from_dataframe(H3K27ac_peak_df)
H3K27ac_peak_MDAMB231 = H3K27ac_peak.sort()

H3K27me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB231/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_df = H3K27me3_peak.iloc[:, [0,1,2]]
H3K27me3_peak_df.columns = ["chr", "start", "end"]
H3K27me3_peak_df['Annotation'] = "MDAMB231_H3K27me3_peak"
H3K27me3_peak = pybed.BedTool.from_dataframe(H3K27me3_peak_df)
H3K27me3_peak_MDAMB231 = H3K27me3_peak.sort()

H3K4me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB231/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_df = H3K4me3_peak.iloc[:, [0,1,2]]
H3K4me3_peak_df.columns = ["chr", "start", "end"]
H3K4me3_peak_df['Annotation'] = "MDAMB231_H3K4me3_peak"
H3K4me3_peak = pybed.BedTool.from_dataframe(H3K4me3_peak_df)
H3K4me3_peak_MDAMB231 = H3K4me3_peak.sort()


H3K4me1_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB231/H3K4me1/results/Peak/H3K4me1_peaks.preprocessed.bed")
H3K4me1_peak_df = H3K4me1_peak.iloc[:, [0,1,2]]
H3K4me1_peak_df.columns = ["chr", "start", "end"]
H3K4me1_peak_df['Annotation'] = "MDAMB231_H3K4me1_peak"
H3K4me1_peak = pybed.BedTool.from_dataframe(H3K4me1_peak_df)
H3K4me1_peak_MDAMB231 = H3K4me1_peak.sort()


# SUZ12_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/SUZ12/SUZ12_peaks.preprocessed.bed")
# SUZ12_peak_df = SUZ12_peak.iloc[:, [0,1,2]]
# SUZ12_peak_df.columns = ["chr", "start", "end"]
# SUZ12_peak_df['Annotation'] = "T47D_SUZ12_peak"
# SUZ12_peak = pybed.BedTool.from_dataframe(SUZ12_peak_df)
# SUZ12_peak = SUZ12_peak.sort()

# REST_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/REST/results/Peak/REST_peaks.preprocessed.bed")
# REST_peak_df = REST_peak.iloc[:, [0,1,2]]
# REST_peak_df.columns = ["chr", "start", "end"]
# REST_peak_df['Annotation'] = "T47D_REST_peak"
# REST_peak = pybed.BedTool.from_dataframe(REST_peak_df)
# REST_peak = REST_peak.sort()

###########################################

# #Active-enhancers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27ac = H3K27ac_peak.subtract(Coding_promoter, A=True)
# active_enhancer = Distal_H3K27ac.intersect(Distal_ATAC, wa=True, wb=True, f=0.1, r=True)
# active_enhancer_df = pd.read_table(active_enhancer.fn,header=None)
# active_enhancer_df = active_enhancer_df.drop(active_enhancer_df.columns[[3, 7]],axis = 1)
# active_enhancer_df_1 = active_enhancer_df.iloc[:,0:3]
# active_enhancer_df_1.columns = ["chr", "start", "end"]
# active_enhancer_df_1["id"] = range(1, 1 + len(active_enhancer_df_1))
# active_enhancer_df_1["id"] = "AE_" + active_enhancer_df_1["id"].astype(str)
# active_enhancer_df_2 = active_enhancer_df.iloc[:,3:]
# active_enhancer_df_2.columns = ["chr", "start", "end"]
# active_enhancer_df_2["id"] = range(1, 1 + len(active_enhancer_df_2))
# active_enhancer_df_2["id"] = "AE_" + active_enhancer_df_2["id"].astype(str)
# active_enhancer_df = pd.concat([active_enhancer_df_1,active_enhancer_df_2])
# active_enhancer_df = active_enhancer_df.sort_values(by='id')
# active_enhancer = pybed.BedTool.from_dataframe(active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# active_enhancer = active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# active_enhancer_df.columns = ["chr", "name", "start", "end"]
# active_enhancer_df = active_enhancer_df[["chr", "start", "end"]]
# active_enhancer_df["annotation"] = "MDAMB231_active_enhancer"
# active_enhancer_df = active_enhancer_df.drop_duplicates()


#####################################

# #H3K27me3 silencers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27me3 = H3K27me3_peak.subtract(Coding_promoter, A=True)
# H3K27me3_silencer = Distal_H3K27me3.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# H3K27me3_silencer = H3K27me3_silencer.subtract(Distal_H3K27ac, A=True)
# H3K27me3_silencer_df = pd.read_table(H3K27me3_silencer.fn,header=None)
# H3K27me3_silencer_df = H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# H3K27me3_silencer_df["annotation"] = "MDAMB231_H3K27me3_silencer"
# H3K27me3_silencer_df = H3K27me3_silencer_df.drop_duplicates()
# display(H3K27me3_silencer_df)

#####################################

#REST silencers

# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# REST_silencer = REST_peak.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27ac, A=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27me3, A=True)
# REST_silencer_df = pd.read_table(REST_silencer.fn,header=None)
# REST_silencer_df = REST_silencer_df.iloc[:, [4,5,6,7]]
# REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# REST_silencer_df["annotation"] = "T47D_REST_silencer"
# REST_silencer_df = REST_silencer_df.drop_duplicates()

#####################################

# #Polycomb-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Polycomb_promoter = H3K4me3_peak_proximal.intersect(SUZ12_peak, wa=True, wb=True) 
# Polycomb_promoter_df = pd.read_table(Polycomb_promoter.fn,header=None)
# Polycomb_promoter_df = Polycomb_promoter_df.drop(Polycomb_promoter_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_df_1 = Polycomb_promoter_df.iloc[:,0:3]
# Polycomb_promoter_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_1["id"] = range(1, 1 + len(Polycomb_promoter_df_1))
# Polycomb_promoter_df_1["id"] = "AE_" + Polycomb_promoter_df_1["id"].astype(str)
# Polycomb_promoter_df_2 = Polycomb_promoter_df.iloc[:,3:]
# Polycomb_promoter_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_2["id"] = range(1, 1 + len(Polycomb_promoter_df_2))
# Polycomb_promoter_df_2["id"] = "AE_" + Polycomb_promoter_df_2["id"].astype(str)
# Polycomb_promoter_df = pd.concat([Polycomb_promoter_df_1,Polycomb_promoter_df_2])
# Polycomb_promoter_df = Polycomb_promoter_df.sort_values(by='id')
# Polycomb_promoter = pybed.BedTool.from_dataframe(Polycomb_promoter_df)
# Polycomb_promoter = Polycomb_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_df = Polycomb_promoter_df[["chr", "start", "end"]]
# Polycomb_promoter_df["annotation"] = "T47D_polycomb_promoter"
# Polycomb_promoter_df = Polycomb_promoter_df.drop_duplicates()

# #Active-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Active_promoter = H3K4me3_peak_proximal.intersect(H3K27ac_peak, wa=True, wb=True) 
# Active_promoter_df = pd.read_table(Active_promoter.fn,header=None)
# Active_promoter_df = Active_promoter_df.drop(Active_promoter_df.columns[[3, 7]],axis = 1)
# Active_promoter_df_1 = Active_promoter_df.iloc[:,0:3]
# Active_promoter_df_1.columns = ["chr", "start", "end"]
# Active_promoter_df_1["id"] = range(1, 1 + len(Active_promoter_df_1))
# Active_promoter_df_1["id"] = "AE_" + Active_promoter_df_1["id"].astype(str)
# Active_promoter_df_2 = Active_promoter_df.iloc[:,3:]
# Active_promoter_df_2.columns = ["chr", "start", "end"]
# Active_promoter_df_2["id"] = range(1, 1 + len(Active_promoter_df_2))
# Active_promoter_df_2["id"] = "AE_" + Active_promoter_df_2["id"].astype(str)
# Active_promoter_df = pd.concat([Active_promoter_df_1,Active_promoter_df_2])
# Active_promoter_df = Active_promoter_df.sort_values(by='id')
# Active_promoter = pybed.BedTool.from_dataframe(Active_promoter_df)
# Active_promoter = Active_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_df = Active_promoter_df[["chr", "start", "end"]]
# Active_promoter_df["annotation"] = "MDAMB231_active_promoter"
# Active_promoter_df = Active_promoter_df.drop_duplicates()

# reg_elements = pd.concat([ active_enhancer_df, H3K27me3_silencer_df , Active_promoter_df ])
# display(reg_elements)

#active enhancer
Distal_ATAC_MDAMB231 = ATAC_peak_MDAMB231.subtract(Coding_promoter, A=True)
Distal_H3K27ac_MDAMB231 = H3K27ac_peak_MDAMB231.subtract(Coding_promoter, A=True)
MDAMB231_active_enhancer = Distal_H3K27ac_MDAMB231.intersect(Distal_ATAC_MDAMB231, wb=True, f=0.1, r=True)
MDAMB231_active_enhancer = MDAMB231_active_enhancer.subtract(H3K27me3_peak_MDAMB231, A=True)
MDAMB231_active_enhancer_df = pd.read_table(MDAMB231_active_enhancer.fn,header=None)
MDAMB231_active_enhancer_df = MDAMB231_active_enhancer_df.iloc[:, [4,5,6,7]]
MDAMB231_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
MDAMB231_active_enhancer_df["annotation"] = "MDAMB231_active_enhancer"
MDAMB231_active_enhancer_df = MDAMB231_active_enhancer_df.drop_duplicates()
#
# MDAMB231_active_enhancer = pybed.BedTool.from_dataframe(MDAMB231_active_enhancer_df)
# Active_promoter_MDAMB231_enh = MDAMB231_active_enhancer.intersect(H3K4me3_peak_MDAMB231, wa=True)
# Active_promoter_MDAMB231_enh_df = pd.read_table(Active_promoter_MDAMB231_enh.fn, header=None)
# Active_promoter_MDAMB231_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_MDAMB231_enh_df['annotation'] = 'MDAMB231_active_promoter'
# MDAMB231_active_enhancer = MDAMB231_active_enhancer.subtract(H3K4me3_peak_MDAMB231, A=True)
# MDAMB231_active_enhancer_df = pd.read_table(MDAMB231_active_enhancer.fn, header=None)
# MDAMB231_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_MDAMB231 = ATAC_peak_MDAMB231.subtract(Coding_promoter, A=True)
Distal_H3K27me3_MDAMB231 = H3K27me3_peak_MDAMB231.subtract(Coding_promoter, A=True)
MDAMB231_H3K27me3_silencer = Distal_H3K27me3_MDAMB231.intersect(Distal_ATAC_MDAMB231, wb=True, f=0.1, r=True)
MDAMB231_H3K27me3_silencer = MDAMB231_H3K27me3_silencer.subtract(Distal_H3K27ac_MDAMB231, A=True)
MDAMB231_H3K27me3_silencer_df = pd.read_table(MDAMB231_H3K27me3_silencer.fn,header=None)
MDAMB231_H3K27me3_silencer_df = MDAMB231_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
MDAMB231_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
MDAMB231_H3K27me3_silencer_df["annotation"] = "MDAMB231_H3K27me3_silencer"
MDAMB231_H3K27me3_silencer_df = MDAMB231_H3K27me3_silencer_df.drop_duplicates()
#
# MDAMB231_H3K27me3_silencer = pybed.BedTool.from_dataframe(MDAMB231_H3K27me3_silencer_df)
# # Active_promoter_MDAMB231_sil = MDAMB231_H3K27me3_silencer.intersect(H3K4me3_peak_MDAMB231, wa=True)
# # Active_promoter_MDAMB231_sil_df = pd.read_table(Active_promoter_MDAMB231_sil.fn, header=None)
# # Active_promoter_MDAMB231_sil_df.columns = ['chr', 'start', 'end', 'annotation']
# # Active_promoter_MDAMB231_sil_df['annotation'] = 'MDAMB231_active_promoter'
# MDAMB231_H3K27me3_silencer = MDAMB231_H3K27me3_silencer.subtract(H3K4me3_peak_MDAMB231, A=True)
# MDAMB231_H3K27me3_silencer_df = pd.read_table(MDAMB231_H3K27me3_silencer.fn, header=None)
# MDAMB231_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_MDAMB231_proximal = ATAC_peak_MDAMB231.intersect(Coding_promoter, wa=True)
Active_promoter_MDAMB231 = ATAC_peak_MDAMB231_proximal.intersect(H3K27ac_peak_MDAMB231, wa=True)
Active_promoter_MDAMB231 = Active_promoter_MDAMB231.subtract(H3K27me3_peak_MDAMB231, A=True)
Active_promoter_MDAMB231_df = pd.read_table(Active_promoter_MDAMB231.fn,header=None) 
Active_promoter_MDAMB231_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_MDAMB231_df["annotation"] = "MDAMB231_active_promoter"
Active_promoter_MDAMB231_df = Active_promoter_MDAMB231_df.drop_duplicates()

#

# Active_promoter_MDAMB231 = pybed.BedTool.from_dataframe(Active_promoter_MDAMB231_df)
# Active_enhancer_MDAMB231_prom = Active_promoter_MDAMB231.intersect(H3K4me1_peak_MDAMB231, wa=True)
# Active_enhancer_MDAMB231_prom_df = pd.read_table(Active_enhancer_MDAMB231_prom.fn, header=None)
# Active_enhancer_MDAMB231_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_MDAMB231_prom_df['annotation'] = 'MDAMB231_active_promoter'
# Active_promoter_MDAMB231 = Active_promoter_MDAMB231.subtract(H3K4me1_peak_MDAMB231, A=True)
# Active_promoter_MDAMB231_df = pd.read_table(Active_promoter_MDAMB231.fn, header=None)
# Active_promoter_MDAMB231_df.columns = ['chr', 'start', 'end', 'annotation']

MDAMB231_reg_elements = pd.concat([MDAMB231_active_enhancer_df, MDAMB231_H3K27me3_silencer_df , Active_promoter_MDAMB231_df ])
MDAMB231_reg_elements = MDAMB231_reg_elements.drop_duplicates()
display(MDAMB231_reg_elements)

MDAMB231_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MDAMB231_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/243718191.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_df['Annotation'] = "MDAMB231_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/243718191.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_df['Annotation'] = "MDAMB231_H3K27ac_peak"
# ...

# %%
display(H3K27me3_silencer_df)
# Out:
#        chr      start        end                  annotation
# 0     chr1     416511     416769  MDAMB231_H3K27me3_silencer
# 1     chr1    1532381    1532911  MDAMB231_H3K27me3_silencer
# 2     chr1    2363129    2363958  MDAMB231_H3K27me3_silencer
# 3     chr1    3464691    3465293  MDAMB231_H3K27me3_silencer
# 4     chr1    4016574    4017145  MDAMB231_H3K27me3_silencer
# ...    ...        ...        ...                         ...
# 4758  chrX  152831596  152831884  MDAMB231_H3K27me3_silencer
# 4759  chrX  152901749  152902080  MDAMB231_H3K27me3_silencer
# 4760  chrX  152912253  152912753  MDAMB231_H3K27me3_silencer
# 4761  chrX  153425508  153425903  MDAMB231_H3K27me3_silencer
# 4762  chrX  153499401  153499641  MDAMB231_H3K27me3_silencer
#
# [4575 rows x 4 columns]

# %% [markdown]
# # Add super-enhancers

# %%
MDAMB231_reg_elements = pybed.BedTool.from_dataframe(MDAMB231_reg_elements)
MDAMB231_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/MDAMB231/MDAMB231_Gateway_SuperEnhancers.bed",header=None)
MDAMB231_Super_enhancers_df = MDAMB231_Super_enhancers_df.iloc[:, [0,1,2]]
MDAMB231_Super_enhancers_df.columns = ["chr", "start", "end"]
MDAMB231_Super_enhancers_df['Annotation'] = "MDAMB231_super_enhancer"
MDAMB231_Super_enhancers = pybed.BedTool.from_dataframe(MDAMB231_Super_enhancers_df)
MDAMB231_reg_elements = MDAMB231_reg_elements.subtract(MDAMB231_Super_enhancers)

MDAMB231_reg_elements = pd.read_table(MDAMB231_reg_elements.fn, header=None)
MDAMB231_Super_enhancers = pd.read_table(MDAMB231_Super_enhancers.fn, header=None)

MDAMB231_reg_elements = pybed.BedTool.from_dataframe(pd.concat([MDAMB231_reg_elements,MDAMB231_Super_enhancers]))
MDAMB231_reg_elements = MDAMB231_reg_elements.sort()
MDAMB231_reg_elements = pd.read_table(MDAMB231_reg_elements.fn, header=None)
MDAMB231_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MDAMB231_reg_elements.txt", sep='\t', index=False, header=None)

# %%
#Call MDAMB436 reg-elements

pd.options.display.float_format = '{:,.0f}'.format

ATAC_peak = pd.read_table("/home/darragh/New/ATAC-seq/MDAMB436/naive/MDAMB436_peaks.preprocessed.bed")
ATAC_peak_df = ATAC_peak.iloc[:, [0,1,2]]
ATAC_peak_df.columns = ["chr", "start", "end"]
ATAC_peak_df['Annotation'] = "MDAMB436_ATAC_peak"
ATAC_peak = pybed.BedTool.from_dataframe(ATAC_peak_df)
ATAC_peak_MDAMB436 = ATAC_peak.sort()

H3K27ac_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB436/H3K27ac/results/Peak/MDAMB436_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_df = H3K27ac_peak.iloc[:, [0,1,2]]
H3K27ac_peak_df.columns = ["chr", "start", "end"]
H3K27ac_peak_df['Annotation'] = "MDAMB436_H3K27ac_peak"
H3K27ac_peak = pybed.BedTool.from_dataframe(H3K27ac_peak_df)
H3K27ac_peak_MDAMB436 = H3K27ac_peak.sort()

H3K27me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB436/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_df = H3K27me3_peak.iloc[:, [0,1,2]]
H3K27me3_peak_df.columns = ["chr", "start", "end"]
H3K27me3_peak_df['Annotation'] = "MDAMB436_H3K27me3_peak"
H3K27me3_peak = pybed.BedTool.from_dataframe(H3K27me3_peak_df)
H3K27me3_peak_MDAMB436 = H3K27me3_peak.sort()

H3K4me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB436/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_df = H3K4me3_peak.iloc[:, [0,1,2]]
H3K4me3_peak_df.columns = ["chr", "start", "end"]
H3K4me3_peak_df['Annotation'] = "MDAMB436_H3K4me3_peak"
H3K4me3_peak = pybed.BedTool.from_dataframe(H3K4me3_peak_df)
H3K4me3_peak_MDAMB436 = H3K4me3_peak.sort()


H3K4me1_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB436/H3K4me1/results/Peak/H3K4me1_peaks.preprocessed.bed")
H3K4me1_peak_df = H3K4me1_peak.iloc[:, [0,1,2]]
H3K4me1_peak_df.columns = ["chr", "start", "end"]
H3K4me1_peak_df['Annotation'] = "MDAMB436_H3K4me1_peak"
H3K4me1_peak = pybed.BedTool.from_dataframe(H3K4me1_peak_df)
H3K4me1_peak_MDAMB436 = H3K4me1_peak.sort()

# SUZ12_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/SUZ12/SUZ12_peaks.preprocessed.bed")
# SUZ12_peak_df = SUZ12_peak.iloc[:, [0,1,2]]
# SUZ12_peak_df.columns = ["chr", "start", "end"]
# SUZ12_peak_df['Annotation'] = "T47D_SUZ12_peak"
# SUZ12_peak = pybed.BedTool.from_dataframe(SUZ12_peak_df)
# SUZ12_peak = SUZ12_peak.sort()

# REST_peak = pd.read_table("/home/darragh/New/ChIP-seq/T47D/REST/results/Peak/REST_peaks.preprocessed.bed")
# REST_peak_df = REST_peak.iloc[:, [0,1,2]]
# REST_peak_df.columns = ["chr", "start", "end"]
# REST_peak_df['Annotation'] = "T47D_REST_peak"
# REST_peak = pybed.BedTool.from_dataframe(REST_peak_df)
# REST_peak = REST_peak.sort()

###########################################

#Active-enhancers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27ac = H3K27ac_peak.subtract(Coding_promoter, A=True)
# active_enhancer = Distal_H3K27ac.intersect(Distal_ATAC, wa=True, wb=True, f=0.1, r=True)
# active_enhancer_df = pd.read_table(active_enhancer.fn,header=None)
# active_enhancer_df = active_enhancer_df.drop(active_enhancer_df.columns[[3, 7]],axis = 1)
# active_enhancer_df_1 = active_enhancer_df.iloc[:,0:3]
# active_enhancer_df_1.columns = ["chr", "start", "end"]
# active_enhancer_df_1["id"] = range(1, 1 + len(active_enhancer_df_1))
# active_enhancer_df_1["id"] = "AE_" + active_enhancer_df_1["id"].astype(str)
# active_enhancer_df_2 = active_enhancer_df.iloc[:,3:]
# active_enhancer_df_2.columns = ["chr", "start", "end"]
# active_enhancer_df_2["id"] = range(1, 1 + len(active_enhancer_df_2))
# active_enhancer_df_2["id"] = "AE_" + active_enhancer_df_2["id"].astype(str)
# active_enhancer_df = pd.concat([active_enhancer_df_1,active_enhancer_df_2])
# active_enhancer_df = active_enhancer_df.sort_values(by='id')
# active_enhancer = pybed.BedTool.from_dataframe(active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# active_enhancer = active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# active_enhancer_df.columns = ["chr", "name", "start", "end"]
# active_enhancer_df = active_enhancer_df[["chr", "start", "end"]]
# active_enhancer_df["annotation"] = "MDAMB436_active_enhancer"
# active_enhancer_df = active_enhancer_df.drop_duplicates()


#####################################

#H3K27me3 silencers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27me3 = H3K27me3_peak.subtract(Coding_promoter, A=True)
# H3K27me3_silencer = Distal_H3K27me3.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# H3K27me3_silencer = H3K27me3_silencer.subtract(Distal_H3K27ac, A=True)
# H3K27me3_silencer_df = pd.read_table(H3K27me3_silencer.fn,header=None)
# H3K27me3_silencer_df = H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# H3K27me3_silencer_df["annotation"] = "MDAMB436_H3K27me3_silencer"
# H3K27me3_silencer_df = H3K27me3_silencer_df.drop_duplicates()

#####################################

#REST silencers

# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# REST_silencer = REST_peak.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27ac, A=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27me3, A=True)
# REST_silencer_df = pd.read_table(REST_silencer.fn,header=None)
# REST_silencer_df = REST_silencer_df.iloc[:, [4,5,6,7]]
# REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# REST_silencer_df["annotation"] = "T47D_REST_silencer"
# REST_silencer_df = REST_silencer_df.drop_duplicates()

#####################################

# #Polycomb-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Polycomb_promoter = H3K4me3_peak_proximal.intersect(SUZ12_peak, wa=True, wb=True) 
# Polycomb_promoter_df = pd.read_table(Polycomb_promoter.fn,header=None)
# Polycomb_promoter_df = Polycomb_promoter_df.drop(Polycomb_promoter_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_df_1 = Polycomb_promoter_df.iloc[:,0:3]
# Polycomb_promoter_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_1["id"] = range(1, 1 + len(Polycomb_promoter_df_1))
# Polycomb_promoter_df_1["id"] = "AE_" + Polycomb_promoter_df_1["id"].astype(str)
# Polycomb_promoter_df_2 = Polycomb_promoter_df.iloc[:,3:]
# Polycomb_promoter_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_2["id"] = range(1, 1 + len(Polycomb_promoter_df_2))
# Polycomb_promoter_df_2["id"] = "AE_" + Polycomb_promoter_df_2["id"].astype(str)
# Polycomb_promoter_df = pd.concat([Polycomb_promoter_df_1,Polycomb_promoter_df_2])
# Polycomb_promoter_df = Polycomb_promoter_df.sort_values(by='id')
# Polycomb_promoter = pybed.BedTool.from_dataframe(Polycomb_promoter_df)
# Polycomb_promoter = Polycomb_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_df = Polycomb_promoter_df[["chr", "start", "end"]]
# Polycomb_promoter_df["annotation"] = "T47D_polycomb_promoter"
# Polycomb_promoter_df = Polycomb_promoter_df.drop_duplicates()

#Active-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Active_promoter = H3K4me3_peak_proximal.intersect(H3K27ac_peak, wa=True, wb=True) 
# Active_promoter_df = pd.read_table(Active_promoter.fn,header=None)
# Active_promoter_df = Active_promoter_df.drop(Active_promoter_df.columns[[3, 7]],axis = 1)
# Active_promoter_df_1 = Active_promoter_df.iloc[:,0:3]
# Active_promoter_df_1.columns = ["chr", "start", "end"]
# Active_promoter_df_1["id"] = range(1, 1 + len(Active_promoter_df_1))
# Active_promoter_df_1["id"] = "AE_" + Active_promoter_df_1["id"].astype(str)
# Active_promoter_df_2 = Active_promoter_df.iloc[:,3:]
# Active_promoter_df_2.columns = ["chr", "start", "end"]
# Active_promoter_df_2["id"] = range(1, 1 + len(Active_promoter_df_2))
# Active_promoter_df_2["id"] = "AE_" + Active_promoter_df_2["id"].astype(str)
# Active_promoter_df = pd.concat([Active_promoter_df_1,Active_promoter_df_2])
# Active_promoter_df = Active_promoter_df.sort_values(by='id')
# Active_promoter = pybed.BedTool.from_dataframe(Active_promoter_df)
# Active_promoter = Active_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_df = Active_promoter_df[["chr", "start", "end"]]
# Active_promoter_df["annotation"] = "MDAMB436_active_promoter"
# Active_promoter_df = Active_promoter_df.drop_duplicates()

# reg_elements = pd.concat([ active_enhancer_df, H3K27me3_silencer_df , Active_promoter_df ])
# display(reg_elements)

#active enhancer
Distal_ATAC_MDAMB436 = ATAC_peak_MDAMB436.subtract(Coding_promoter, A=True)
Distal_H3K27ac_MDAMB436 = H3K27ac_peak_MDAMB436.subtract(Coding_promoter, A=True)
MDAMB436_active_enhancer = Distal_H3K27ac_MDAMB436.intersect(Distal_ATAC_MDAMB436, wb=True, f=0.1, r=True)
MDAMB436_active_enhancer = MDAMB436_active_enhancer.subtract(H3K27me3_peak_MDAMB436, A=True)
MDAMB436_active_enhancer_df = pd.read_table(MDAMB436_active_enhancer.fn,header=None)
MDAMB436_active_enhancer_df = MDAMB436_active_enhancer_df.iloc[:, [4,5,6,7]]
MDAMB436_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
MDAMB436_active_enhancer_df["annotation"] = "MDAMB436_active_enhancer"
MDAMB436_active_enhancer_df = MDAMB436_active_enhancer_df.drop_duplicates()
#
# MDAMB436_active_enhancer = pybed.BedTool.from_dataframe(MDAMB436_active_enhancer_df)
# Active_promoter_MDAMB436_enh = MDAMB436_active_enhancer.intersect(H3K4me3_peak_MDAMB436, wa=True)
# Active_promoter_MDAMB436_enh_df = pd.read_table(Active_promoter_MDAMB436_enh.fn, header=None)
# Active_promoter_MDAMB436_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_MDAMB436_enh_df['annotation'] = 'MDAMB436_active_promoter'
# MDAMB436_active_enhancer = MDAMB436_active_enhancer.subtract(H3K4me3_peak_MDAMB436, A=True)
# MDAMB436_active_enhancer_df = pd.read_table(MDAMB436_active_enhancer.fn, header=None)
# MDAMB436_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_MDAMB436 = ATAC_peak_MDAMB436.subtract(Coding_promoter, A=True)
Distal_H3K27me3_MDAMB436 = H3K27me3_peak_MDAMB436.subtract(Coding_promoter, A=True)
MDAMB436_H3K27me3_silencer = Distal_H3K27me3_MDAMB436.intersect(Distal_ATAC_MDAMB436, wb=True, f=0.1, r=True)
MDAMB436_H3K27me3_silencer = MDAMB436_H3K27me3_silencer.subtract(Distal_H3K27ac_MDAMB436, A=True)
MDAMB436_H3K27me3_silencer_df = pd.read_table(MDAMB436_H3K27me3_silencer.fn,header=None)
MDAMB436_H3K27me3_silencer_df = MDAMB436_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
MDAMB436_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
MDAMB436_H3K27me3_silencer_df["annotation"] = "MDAMB436_H3K27me3_silencer"
MDAMB436_H3K27me3_silencer_df = MDAMB436_H3K27me3_silencer_df.drop_duplicates()
#
# MDAMB436_H3K27me3_silencer = pybed.BedTool.from_dataframe(MDAMB436_H3K27me3_silencer_df)
# # Active_promoter_MDAMB436_sil = MDAMB436_H3K27me3_silencer.intersect(H3K4me3_peak_MDAMB436, wa=True)
# # Active_promoter_MDAMB436_sil_df = pd.read_table(Active_promoter_MDAMB436_sil.fn, header=None)
# # Active_promoter_MDAMB436_sil_df.columns = ['chr', 'start', 'end', 'annotation']
# # Active_promoter_MDAMB436_sil_df['annotation'] = 'MDAMB436_active_promoter'
# MDAMB436_H3K27me3_silencer = MDAMB436_H3K27me3_silencer.subtract(H3K4me3_peak_MDAMB436, A=True)
# MDAMB436_H3K27me3_silencer_df = pd.read_table(MDAMB436_H3K27me3_silencer.fn, header=None)
# MDAMB436_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_MDAMB436_proximal = ATAC_peak_MDAMB436.intersect(Coding_promoter, wa=True)
Active_promoter_MDAMB436 = ATAC_peak_MDAMB436_proximal.intersect(H3K27ac_peak_MDAMB436, wa=True)
Active_promoter_MDAMB436 = Active_promoter_MDAMB436.subtract(H3K27me3_peak_MDAMB436, A=True)
Active_promoter_MDAMB436_df = pd.read_table(Active_promoter_MDAMB436.fn,header=None) 
Active_promoter_MDAMB436_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_MDAMB436_df["annotation"] = "MDAMB436_active_promoter"
Active_promoter_MDAMB436_df = Active_promoter_MDAMB436_df.drop_duplicates()


#

# Active_promoter_MDAMB436 = pybed.BedTool.from_dataframe(Active_promoter_MDAMB436_df)
# Active_enhancer_MDAMB436_prom = Active_promoter_MDAMB436.intersect(H3K4me1_peak_MDAMB436, wa=True)
# Active_enhancer_MDAMB436_prom_df = pd.read_table(Active_enhancer_MDAMB436_prom.fn, header=None)
# Active_enhancer_MDAMB436_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_MDAMB436_prom_df['annotation'] = 'MDAMB436_active_promoter'
# Active_promoter_MDAMB436 = Active_promoter_MDAMB436.subtract(H3K4me1_peak_MDAMB436, A=True)
# Active_promoter_MDAMB436_df = pd.read_table(Active_promoter_MDAMB436.fn, header=None)
# Active_promoter_MDAMB436_df.columns = ['chr', 'start', 'end', 'annotation']

MDAMB436_reg_elements = pd.concat([MDAMB436_active_enhancer_df, MDAMB436_H3K27me3_silencer_df , Active_promoter_MDAMB436_df])
MDAMB436_reg_elements = MDAMB436_reg_elements.drop_duplicates()
display(MDAMB436_reg_elements)

MDAMB436_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MDAMB436_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/3871437552.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_df['Annotation'] = "MDAMB436_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/3871437552.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_df['Annotation'] = "MDAMB436_H3K27ac_peak"
# ...

# %%
display(H3K27me3_silencer_df)
# Out:
#        chr     start       end                  annotation
# 0     chr1    805027    805454  MDAMB436_H3K27me3_silencer
# 1     chr1   2838193   2838868  MDAMB436_H3K27me3_silencer
# 2     chr1   4166364   4166672  MDAMB436_H3K27me3_silencer
# 3     chr1   4726583   4727148  MDAMB436_H3K27me3_silencer
# 4     chr1   5671607   5672184  MDAMB436_H3K27me3_silencer
# ...    ...       ...       ...                         ...
# 1310  chrY  10012548  10012875  MDAMB436_H3K27me3_silencer
# 1311  chrY  10022175  10023144  MDAMB436_H3K27me3_silencer
# 1313  chrY  13631111  13631369  MDAMB436_H3K27me3_silencer
# 1314  chrY  59001343  59002097  MDAMB436_H3K27me3_silencer
# 1315  chrY  59029814  59030035  MDAMB436_H3K27me3_silencer
#
# [1285 rows x 4 columns]

# %% [markdown]
# # Add super-enhancers

# %%
BT549_reg_elements = pybed.BedTool.from_dataframe(BT549_reg_elements)
BT549_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/BT549/BT549_Gateway_SuperEnhancers.bed",header=None)
BT549_Super_enhancers_df = BT549_Super_enhancers_df.iloc[:, [0,1,2]]
BT549_Super_enhancers_df.columns = ["chr", "start", "end"]
BT549_Super_enhancers_df['Annotation'] = "BT549_super_enhancer"
BT549_Super_enhancers = pybed.BedTool.from_dataframe(BT549_Super_enhancers_df)
BT549_reg_elements = BT549_reg_elements.subtract(BT549_Super_enhancers)

BT549_reg_elements = pd.read_table(BT549_reg_elements.fn, header=None)
BT549_Super_enhancers = pd.read_table(BT549_Super_enhancers.fn, header=None)

BT549_reg_elements = pybed.BedTool.from_dataframe(pd.concat([BT549_reg_elements,BT549_Super_enhancers]))
BT549_reg_elements = BT549_reg_elements.sort()
BT549_reg_elements = pd.read_table(BT549_reg_elements.fn, header=None)
BT549_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/BT549_reg_elements.txt", sep='\t', index=False, header=None)

# %%
#Call MDAMB468 reg-elements

pd.options.display.float_format = '{:,.0f}'.format

ATAC_peak = pd.read_table("/home/darragh/New/ATAC-seq/MDAMB468/naive/MDAMB468_peaks.preprocessed.bed")
ATAC_peak_df = ATAC_peak.iloc[:, [0,1,2]]
ATAC_peak_df.columns = ["chr", "start", "end"]
ATAC_peak_df['Annotation'] = "MDAMB468_ATAC_peak"
ATAC_peak = pybed.BedTool.from_dataframe(ATAC_peak_df)
ATAC_peak_MDAMB468 = ATAC_peak.sort()

H3K27ac_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB468/H3K27ac/results/Peak/MDAMB468_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_df = H3K27ac_peak.iloc[:, [0,1,2]]
H3K27ac_peak_df.columns = ["chr", "start", "end"]
H3K27ac_peak_df['Annotation'] = "MDAMB468_H3K27ac_peak"
H3K27ac_peak = pybed.BedTool.from_dataframe(H3K27ac_peak_df)
H3K27ac_peak_MDAMB468 = H3K27ac_peak.sort()

H3K27me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB468/H3K27me3/results/Peak/H3K27me3_peaks.preprocessed.bed")
H3K27me3_peak_df = H3K27me3_peak.iloc[:, [0,1,2]]
H3K27me3_peak_df.columns = ["chr", "start", "end"]
H3K27me3_peak_df['Annotation'] = "MDAMB468_H3K27me3_peak"
H3K27me3_peak = pybed.BedTool.from_dataframe(H3K27me3_peak_df)
H3K27me3_peak_MDAMB468 = H3K27me3_peak.sort()

H3K4me3_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB468/H3K4me3/results/Peak/H3K4me3_peaks.preprocessed.bed")
H3K4me3_peak_df = H3K4me3_peak.iloc[:, [0,1,2]]
H3K4me3_peak_df.columns = ["chr", "start", "end"]
H3K4me3_peak_df['Annotation'] = "MDAMB468_H3K4me3_peak"
H3K4me3_peak = pybed.BedTool.from_dataframe(H3K4me3_peak_df)
H3K4me3_peak_MDAMB468 = H3K4me3_peak.sort()

H3K4me1_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB468/H3K4me1/results/Peak/H3K4me1_peaks.preprocessed.bed")
H3K4me1_peak_df = H3K4me1_peak.iloc[:, [0,1,2]]
H3K4me1_peak_df.columns = ["chr", "start", "end"]
H3K4me1_peak_df['Annotation'] = "MDAMB468_H3K4me1_peak"
H3K4me1_peak = pybed.BedTool.from_dataframe(H3K4me1_peak_df)
H3K4me1_peak_MDAMB468 = H3K4me1_peak.sort()


SUZ12_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB468/SUZ12/SUZ12_peaks.preprocessed.bed")
SUZ12_peak_df = SUZ12_peak.iloc[:, [0,1,2]]
SUZ12_peak_df.columns = ["chr", "start", "end"]
SUZ12_peak_df['Annotation'] = "MDAMB468_SUZ12_peak"
SUZ12_peak = pybed.BedTool.from_dataframe(SUZ12_peak_df)
SUZ12_peak = SUZ12_peak.sort()

REST_peak = pd.read_table("/home/darragh/New/ChIP-seq/MDAMB468/REST/results/Peak/REST_peaks.preprocessed.bed")
REST_peak_df = REST_peak.iloc[:, [0,1,2]]
REST_peak_df.columns = ["chr", "start", "end"]
REST_peak_df['Annotation'] = "MDAMB468_REST_peak"
REST_peak = pybed.BedTool.from_dataframe(REST_peak_df)
REST_peak = REST_peak.sort()

###########################################

#Active-enhancers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27ac = H3K27ac_peak.subtract(Coding_promoter, A=True)
# active_enhancer = Distal_H3K27ac.intersect(Distal_ATAC, wa=True, wb=True, f=0.1, r=True)
# active_enhancer_df = pd.read_table(active_enhancer.fn,header=None)
# active_enhancer_df = active_enhancer_df.drop(active_enhancer_df.columns[[3, 7]],axis = 1)
# active_enhancer_df_1 = active_enhancer_df.iloc[:,0:3]
# active_enhancer_df_1.columns = ["chr", "start", "end"]
# active_enhancer_df_1["id"] = range(1, 1 + len(active_enhancer_df_1))
# active_enhancer_df_1["id"] = "AE_" + active_enhancer_df_1["id"].astype(str)
# active_enhancer_df_2 = active_enhancer_df.iloc[:,3:]
# active_enhancer_df_2.columns = ["chr", "start", "end"]
# active_enhancer_df_2["id"] = range(1, 1 + len(active_enhancer_df_2))
# active_enhancer_df_2["id"] = "AE_" + active_enhancer_df_2["id"].astype(str)
# active_enhancer_df = pd.concat([active_enhancer_df_1,active_enhancer_df_2])
# active_enhancer_df = active_enhancer_df.sort_values(by='id')
# active_enhancer = pybed.BedTool.from_dataframe(active_enhancer_df)
# #HMEC_active_enhancer = HMEC_active_enhancer.subtract(HMEC_Super_enhancers, A=True ,f=0.1)
# active_enhancer = active_enhancer.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# active_enhancer_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# active_enhancer_df.columns = ["chr", "name", "start", "end"]
# active_enhancer_df = active_enhancer_df[["chr", "start", "end"]]
# active_enhancer_df["annotation"] = "MDAMB468_active_enhancer"
# active_enhancer_df = active_enhancer_df.drop_duplicates()


#####################################

#H3K27me3 silencers
# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# Distal_H3K27me3 = H3K27me3_peak.subtract(Coding_promoter, A=True)
# H3K27me3_silencer = Distal_H3K27me3.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# H3K27me3_silencer = H3K27me3_silencer.subtract(Distal_H3K27ac, A=True)
# H3K27me3_silencer_df = pd.read_table(H3K27me3_silencer.fn,header=None)
# H3K27me3_silencer_df = H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
# H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# H3K27me3_silencer_df["annotation"] = "MDAMB468_H3K27me3_silencer"
# H3K27me3_silencer_df = H3K27me3_silencer_df.drop_duplicates()

#####################################

#REST silencers

# Distal_ATAC = ATAC_peak.subtract(Coding_promoter, A=True)
# REST_silencer = REST_peak.intersect(Distal_ATAC, wb=True, f=0.1, r=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27ac, A=True)
# REST_silencer = REST_silencer.subtract(Distal_H3K27me3, A=True)
# REST_silencer_df = pd.read_table(REST_silencer.fn,header=None)
# REST_silencer_df = REST_silencer_df.iloc[:, [4,5,6,7]]
# REST_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
# REST_silencer_df["annotation"] = "MDAMB468_REST_silencer"
# REST_silencer_df = REST_silencer_df.drop_duplicates()

####################################

#Polycomb-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Polycomb_promoter = H3K4me3_peak_proximal.intersect(SUZ12_peak, wa=True, wb=True) 
# Polycomb_promoter_df = pd.read_table(Polycomb_promoter.fn,header=None)
# Polycomb_promoter_df = Polycomb_promoter_df.drop(Polycomb_promoter_df.columns[[3, 7]],axis = 1)
# Polycomb_promoter_df_1 = Polycomb_promoter_df.iloc[:,0:3]
# Polycomb_promoter_df_1.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_1["id"] = range(1, 1 + len(Polycomb_promoter_df_1))
# Polycomb_promoter_df_1["id"] = "AE_" + Polycomb_promoter_df_1["id"].astype(str)
# Polycomb_promoter_df_2 = Polycomb_promoter_df.iloc[:,3:]
# Polycomb_promoter_df_2.columns = ["chr", "start", "end"]
# Polycomb_promoter_df_2["id"] = range(1, 1 + len(Polycomb_promoter_df_2))
# Polycomb_promoter_df_2["id"] = "AE_" + Polycomb_promoter_df_2["id"].astype(str)
# Polycomb_promoter_df = pd.concat([Polycomb_promoter_df_1,Polycomb_promoter_df_2])
# Polycomb_promoter_df = Polycomb_promoter_df.sort_values(by='id')
# Polycomb_promoter = pybed.BedTool.from_dataframe(Polycomb_promoter_df)
# Polycomb_promoter = Polycomb_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Polycomb_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Polycomb_promoter_df.columns = ["chr", "name", "start", "end"]
# Polycomb_promoter_df = Polycomb_promoter_df[["chr", "start", "end"]]
# Polycomb_promoter_df["annotation"] = "MDAMB468_polycomb_promoter"
# Polycomb_promoter_df = Polycomb_promoter_df.drop_duplicates()

#Active-promoters
# H3K4me3_peak_proximal = H3K4me3_peak.intersect(Coding_promoter, wa=True)
# Active_promoter = H3K4me3_peak_proximal.intersect(H3K27ac_peak, wa=True, wb=True) 
# Active_promoter_df = pd.read_table(Active_promoter.fn,header=None)
# Active_promoter_df = Active_promoter_df.drop(Active_promoter_df.columns[[3, 7]],axis = 1)
# Active_promoter_df_1 = Active_promoter_df.iloc[:,0:3]
# Active_promoter_df_1.columns = ["chr", "start", "end"]
# Active_promoter_df_1["id"] = range(1, 1 + len(Active_promoter_df_1))
# Active_promoter_df_1["id"] = "AE_" + Active_promoter_df_1["id"].astype(str)
# Active_promoter_df_2 = Active_promoter_df.iloc[:,3:]
# Active_promoter_df_2.columns = ["chr", "start", "end"]
# Active_promoter_df_2["id"] = range(1, 1 + len(Active_promoter_df_2))
# Active_promoter_df_2["id"] = "AE_" + Active_promoter_df_2["id"].astype(str)
# Active_promoter_df = pd.concat([Active_promoter_df_1,Active_promoter_df_2])
# Active_promoter_df = Active_promoter_df.sort_values(by='id')
# Active_promoter = pybed.BedTool.from_dataframe(Active_promoter_df)
# Active_promoter = Active_promoter.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# Active_promoter_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# Active_promoter_df.columns = ["chr", "name", "start", "end"]
# Active_promoter_df = Active_promoter_df[["chr", "start", "end"]]
# Active_promoter_df["annotation"] = "MDAMB468_active_promoter"
# Active_promoter_df = Active_promoter_df.drop_duplicates()

# reg_elements = pd.concat([ active_enhancer_df,Polycomb_promoter_df, H3K27me3_silencer_df , Active_promoter_df ])
# display(reg_elements)

#active enhancer
Distal_ATAC_MDAMB468 = ATAC_peak_MDAMB468.subtract(Coding_promoter, A=True)
Distal_H3K27ac_MDAMB468 = H3K27ac_peak_MDAMB468.subtract(Coding_promoter, A=True)
MDAMB468_active_enhancer = Distal_H3K27ac_MDAMB468.intersect(Distal_ATAC_MDAMB468, wb=True, f=0.1, r=True)
MDAMB468_active_enhancer = MDAMB468_active_enhancer.subtract(H3K27me3_peak_MDAMB468, A=True)
MDAMB468_active_enhancer_df = pd.read_table(MDAMB468_active_enhancer.fn,header=None)
MDAMB468_active_enhancer_df = MDAMB468_active_enhancer_df.iloc[:, [4,5,6,7]]
MDAMB468_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']
MDAMB468_active_enhancer_df["annotation"] = "MDAMB468_active_enhancer"
MDAMB468_active_enhancer_df = MDAMB468_active_enhancer_df.drop_duplicates()

#
# MDAMB468_active_enhancer = pybed.BedTool.from_dataframe(MDAMB468_active_enhancer_df)
# Active_promoter_MDAMB468_enh = MDAMB468_active_enhancer.intersect(H3K4me3_peak_MDAMB468, wa=True)
# Active_promoter_MDAMB468_enh_df = pd.read_table(Active_promoter_MDAMB468_enh.fn, header=None)
# Active_promoter_MDAMB468_enh_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_promoter_MDAMB468_enh_df['annotation'] = 'MDAMB468_active_promoter'
# MDAMB468_active_enhancer = MDAMB468_active_enhancer.subtract(H3K4me3_peak_MDAMB468, A=True)
# MDAMB468_active_enhancer_df = pd.read_table(MDAMB468_active_enhancer.fn, header=None)
# MDAMB468_active_enhancer_df.columns = ['chr', 'start', 'end', 'annotation']


#H3K27me3 silencer
Distal_ATAC_MDAMB468 = ATAC_peak_MDAMB468.subtract(Coding_promoter, A=True)
Distal_H3K27me3_MDAMB468 = H3K27me3_peak_MDAMB468.subtract(Coding_promoter, A=True)
MDAMB468_H3K27me3_silencer = Distal_H3K27me3_MDAMB468.intersect(Distal_ATAC_MDAMB468, wb=True, f=0.1, r=True)
MDAMB468_H3K27me3_silencer = MDAMB468_H3K27me3_silencer.subtract(Distal_H3K27ac_MDAMB468, A=True)
MDAMB468_H3K27me3_silencer_df = pd.read_table(MDAMB468_H3K27me3_silencer.fn,header=None)
MDAMB468_H3K27me3_silencer_df = MDAMB468_H3K27me3_silencer_df.iloc[:, [4,5,6,7]]
MDAMB468_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']
MDAMB468_H3K27me3_silencer_df["annotation"] = "MDAMB468_H3K27me3_silencer"
MDAMB468_H3K27me3_silencer_df = MDAMB468_H3K27me3_silencer_df.drop_duplicates()
#
# MDAMB468_H3K27me3_silencer = pybed.BedTool.from_dataframe(MDAMB468_H3K27me3_silencer_df)
# # Active_promoter_MDAMB468_sil = MDAMB468_H3K27me3_silencer.intersect(H3K4me3_peak_MDAMB468, wa=True)
# # Active_promoter_MDAMB468_sil_df = pd.read_table(Active_promoter_MDAMB468_sil.fn, header=None)
# # Active_promoter_MDAMB468_sil_df.columns = ['chr', 'start', 'end', 'annotation']
# # Active_promoter_MDAMB468_sil_df['annotation'] = 'MDAMB468_active_promoter'
# MDAMB468_H3K27me3_silencer = MDAMB468_H3K27me3_silencer.subtract(H3K4me3_peak_MDAMB468, A=True)
# MDAMB468_H3K27me3_silencer_df = pd.read_table(MDAMB468_H3K27me3_silencer.fn, header=None)
# MDAMB468_H3K27me3_silencer_df.columns = ['chr', 'start', 'end', 'annotation']

#active promoter
ATAC_peak_MDAMB468_proximal = ATAC_peak_MDAMB468.intersect(Coding_promoter, wa=True)
Active_promoter_MDAMB468 = ATAC_peak_MDAMB468_proximal.intersect(H3K27ac_peak_MDAMB468, wa=True)
Active_promoter_MDAMB468 = Active_promoter_MDAMB468.subtract(H3K27me3_peak_MDAMB468, A=True)
Active_promoter_MDAMB468_df = pd.read_table(Active_promoter_MDAMB468.fn,header=None) 
Active_promoter_MDAMB468_df.columns = ['chr', 'start', 'end', 'annotation']
Active_promoter_MDAMB468_df["annotation"] = "MDAMB468_active_promoter"
Active_promoter_MDAMB468_df = Active_promoter_MDAMB468_df.drop_duplicates()


#

# Active_promoter_MDAMB468 = pybed.BedTool.from_dataframe(Active_promoter_MDAMB468_df)
# Active_enhancer_MDAMB468_prom = Active_promoter_MDAMB468.intersect(H3K4me1_peak_MDAMB468, wa=True)
# Active_enhancer_MDAMB468_prom_df = pd.read_table(Active_enhancer_MDAMB468_prom.fn, header=None)
# Active_enhancer_MDAMB468_prom_df.columns = ['chr', 'start', 'end', 'annotation']
# Active_enhancer_MDAMB468_prom_df['annotation'] = 'MDAMB468_active_promoter'
# Active_promoter_MDAMB468 = Active_promoter_MDAMB468.subtract(H3K4me1_peak_MDAMB468, A=True)
# Active_promoter_MDAMB468_df = pd.read_table(Active_promoter_MDAMB468.fn, header=None)
# Active_promoter_MDAMB468_df.columns = ['chr', 'start', 'end', 'annotation']

MDAMB468_reg_elements = pd.concat([MDAMB468_active_enhancer_df, MDAMB468_H3K27me3_silencer_df , Active_promoter_MDAMB468_df ])
MDAMB468_reg_elements = MDAMB468_reg_elements.drop_duplicates()
display(MDAMB468_reg_elements)

MDAMB468_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MDAMB468_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2078351/4126333562.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ATAC_peak_df['Annotation'] = "MDAMB468_ATAC_peak"
# /usr/lib/python3.8/subprocess.py:853: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)
# /tmp/ipykernel_2078351/4126333562.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H3K27ac_peak_df['Annotation'] = "MDAMB468_H3K27ac_peak"
# ...

# %%
display(H3K27me3_silencer_df)
# Out:
#        chr     start       end                  annotation
# 0     chr1   1225453   1225801  MDAMB468_H3K27me3_silencer
# 1     chr1   2262852   2263343  MDAMB468_H3K27me3_silencer
# 2     chr1   2559389   2559660  MDAMB468_H3K27me3_silencer
# 3     chr1   3420705   3421010  MDAMB468_H3K27me3_silencer
# 4     chr1   3426409   3427714  MDAMB468_H3K27me3_silencer
# ...    ...       ...       ...                         ...
# 5575  chrY    342925    343645  MDAMB468_H3K27me3_silencer
# 5576  chrY   1186549   1186916  MDAMB468_H3K27me3_silencer
# 5577  chrY   9929882   9931518  MDAMB468_H3K27me3_silencer
# 5578  chrY  10012452  10013242  MDAMB468_H3K27me3_silencer
# 5579  chrY  59001445  59002040  MDAMB468_H3K27me3_silencer
#
# [5483 rows x 4 columns]

# %% [markdown]
# # Add super-enhancers

# %%
MDAMB468_reg_elements = pybed.BedTool.from_dataframe(MDAMB468_reg_elements)
MDAMB468_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/MDAMB468/MDAMB468_Gateway_SuperEnhancers.bed",header=None)
MDAMB468_Super_enhancers_df = MDAMB468_Super_enhancers_df.iloc[:, [0,1,2]]
MDAMB468_Super_enhancers_df.columns = ["chr", "start", "end"]
MDAMB468_Super_enhancers_df['Annotation'] = "MDAMB468_super_enhancer"
MDAMB468_Super_enhancers = pybed.BedTool.from_dataframe(MDAMB468_Super_enhancers_df)
MDAMB468_reg_elements = MDAMB468_reg_elements.subtract(MDAMB468_Super_enhancers)

MDAMB468_reg_elements = pd.read_table(MDAMB468_reg_elements.fn, header=None)
MDAMB468_Super_enhancers = pd.read_table(MDAMB468_Super_enhancers.fn, header=None)

MDAMB468_reg_elements = pybed.BedTool.from_dataframe(pd.concat([MDAMB468_reg_elements,MDAMB468_Super_enhancers]))
MDAMB468_reg_elements = MDAMB468_reg_elements.sort()
MDAMB468_reg_elements = pd.read_table(MDAMB468_reg_elements.fn, header=None)
MDAMB468_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MDAMB468_reg_elements.txt", sep='\t', index=False, header=None)

# %% [markdown]
# # Add super-enhancers

# %%
MDAMB436_reg_elements = pybed.BedTool.from_dataframe(MDAMB436_reg_elements)
MDAMB436_Super_enhancers_df = pd.read_table("/home/darragh/New/Rose/output/MDAMB436/MDAMB436_Gateway_SuperEnhancers.bed",header=None)
MDAMB436_Super_enhancers_df = MDAMB436_Super_enhancers_df.iloc[:, [0,1,2]]
MDAMB436_Super_enhancers_df.columns = ["chr", "start", "end"]
MDAMB436_Super_enhancers_df['Annotation'] = "MDAMB436_super_enhancer"
MDAMB436_Super_enhancers = pybed.BedTool.from_dataframe(MDAMB436_Super_enhancers_df)
MDAMB436_reg_elements = MDAMB436_reg_elements.subtract(MDAMB436_Super_enhancers)

MDAMB436_reg_elements = pd.read_table(MDAMB436_reg_elements.fn, header=None)
MDAMB436_Super_enhancers = pd.read_table(MDAMB436_Super_enhancers.fn, header=None)

MDAMB436_reg_elements = pybed.BedTool.from_dataframe(pd.concat([MDAMB436_reg_elements,MDAMB436_Super_enhancers]))
MDAMB436_reg_elements = MDAMB436_reg_elements.sort()
MDAMB436_reg_elements = pd.read_table(MDAMB436_reg_elements.fn, header=None)
MDAMB436_reg_elements.to_csv("/home/darragh/New/Regulatory_elements/MDAMB436_reg_elements.txt", sep='\t', index=False, header=None)

# %%
# #TN regulatory elements

# MDAMB231_regs_df = pd.read_table("/home/darragh/New/Regulatory_elements/MDAMB231_reg_elements.txt",header=None)
# MDAMB436_regs_df = pd.read_table("/home/darragh/New/Regulatory_elements/MDAMB436_reg_elements.txt",header=None)
# MDAMB468_regs_df = pd.read_table("/home/darragh/New/Regulatory_elements/MDAMB468_reg_elements.txt",header=None)
# BT549_regs_df = pd.read_table("/home/darragh/New/Regulatory_elements/BT549_reg_elements.txt",header=None)

# MDAMB231_regs_df.columns = ["chr", "start", "end", "annotation"]
# MDAMB436_regs_df.columns = ["chr", "start", "end", "annotation"]
# MDAMB468_regs_df.columns = ["chr", "start", "end", "annotation"]
# BT549_regs_df.columns = ["chr", "start", "end", "annotation"]

# #active promoter
# TN_active_promoter_df = MDAMB468_regs_df.loc[MDAMB468_regs_df['annotation'] == "MDAMB468_active_promoter"]
# TN_active_promoter_df.columns = ["chr", "start", "end", "annotation"]
# TN_active_promoter_df["annotation"] = "TN_active_promoter"
# display(TN_active_promoter_df)

# #polycomb promoter
# TN_polycomb_promoter_df = MDAMB468_regs_df.loc[MDAMB468_regs_df['annotation'] == "MDAMB468_polycomb_promoter"]
# TN_polycomb_promoter_df.columns = ["chr", "start", "end", "annotation"]
# TN_polycomb_promoter_df["annotation"] = "TN_polycomb_promoter"
# display(TN_polycomb_promoter_df)


# MDAMB231_super_enhancer = pybed.BedTool.from_dataframe(MDAMB231_regs_df.loc[MDAMB231_regs_df['annotation'] == "MDAMB231_super_enhancer"])
# MDAMB436_super_enhancer = pybed.BedTool.from_dataframe(MDAMB436_regs_df.loc[MDAMB436_regs_df['annotation'] == "MDAMB436_super_enhancer"])
# MDAMB468_super_enhancer = pybed.BedTool.from_dataframe(MDAMB468_regs_df.loc[MDAMB468_regs_df['annotation'] == "MDAMB468_super_enhancer"])
# BT549_super_enhancer = pybed.BedTool.from_dataframe(BT549_regs_df.loc[BT549_regs_df['annotation'] == "BT549_super_enhancer"])



# #Take the union of all super-enhancers
# TN_super_enhancer = MDAMB231_super_enhancer.cat(MDAMB436_super_enhancer, postmerge=False)
# TN_super_enhancer = TN_super_enhancer.cat(MDAMB468_super_enhancer, postmerge=False)
# TN_super_enhancer = TN_super_enhancer.cat(BT549_super_enhancer, postmerge=False)
# TN_super_enhancer = TN_super_enhancer.sort()
# TN_super_enhancer = TN_super_enhancer.merge()
# TN_super_enhancer_df = pd.read_table(TN_super_enhancer.fn, header=None)
# TN_super_enhancer_df.columns = ["chr", "start", "end"]
# TN_super_enhancer_df["annotation"] = 'TN_super_enhancer'
# TN_super_enhancer_df = TN_super_enhancer_df.drop_duplicates()

# ## active enhancers
# MDAMB231_active_enhancer = pybed.BedTool.from_dataframe(MDAMB231_regs_df.loc[MDAMB231_regs_df['annotation'] == "MDAMB231_active_enhancer"])
# MDAMB436_active_enhancer = pybed.BedTool.from_dataframe(MDAMB436_regs_df.loc[MDAMB436_regs_df['annotation'] == "MDAMB436_active_enhancer"])
# MDAMB468_active_enhancer = pybed.BedTool.from_dataframe(MDAMB468_regs_df.loc[MDAMB468_regs_df['annotation'] == "MDAMB468_active_enhancer"])
# BT549_active_enhancer = pybed.BedTool.from_dataframe(BT549_regs_df.loc[BT549_regs_df['annotation'] == "BT549_active_enhancer"])


# # #Get the active enhancers which are shared by all four
# TN_active_enhancer_all = MDAMB231_active_enhancer.intersect(MDAMB436_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_all = TN_active_enhancer_all.intersect(MDAMB468_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_all = TN_active_enhancer_all.intersect(BT549_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_all = TN_active_enhancer_all.sort()
# TN_active_enhancer_all = TN_active_enhancer_all.subtract(TN_super_enhancer, A=True, f=0.1)
# TN_active_enhancer_all_df = pd.read_table(TN_active_enhancer_all.fn,header=None) 
# TN_active_enhancer_all_df = TN_active_enhancer_all_df.drop(TN_active_enhancer_all_df.columns[[3,7,11,15]],axis = 1)
# TN_active_enhancer_all_df_1 = TN_active_enhancer_all_df.iloc[:,0:3]
# TN_active_enhancer_all_df_1.columns = ["chr", "start", "end"]
# TN_active_enhancer_all_df_1["id"] = range(1, 1 + len(TN_active_enhancer_all_df_1))
# TN_active_enhancer_all_df_1["id"] = "SE_" + TN_active_enhancer_all_df_1["id"].astype(str)
# TN_active_enhancer_all_df_2 = TN_active_enhancer_all_df.iloc[:,3:6]
# TN_active_enhancer_all_df_2.columns = ["chr", "start", "end"]
# TN_active_enhancer_all_df_2["id"] = range(1, 1 + len(TN_active_enhancer_all_df_2))
# TN_active_enhancer_all_df_2["id"] = "SE_" + TN_active_enhancer_all_df_2["id"].astype(str)
# TN_active_enhancer_all_df_3 = TN_active_enhancer_all_df.iloc[:,6:9]
# TN_active_enhancer_all_df_3.columns = ["chr", "start", "end"]
# TN_active_enhancer_all_df_3["id"] = range(1, 1 + len(TN_active_enhancer_all_df_3))
# TN_active_enhancer_all_df_3["id"] = "SE_" + TN_active_enhancer_all_df_3["id"].astype(str)
# TN_active_enhancer_all_df_4 = TN_active_enhancer_all_df.iloc[:,9:]
# TN_active_enhancer_all_df_4.columns = ["chr", "start", "end"]
# TN_active_enhancer_all_df_4["id"] = range(1, 1 + len(TN_active_enhancer_all_df_4))
# TN_active_enhancer_all_df_4["id"] = "SE_" + TN_active_enhancer_all_df_4["id"].astype(str)
# TN_active_enhancer_all_df = pd.concat([TN_active_enhancer_all_df_1,TN_active_enhancer_all_df_2,TN_active_enhancer_all_df_3,TN_active_enhancer_all_df_4])
# TN_active_enhancer_all_df = TN_active_enhancer_all_df.sort_values(by='id')
# TN_active_enhancer_all_2 = pybed.BedTool.from_dataframe(TN_active_enhancer_all_df)
# TN_active_enhancer_all_2 = TN_active_enhancer_all_2.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# TN_active_enhancer_all_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# TN_active_enhancer_all_df.columns = ["chr", "name", "start", "end"]
# TN_active_enhancer_all_df = TN_active_enhancer_all_df[["chr", "start", "end"]]
# TN_active_enhancer_all_df["annotation"] = "TN_active_enhancer"
# TN_active_enhancer_all_df = TN_active_enhancer_all_df.drop_duplicates()

# MDAMB231_active_enhancer = MDAMB231_active_enhancer.subtract(TN_active_enhancer_all, A=True, f=0.1, r=True)
# MDAMB436_active_enhancer = MDAMB436_active_enhancer.subtract(TN_active_enhancer_all, A=True, f=0.1, r=True)
# MDAMB468_active_enhancer = MDAMB468_active_enhancer.subtract(TN_active_enhancer_all, A=True, f=0.1, r=True)
# BT549_active_enhancer = BT549_active_enhancer.subtract(TN_active_enhancer_all, A=True, f=0.1, r=True)

# #######################

# #Shared between 231 436 468
# TN_active_enhancer_3way_1 = MDAMB231_active_enhancer.intersect(MDAMB436_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_3way_1 = TN_active_enhancer_3way_1.intersect(MDAMB468_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_3way_1 = TN_active_enhancer_3way_1.sort()
# TN_active_enhancer_3way_1 = TN_active_enhancer_3way_1.subtract(TN_super_enhancer, A=True, f=0.1)
# TN_active_enhancer_3way_1_df = pd.read_table(TN_active_enhancer_3way_1.fn,header=None) 
# TN_active_enhancer_3way_1_df = TN_active_enhancer_3way_1_df.drop(TN_active_enhancer_3way_1_df.columns[[3,7,11]],axis = 1)
# TN_active_enhancer_3way_1_df_1 = TN_active_enhancer_3way_1_df.iloc[:,0:3]
# TN_active_enhancer_3way_1_df_1.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_1_df_1["id"] = range(1, 1 + len(TN_active_enhancer_3way_1_df_1))
# TN_active_enhancer_3way_1_df_1["id"] = "SE_" + TN_active_enhancer_3way_1_df_1["id"].astype(str)
# TN_active_enhancer_3way_1_df_2 = TN_active_enhancer_3way_1_df.iloc[:,3:6]
# TN_active_enhancer_3way_1_df_2.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_1_df_2["id"] = range(1, 1 + len(TN_active_enhancer_3way_1_df_2))
# TN_active_enhancer_3way_1_df_2["id"] = "SE_" + TN_active_enhancer_3way_1_df_2["id"].astype(str)
# TN_active_enhancer_3way_1_df_3 = TN_active_enhancer_3way_1_df.iloc[:,6:9]
# TN_active_enhancer_3way_1_df_3.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_1_df_3["id"] = range(1, 1 + len(TN_active_enhancer_3way_1_df_3))
# TN_active_enhancer_3way_1_df_3["id"] = "SE_" + TN_active_enhancer_3way_1_df_3["id"].astype(str)
# TN_active_enhancer_3way_1_df = pd.concat([TN_active_enhancer_3way_1_df_1,TN_active_enhancer_3way_1_df_2,TN_active_enhancer_3way_1_df_3])
# TN_active_enhancer_3way_1_df = TN_active_enhancer_3way_1_df.sort_values(by='id')
# TN_active_enhancer_3way_1_ = pybed.BedTool.from_dataframe(TN_active_enhancer_3way_1_df)
# TN_active_enhancer_3way_1_ = TN_active_enhancer_3way_1_.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# TN_active_enhancer_3way_1_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# TN_active_enhancer_3way_1_df.columns = ["chr", "name", "start", "end"]
# TN_active_enhancer_3way_1_df = TN_active_enhancer_3way_1_df[["chr", "start", "end"]]
# TN_active_enhancer_3way_1_df["annotation"] = "TN_active_enhancer"
# TN_active_enhancer_3way_1_df = TN_active_enhancer_3way_1_df.drop_duplicates()


# ## active enhancers
# MDAMB231_active_enhancer = MDAMB231_active_enhancer.subtract(TN_active_enhancer_3way_1, A=True, f=0.1, r=True)
# MDAMB436_active_enhancer = MDAMB436_active_enhancer.subtract(TN_active_enhancer_3way_1, A=True, f=0.1, r=True)
# MDAMB468_active_enhancer = MDAMB468_active_enhancer.subtract(TN_active_enhancer_3way_1, A=True, f=0.1, r=True)
# BT549_active_enhancer = BT549_active_enhancer.subtract(TN_active_enhancer_3way_1, A=True, f=0.1, r=True)


# #######################

# #Shared between 231 436 BT
# TN_active_enhancer_3way_2 = MDAMB231_active_enhancer.intersect(MDAMB436_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_3way_2 = TN_active_enhancer_3way_2.intersect(BT549_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_3way_2 = TN_active_enhancer_3way_2.sort()
# TN_active_enhancer_3way_2 = TN_active_enhancer_3way_2.subtract(TN_super_enhancer, A=True, f=0.1)
# TN_active_enhancer_3way_2_df = pd.read_table(TN_active_enhancer_3way_2.fn,header=None) 
# TN_active_enhancer_3way_2_df = TN_active_enhancer_3way_2_df.drop(TN_active_enhancer_3way_2_df.columns[[3,7,11]],axis = 1)
# TN_active_enhancer_3way_2_df_1 = TN_active_enhancer_3way_2_df.iloc[:,0:3]
# TN_active_enhancer_3way_2_df_1.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_2_df_1["id"] = range(1, 1 + len(TN_active_enhancer_3way_2_df_1))
# TN_active_enhancer_3way_2_df_1["id"] = "SE_" + TN_active_enhancer_3way_2_df_1["id"].astype(str)
# TN_active_enhancer_3way_2_df_2 = TN_active_enhancer_3way_2_df.iloc[:,3:6]
# TN_active_enhancer_3way_2_df_2.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_2_df_2["id"] = range(1, 1 + len(TN_active_enhancer_3way_2_df_2))
# TN_active_enhancer_3way_2_df_2["id"] = "SE_" + TN_active_enhancer_3way_2_df_2["id"].astype(str)
# TN_active_enhancer_3way_2_df_3 = TN_active_enhancer_3way_2_df.iloc[:,6:9]
# TN_active_enhancer_3way_2_df_3.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_2_df_3["id"] = range(1, 1 + len(TN_active_enhancer_3way_2_df_3))
# TN_active_enhancer_3way_2_df_3["id"] = "SE_" + TN_active_enhancer_3way_2_df_3["id"].astype(str)
# TN_active_enhancer_3way_2_df = pd.concat([TN_active_enhancer_3way_2_df_1,TN_active_enhancer_3way_2_df_2,TN_active_enhancer_3way_2_df_3])
# TN_active_enhancer_3way_2_df = TN_active_enhancer_3way_2_df.sort_values(by='id')
# TN_active_enhancer_3way_2_ = pybed.BedTool.from_dataframe(TN_active_enhancer_3way_2_df)
# TN_active_enhancer_3way_2_ = TN_active_enhancer_3way_2_.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# TN_active_enhancer_3way_2_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# TN_active_enhancer_3way_2_df.columns = ["chr", "name", "start", "end"]
# TN_active_enhancer_3way_2_df = TN_active_enhancer_3way_2_df[["chr", "start", "end"]]
# TN_active_enhancer_3way_2_df["annotation"] = "TN_active_enhancer"
# TN_active_enhancer_3way_2_df = TN_active_enhancer_3way_2_df.drop_duplicates()

# MDAMB231_active_enhancer = MDAMB231_active_enhancer.subtract(TN_active_enhancer_3way_2, A=True, f=0.1, r=True)
# MDAMB436_active_enhancer = MDAMB436_active_enhancer.subtract(TN_active_enhancer_3way_2, A=True, f=0.1, r=True)
# MDAMB468_active_enhancer = MDAMB468_active_enhancer.subtract(TN_active_enhancer_3way_2, A=True, f=0.1, r=True)
# BT549_active_enhancer = BT549_active_enhancer.subtract(TN_active_enhancer_3way_2, A=True, f=0.1, r=True)

# ################################

# #Shared between BT 436 468
# TN_active_enhancer_3way_3 = BT549_active_enhancer.intersect(MDAMB436_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_3way_3 = TN_active_enhancer_3way_3.intersect(MDAMB468_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# TN_active_enhancer_3way_3 = TN_active_enhancer_3way_3.sort()
# TN_active_enhancer_3way_3 = TN_active_enhancer_3way_3.subtract(TN_super_enhancer, A=True, f=0.1)
# TN_active_enhancer_3way_3_df = pd.read_table(TN_active_enhancer_3way_3.fn,header=None) 
# TN_active_enhancer_3way_3_df = TN_active_enhancer_3way_3_df.drop(TN_active_enhancer_3way_3_df.columns[[3,7,11]],axis = 1)
# TN_active_enhancer_3way_3_df_1 = TN_active_enhancer_3way_3_df.iloc[:,0:3]
# TN_active_enhancer_3way_3_df_1.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_3_df_1["id"] = range(1, 1 + len(TN_active_enhancer_3way_3_df_1))
# TN_active_enhancer_3way_3_df_1["id"] = "SE_" + TN_active_enhancer_3way_3_df_1["id"].astype(str)
# TN_active_enhancer_3way_3_df_2 = TN_active_enhancer_3way_3_df.iloc[:,3:6]
# TN_active_enhancer_3way_3_df_2.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_3_df_2["id"] = range(1, 1 + len(TN_active_enhancer_3way_3_df_2))
# TN_active_enhancer_3way_3_df_2["id"] = "SE_" + TN_active_enhancer_3way_3_df_2["id"].astype(str)
# TN_active_enhancer_3way_3_df_3 = TN_active_enhancer_3way_3_df.iloc[:,6:9]
# TN_active_enhancer_3way_3_df_3.columns = ["chr", "start", "end"]
# TN_active_enhancer_3way_3_df_3["id"] = range(1, 1 + len(TN_active_enhancer_3way_3_df_3))
# TN_active_enhancer_3way_3_df_3["id"] = "SE_" + TN_active_enhancer_3way_3_df_3["id"].astype(str)
# TN_active_enhancer_3way_3_df = pd.concat([TN_active_enhancer_3way_3_df_1,TN_active_enhancer_3way_3_df_2,TN_active_enhancer_3way_3_df_3])
# TN_active_enhancer_3way_3_df = TN_active_enhancer_3way_3_df.sort_values(by='id')
# TN_active_enhancer_3way_3_ = pybed.BedTool.from_dataframe(TN_active_enhancer_3way_3_df)
# TN_active_enhancer_3way_3_ = TN_active_enhancer_3way_3_.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# TN_active_enhancer_3way_3_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# TN_active_enhancer_3way_3_df.columns = ["chr", "name", "start", "end"]
# TN_active_enhancer_3way_3_df = TN_active_enhancer_3way_3_df[["chr", "start", "end"]]
# TN_active_enhancer_3way_3_df["annotation"] = "TN_active_enhancer"
# TN_active_enhancer_3way_3_df = TN_active_enhancer_3way_3_df.drop_duplicates()

# MDAMB231_active_enhancer = MDAMB231_active_enhancer.subtract(TN_active_enhancer_3way_3, A=True, f=0.1, r=True)
# MDAMB436_active_enhancer = MDAMB436_active_enhancer.subtract(TN_active_enhancer_3way_3, A=True, f=0.1, r=True)
# MDAMB468_active_enhancer = MDAMB468_active_enhancer.subtract(TN_active_enhancer_3way_3, A=True, f=0.1, r=True)
# BT549_active_enhancer = BT549_active_enhancer.subtract(TN_active_enhancer_3way_3, A=True, f=0.1, r=True)

# ###############################################


# #Shared between 231 and 436
# MDAMB231_MDAMB436_AE = MDAMB231_active_enhancer.intersect(MDAMB436_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# MDAMB231_MDAMB436_AE_df = pd.read_table(MDAMB231_MDAMB436_AE.fn,header=None) 
# MDAMB231_MDAMB436_AE_df = MDAMB231_MDAMB436_AE_df.drop(MDAMB231_MDAMB436_AE_df.columns[[3,7]],axis = 1)
# MDAMB231_MDAMB436_AE_df_1 = MDAMB231_MDAMB436_AE_df.iloc[:,0:3]
# MDAMB231_MDAMB436_AE_df_1.columns = ["chr", "start", "end"]
# MDAMB231_MDAMB436_AE_df_1["id"] = range(1, 1 + len(MDAMB231_MDAMB436_AE_df_1))
# MDAMB231_MDAMB436_AE_df_1["id"] = "AE_" + MDAMB231_MDAMB436_AE_df_1["id"].astype(str)
# MDAMB231_MDAMB436_AE_df_2 = MDAMB231_MDAMB436_AE_df.iloc[:,3:6]
# MDAMB231_MDAMB436_AE_df_2.columns = ["chr", "start", "end"]
# MDAMB231_MDAMB436_AE_df_2["id"] = range(1, 1 + len(MDAMB231_MDAMB436_AE_df_2))
# MDAMB231_MDAMB436_AE_df_2["id"] = "AE_" + MDAMB231_MDAMB436_AE_df_2["id"].astype(str)
# MDAMB231_MDAMB436_AE_df = pd.concat([MDAMB231_MDAMB436_AE_df_1,MDAMB231_MDAMB436_AE_df_2])
# MDAMB231_MDAMB436_AE_df = MDAMB231_MDAMB436_AE_df.sort_values(by='id')
# MDAMB231_MDAMB436_AE_2 = pybed.BedTool.from_dataframe(MDAMB231_MDAMB436_AE_df)
# MDAMB231_MDAMB436_AE_2 = MDAMB231_MDAMB436_AE_2.sort()
# MDAMB231_MDAMB436_AE_2 = MDAMB231_MDAMB436_AE_2.subtract(TN_super_enhancer, A=True, f=0.1)
# MDAMB231_MDAMB436_AE_2 = MDAMB231_MDAMB436_AE_2.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# MDAMB231_MDAMB436_AE_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# MDAMB231_MDAMB436_AE_df.columns = ["chr", "name", "start", "end"]
# MDAMB231_MDAMB436_AE_df = MDAMB231_MDAMB436_AE_df[["chr", "start", "end"]]
# MDAMB231_MDAMB436_AE_df["annotation"] = "TN_active_enhancer"
# MDAMB231_MDAMB436_AE_df = MDAMB231_MDAMB436_AE_df.drop_duplicates()

# #Shared between 231 and 468
# MDAMB231_MDAMB468_AE = MDAMB231_active_enhancer.intersect(MDAMB468_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# MDAMB231_MDAMB468_AE_df = pd.read_table(MDAMB231_MDAMB468_AE.fn,header=None) 
# MDAMB231_MDAMB468_AE_df = MDAMB231_MDAMB468_AE_df.drop(MDAMB231_MDAMB468_AE_df.columns[[3,7]],axis = 1)
# MDAMB231_MDAMB468_AE_df_1 = MDAMB231_MDAMB468_AE_df.iloc[:,0:3]
# MDAMB231_MDAMB468_AE_df_1.columns = ["chr", "start", "end"]
# MDAMB231_MDAMB468_AE_df_1["id"] = range(1, 1 + len(MDAMB231_MDAMB468_AE_df_1))
# MDAMB231_MDAMB468_AE_df_1["id"] = "AE_" + MDAMB231_MDAMB468_AE_df_1["id"].astype(str)
# MDAMB231_MDAMB468_AE_df_2 = MDAMB231_MDAMB468_AE_df.iloc[:,3:6]
# MDAMB231_MDAMB468_AE_df_2.columns = ["chr", "start", "end"]
# MDAMB231_MDAMB468_AE_df_2["id"] = range(1, 1 + len(MDAMB231_MDAMB468_AE_df_2))
# MDAMB231_MDAMB468_AE_df_2["id"] = "AE_" + MDAMB231_MDAMB468_AE_df_2["id"].astype(str)
# MDAMB231_MDAMB468_AE_df = pd.concat([MDAMB231_MDAMB468_AE_df_1,MDAMB231_MDAMB468_AE_df_2])
# MDAMB231_MDAMB468_AE_df = MDAMB231_MDAMB468_AE_df.sort_values(by='id')
# MDAMB231_MDAMB468_AE_2 = pybed.BedTool.from_dataframe(MDAMB231_MDAMB468_AE_df)
# MDAMB231_MDAMB468_AE_2 = MDAMB231_MDAMB468_AE_2.sort()
# MDAMB231_MDAMB468_AE_2 = MDAMB231_MDAMB468_AE_2.subtract(TN_super_enhancer, A=True, f=0.1)
# MDAMB231_MDAMB468_AE_2 = MDAMB231_MDAMB468_AE_2.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# MDAMB231_MDAMB468_AE_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# MDAMB231_MDAMB468_AE_df.columns = ["chr", "name", "start", "end"]
# MDAMB231_MDAMB468_AE_df = MDAMB231_MDAMB468_AE_df[["chr", "start", "end"]]
# MDAMB231_MDAMB468_AE_df["annotation"] = "TN_active_enhancer"
# MDAMB231_MDAMB468_AE_df = MDAMB231_MDAMB468_AE_df.drop_duplicates()

# #Shared between 231 and BT549
# MDAMB231_BT549_AE = MDAMB231_active_enhancer.intersect(BT549_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# MDAMB231_BT549_AE_df = pd.read_table(MDAMB231_BT549_AE.fn,header=None) 
# MDAMB231_BT549_AE_df = MDAMB231_BT549_AE_df.drop(MDAMB231_BT549_AE_df.columns[[3,7]],axis = 1)
# MDAMB231_BT549_AE_df_1 = MDAMB231_BT549_AE_df.iloc[:,0:3]
# MDAMB231_BT549_AE_df_1.columns = ["chr", "start", "end"]
# MDAMB231_BT549_AE_df_1["id"] = range(1, 1 + len(MDAMB231_BT549_AE_df_1))
# MDAMB231_BT549_AE_df_1["id"] = "AE_" + MDAMB231_BT549_AE_df_1["id"].astype(str)
# MDAMB231_BT549_AE_df_2 = MDAMB231_BT549_AE_df.iloc[:,3:6]
# MDAMB231_BT549_AE_df_2.columns = ["chr", "start", "end"]
# MDAMB231_BT549_AE_df_2["id"] = range(1, 1 + len(MDAMB231_BT549_AE_df_2))
# MDAMB231_BT549_AE_df_2["id"] = "AE_" + MDAMB231_BT549_AE_df_2["id"].astype(str)
# MDAMB231_BT549_AE_df = pd.concat([MDAMB231_BT549_AE_df_1,MDAMB231_BT549_AE_df_2])
# MDAMB231_BT549_AE_df = MDAMB231_BT549_AE_df.sort_values(by='id')
# MDAMB231_BT549_AE_2 = pybed.BedTool.from_dataframe(MDAMB231_BT549_AE_df)
# MDAMB231_BT549_AE_2 = MDAMB231_BT549_AE_2.sort()
# MDAMB231_BT549_AE_2 = MDAMB231_BT549_AE_2.subtract(TN_super_enhancer, A=True, f=0.1)
# MDAMB231_BT549_AE_2 = MDAMB231_BT549_AE_2.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# MDAMB231_BT549_AE_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# MDAMB231_BT549_AE_df.columns = ["chr", "name", "start", "end"]
# MDAMB231_BT549_AE_df = MDAMB231_BT549_AE_df[["chr", "start", "end"]]
# MDAMB231_BT549_AE_df["annotation"] = "TN_active_enhancer"
# MDAMB231_BT549_AE_df = MDAMB231_BT549_AE_df.drop_duplicates()


# #Shared between 436 and 468
# MDAMB436_MDAMB468_AE = MDAMB436_active_enhancer.intersect(MDAMB468_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# MDAMB436_MDAMB468_AE_df = pd.read_table(MDAMB436_MDAMB468_AE.fn,header=None) 
# MDAMB436_MDAMB468_AE_df = MDAMB436_MDAMB468_AE_df.drop(MDAMB436_MDAMB468_AE_df.columns[[3,7]],axis = 1)
# MDAMB436_MDAMB468_AE_df_1 = MDAMB436_MDAMB468_AE_df.iloc[:,0:3]
# MDAMB436_MDAMB468_AE_df_1.columns = ["chr", "start", "end"]
# MDAMB436_MDAMB468_AE_df_1["id"] = range(1, 1 + len(MDAMB436_MDAMB468_AE_df_1))
# MDAMB436_MDAMB468_AE_df_1["id"] = "AE_" + MDAMB436_MDAMB468_AE_df_1["id"].astype(str)
# MDAMB436_MDAMB468_AE_df_2 = MDAMB436_MDAMB468_AE_df.iloc[:,3:6]
# MDAMB436_MDAMB468_AE_df_2.columns = ["chr", "start", "end"]
# MDAMB436_MDAMB468_AE_df_2["id"] = range(1, 1 + len(MDAMB436_MDAMB468_AE_df_2))
# MDAMB436_MDAMB468_AE_df_2["id"] = "AE_" + MDAMB436_MDAMB468_AE_df_2["id"].astype(str)
# MDAMB436_MDAMB468_AE_df = pd.concat([MDAMB436_MDAMB468_AE_df_1,MDAMB436_MDAMB468_AE_df_2])
# MDAMB436_MDAMB468_AE_df = MDAMB436_MDAMB468_AE_df.sort_values(by='id')
# MDAMB436_MDAMB468_AE_2 = pybed.BedTool.from_dataframe(MDAMB436_MDAMB468_AE_df)
# MDAMB436_MDAMB468_AE_2 = MDAMB436_MDAMB468_AE_2.sort()
# MDAMB436_MDAMB468_AE_2 = MDAMB436_MDAMB468_AE_2.subtract(TN_super_enhancer, A=True, f=0.1)
# MDAMB436_MDAMB468_AE_2 = MDAMB436_MDAMB468_AE_2.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# MDAMB436_MDAMB468_AE_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# MDAMB436_MDAMB468_AE_df.columns = ["chr", "name", "start", "end"]
# MDAMB436_MDAMB468_AE_df = MDAMB436_MDAMB468_AE_df[["chr", "start", "end"]]
# MDAMB436_MDAMB468_AE_df["annotation"] = "TN_active_enhancer"
# MDAMB436_MDAMB468_AE_df = MDAMB436_MDAMB468_AE_df.drop_duplicates()


# #Shared between 436 and BT549
# MDAMB436_BT549_AE = MDAMB436_active_enhancer.intersect(BT549_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# MDAMB436_BT549_AE_df = pd.read_table(MDAMB436_BT549_AE.fn,header=None) 
# MDAMB436_BT549_AE_df = MDAMB436_BT549_AE_df.drop(MDAMB436_BT549_AE_df.columns[[3,7]],axis = 1)
# MDAMB436_BT549_AE_df_1 = MDAMB436_BT549_AE_df.iloc[:,0:3]
# MDAMB436_BT549_AE_df_1.columns = ["chr", "start", "end"]
# MDAMB436_BT549_AE_df_1["id"] = range(1, 1 + len(MDAMB436_BT549_AE_df_1))
# MDAMB436_BT549_AE_df_1["id"] = "AE_" + MDAMB436_BT549_AE_df_1["id"].astype(str)
# MDAMB436_BT549_AE_df_2 = MDAMB436_BT549_AE_df.iloc[:,3:6]
# MDAMB436_BT549_AE_df_2.columns = ["chr", "start", "end"]
# MDAMB436_BT549_AE_df_2["id"] = range(1, 1 + len(MDAMB436_BT549_AE_df_2))
# MDAMB436_BT549_AE_df_2["id"] = "AE_" + MDAMB436_BT549_AE_df_2["id"].astype(str)
# MDAMB436_BT549_AE_df = pd.concat([MDAMB436_BT549_AE_df_1,MDAMB436_BT549_AE_df_2])
# MDAMB436_BT549_AE_df = MDAMB436_BT549_AE_df.sort_values(by='id')
# MDAMB436_BT549_AE_2 = pybed.BedTool.from_dataframe(MDAMB436_BT549_AE_df)
# MDAMB436_BT549_AE_2 = MDAMB436_BT549_AE_2.sort()
# MDAMB436_BT549_AE_2 = MDAMB436_BT549_AE_2.subtract(TN_super_enhancer, A=True, f=0.1)
# MDAMB436_BT549_AE_2 = MDAMB436_BT549_AE_2.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# MDAMB436_BT549_AE_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# MDAMB436_BT549_AE_df.columns = ["chr", "name", "start", "end"]
# MDAMB436_BT549_AE_df = MDAMB436_BT549_AE_df[["chr", "start", "end"]]
# MDAMB436_BT549_AE_df["annotation"] = "TN_active_enhancer"
# MDAMB436_BT549_AE_df = MDAMB436_BT549_AE_df.drop_duplicates()


# #Shared between 468 and BT549
# MDAMB468_BT549_AE = MDAMB468_active_enhancer.intersect(BT549_active_enhancer, wa=True, wb=True, f=0.1, r=True)
# MDAMB468_BT549_AE_df = pd.read_table(MDAMB468_BT549_AE.fn,header=None) 
# MDAMB468_BT549_AE_df = MDAMB468_BT549_AE_df.drop(MDAMB468_BT549_AE_df.columns[[3,7]],axis = 1)
# MDAMB468_BT549_AE_df_1 = MDAMB468_BT549_AE_df.iloc[:,0:3]
# MDAMB468_BT549_AE_df_1.columns = ["chr", "start", "end"]
# MDAMB468_BT549_AE_df_1["id"] = range(1, 1 + len(MDAMB468_BT549_AE_df_1))
# MDAMB468_BT549_AE_df_1["id"] = "AE_" + MDAMB468_BT549_AE_df_1["id"].astype(str)
# MDAMB468_BT549_AE_df_2 = MDAMB468_BT549_AE_df.iloc[:,3:6]
# MDAMB468_BT549_AE_df_2.columns = ["chr", "start", "end"]
# MDAMB468_BT549_AE_df_2["id"] = range(1, 1 + len(MDAMB468_BT549_AE_df_2))
# MDAMB468_BT549_AE_df_2["id"] = "AE_" + MDAMB468_BT549_AE_df_2["id"].astype(str)
# MDAMB468_BT549_AE_df = pd.concat([MDAMB468_BT549_AE_df_1,MDAMB468_BT549_AE_df_2])
# MDAMB468_BT549_AE_df = MDAMB468_BT549_AE_df.sort_values(by='id')
# MDAMB468_BT549_AE_2 = pybed.BedTool.from_dataframe(MDAMB468_BT549_AE_df)
# MDAMB468_BT549_AE_2 = MDAMB468_BT549_AE_2.sort()
# MDAMB468_BT549_AE_2 = MDAMB468_BT549_AE_2.subtract(TN_super_enhancer, A=True, f=0.1)
# MDAMB468_BT549_AE_2 = MDAMB468_BT549_AE_2.groupby(g=[1, 4], c=[2,3], o=['min','max']).saveas('/home/darragh/New/Regulatory_elements/test')
# MDAMB468_BT549_AE_df = pd.read_table('/home/darragh/New/Regulatory_elements/test',header=None)
# MDAMB468_BT549_AE_df.columns = ["chr", "name", "start", "end"]
# MDAMB468_BT549_AE_df = MDAMB468_BT549_AE_df[["chr", "start", "end"]]
# MDAMB468_BT549_AE_df["annotation"] = "TN_active_enhancer"
# MDAMB468_BT549_AE_df = MDAMB468_BT549_AE_df.drop_duplicates()

# TN_active_enhancer_df = pd.concat([TN_active_enhancer_all_df,TN_active_enhancer_3way_2_df, TN_active_enhancer_3way_2_df, TN_active_enhancer_3way_3_df, MDAMB231_MDAMB436_AE_df, MDAMB231_MDAMB468_AE_df, MDAMB231_BT549_AE_df, MDAMB436_MDAMB468_AE_df, MDAMB436_BT549_AE_df, MDAMB468_BT549_AE_df   ])
# TN_reg_elements_df = pd.concat([TN_active_promoter_df, TN_polycomb_promoter_df, TN_super_enhancer_df, TN_active_enhancer_df])

# TN_reg_elements_df.to_csv("/home/darragh/New/Regulatory_elements/TN_reg_elements.txt", sep='\t', index=False, header=None)
# Out:
# /tmp/ipykernel_2046374/3662071938.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TN_active_promoter_df["annotation"] = "TN_active_promoter"
#         chr      start        end          annotation
# 24306  chr1     892973     897190  TN_active_promoter
# 24307  chr1    1050242    1052504  TN_active_promoter
# 24308  chr1   10269657   10272253  TN_active_promoter
# 24309  chr1  161048397  161063777  TN_active_promoter
# 24310  chr1  161048397  161063777  TN_active_promoter
# ...     ...        ...        ...                 ...
# 37719  chrX  154611284  154614343  TN_active_promoter
# 37720  chrX  154686339  154688773  TN_active_promoter
# 37721  chrX  155109929  155112028  TN_active_promoter
# ...

# %% [markdown]
# # #Identify the regulatory elements which are common or unique to all subtypes

# %%
#Identify the regulatory elements which are common or unique to all subtypes

#########
##Primary
#########
Primary_regs_df = pd.read_table("/home/darragh/New/Regulatory_elements/Primary_reg_elements.txt",header=None)
Primary_regs_df.columns = ['chr', 'start', 'end', 'annotation']

#dfs
Primary_active_promoter_df = Primary_regs_df.loc[Primary_regs_df['annotation'] == "Primary_active_promoter"]
Primary_polycomb_promoter_df = Primary_regs_df.loc[Primary_regs_df['annotation'] == "Primary_polycomb_promoter"]
Primary_active_enhancer_df = Primary_regs_df.loc[Primary_regs_df['annotation'] == "Primary_active_enhancer"]
Primary_super_enhancer_df = Primary_regs_df.loc[Primary_regs_df['annotation'] == "Primary_super_enhancer"]

#beds
Primary_active_promoter = pybed.BedTool.from_dataframe(Primary_active_promoter_df)
Primary_polycomb_promoter = pybed.BedTool.from_dataframe(Primary_polycomb_promoter_df)
Primary_active_enhancer = pybed.BedTool.from_dataframe(Primary_active_enhancer_df)
Primary_super_enhancer = pybed.BedTool.from_dataframe(Primary_super_enhancer_df)

#############
##ER
#############
ER_regs_df = pd.read_table("/home/darragh/New/Regulatory_elements/ER_reg_elements.txt",header=None)
ER_regs_df.columns = ['chr', 'start', 'end', 'annotation']

#dfs
ER_active_promoter_df = ER_regs_df.loc[ER_regs_df['annotation'] == "ER_active_promoter"]
ER_polycomb_promoter_df = ER_regs_df.loc[ER_regs_df['annotation'] == "ER_polycomb_promoter"]
ER_active_enhancer_df = ER_regs_df.loc[ER_regs_df['annotation'] == "ER_active_enhancer"]
ER_super_enhancer_df = ER_regs_df.loc[ER_regs_df['annotation'] == "ER_super_enhancer"]

#beds
ER_active_promoter = pybed.BedTool.from_dataframe(ER_active_promoter_df)
ER_polycomb_promoter = pybed.BedTool.from_dataframe(ER_polycomb_promoter_df)
ER_active_enhancer = pybed.BedTool.from_dataframe(ER_active_enhancer_df)
ER_super_enhancer = pybed.BedTool.from_dataframe(ER_super_enhancer_df)

#############
##TN
#############
TN_regs_df = pd.read_table("/home/darragh/New/Regulatory_elements/TN_reg_elements.txt",header=None)
TN_regs_df.columns = ['chr', 'start', 'end', 'annotation']

#dfs
TN_active_promoter_df = TN_regs_df.loc[TN_regs_df['annotation'] == "TN_active_promoter"]
TN_polycomb_promoter_df = TN_regs_df.loc[TN_regs_df['annotation'] == "TN_polycomb_promoter"]
TN_active_enhancer_df = TN_regs_df.loc[TN_regs_df['annotation'] == "TN_active_enhancer"]
TN_super_enhancer_df = TN_regs_df.loc[TN_regs_df['annotation'] == "TN_super_enhancer"]

#beds
TN_active_promoter = pybed.BedTool.from_dataframe(TN_active_promoter_df)
TN_polycomb_promoter = pybed.BedTool.from_dataframe(TN_polycomb_promoter_df)
TN_active_enhancer = pybed.BedTool.from_dataframe(TN_active_enhancer_df)
TN_super_enhancer = pybed.BedTool.from_dataframe(TN_super_enhancer_df)

#H3K27ac
H3K27ac_peak_HMEC = pybed.BedTool("/home/darragh/New/ChIP-seq/HMEC/H3K27ac/results/Peak/HMEC_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_MCF10A = pybed.BedTool("/home/darragh/New/ChIP-seq/MCF10A/H3K27ac/results/Peak/MCF10A_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_MCF7 = pybed.BedTool("/home/darragh/New/ChIP-seq/MCF7/H3K27ac/results/Peak/MCF7_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_T47D = pybed.BedTool("/home/darragh/New/ChIP-seq/T47D_2/H3K27ac/results/Peak/SRR13755439_peaks.preprocessed.bed")
H3K27ac_peak_MDAMB231 = pybed.BedTool("/home/darragh/New/ChIP-seq/MDAMB231/H3K27ac/results/Peak/MDAMB231_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_MDAMB436 = pybed.BedTool("/home/darragh/New/ChIP-seq/MDAMB436/H3K27ac/results/Peak/MDAMB436_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_MDAMB468 = pybed.BedTool("/home/darragh/New/ChIP-seq/MDAMB468/H3K27ac/results/Peak/MDAMB468_H3K27ac_peaks.preprocessed.bed")
H3K27ac_peak_BT549 = pybed.BedTool("/home/darragh/New/ChIP-seq/BT549/H3K27ac/results/Bam/SRR13755447_peaks.processed.narrowPeak")

SUZ12_peak_HMEC = pybed.BedTool("/home/darragh/New/ChIP-seq/HMEC/SUZ12/SUZ12_peaks.preprocessed.bed")
SUZ12_peak_MCF7 = pybed.BedTool("/home/darragh/New/ChIP-seq/MCF7/SUZ12/SUZ12_peaks.preprocessed.bed")
SUZ12_peak_MDAMB468 = pybed.BedTool("/home/darragh/New/ChIP-seq/MDAMB468/SUZ12/SUZ12_peaks.preprocessed.bed")


#What are the common regs? Those regs which are found in all of our breast epithelial cells.

#Common active_promoter

Common_active_promoter = Primary_active_promoter.intersect(ER_active_promoter, wa=True, wb=True, f=0.1, r=True)
Common_active_promoter = Common_active_promoter.intersect(TN_active_promoter, wa=True, wb=True, f=0.1, r=True)
Common_active_promoter_df = pd.read_table(Common_active_promoter.fn,header=None)
Common_active_promoter_df = Common_active_promoter_df.drop(Common_active_promoter_df.columns[[3,7,11]],axis = 1)
Common_active_promoter_df_1 = Common_active_promoter_df.iloc[:,0:3]
Common_active_promoter_df_1.columns = ["chr", "start", "end"]
Common_active_promoter_df_1 = Common_active_promoter_df_1.reset_index()
Common_active_promoter_df_1 = Common_active_promoter_df_1[["chr", "start", "end"]]
Common_active_promoter_df_1["id"] = range(1, 1 + len(Common_active_promoter_df_1))
Common_active_promoter_df_1["id"] = "Common_" + Common_active_promoter_df_1["id"].astype(str)
Common_active_promoter_df_2 = Common_active_promoter_df.iloc[:,3:6]
Common_active_promoter_df_2.columns = ["chr", "start", "end"]
Common_active_promoter_df_2 = Common_active_promoter_df_2.reset_index()
Common_active_promoter_df_2 = Common_active_promoter_df_2[["chr", "start", "end"]]
Common_active_promoter_df_2["id"] = range(1, 1 + len(Common_active_promoter_df_2))
Common_active_promoter_df_2["id"] = "Common_" + Common_active_promoter_df_2["id"].astype(str)
Common_active_promoter_df_3 = Common_active_promoter_df.iloc[:,6:10]
Common_active_promoter_df_3.columns = ["chr", "start", "end"]
Common_active_promoter_df_3 = Common_active_promoter_df_3.reset_index()
Common_active_promoter_df_3 = Common_active_promoter_df_3[["chr", "start", "end"]]
Common_active_promoter_df_3["id"] = range(1, 1 + len(Common_active_promoter_df_3))
Common_active_promoter_df_3["id"] = "Common_" + Common_active_promoter_df_3["id"].astype(str)
Common_active_promoter_df = pd.concat([Common_active_promoter_df_1,Common_active_promoter_df_2,Common_active_promoter_df_3])
Common_active_promoter_df = Common_active_promoter_df.sort_values(by='id')
Common_active_promoter_df = Common_active_promoter_df.reset_index()
Common_active_promoter_df = Common_active_promoter_df[["chr", "start", "end", "id"]]
Common_active_promoter_df = Common_active_promoter_df.groupby(['chr','id']).agg({'start': ['min'],'end': ['max']} ).reset_index()
Common_active_promoter_df.columns = ['chr','id', 'start', 'end']
Common_active_promoter_df = Common_active_promoter_df[['chr','start','end','id']]
display(Common_active_promoter_df)

#Common polycomb_promoter
Common_polycomb_promoter = Primary_polycomb_promoter.intersect(ER_polycomb_promoter, wa=True, wb=True, f=0.1, r=True)
Common_polycomb_promoter = Common_polycomb_promoter.intersect(TN_polycomb_promoter, wa=True, wb=True, f=0.1, r=True)
Common_polycomb_promoter_df = pd.read_table(Common_polycomb_promoter.fn,header=None)
Common_polycomb_promoter_df = Common_polycomb_promoter_df.drop(Common_polycomb_promoter_df.columns[[3,7,11]],axis = 1)
Common_polycomb_promoter_df_1 = Common_polycomb_promoter_df.iloc[:,0:3]
Common_polycomb_promoter_df_1.columns = ["chr", "start", "end"]
Common_polycomb_promoter_df_1 = Common_polycomb_promoter_df_1.reset_index()
Common_polycomb_promoter_df_1 = Common_polycomb_promoter_df_1[["chr", "start", "end"]]
Common_polycomb_promoter_df_1["id"] = range(1, 1 + len(Common_polycomb_promoter_df_1))
Common_polycomb_promoter_df_1["id"] = "Common_" + Common_polycomb_promoter_df_1["id"].astype(str)
Common_polycomb_promoter_df_2 = Common_polycomb_promoter_df.iloc[:,3:6]
Common_polycomb_promoter_df_2.columns = ["chr", "start", "end"]
Common_polycomb_promoter_df_2 = Common_polycomb_promoter_df_2.reset_index()
Common_polycomb_promoter_df_2 = Common_polycomb_promoter_df_2[["chr", "start", "end"]]
Common_polycomb_promoter_df_2["id"] = range(1, 1 + len(Common_polycomb_promoter_df_2))
Common_polycomb_promoter_df_2["id"] = "Common_" + Common_polycomb_promoter_df_2["id"].astype(str)
Common_polycomb_promoter_df_3 = Common_polycomb_promoter_df.iloc[:,6:10]
Common_polycomb_promoter_df_3.columns = ["chr", "start", "end"]
Common_polycomb_promoter_df_3 = Common_polycomb_promoter_df_3.reset_index()
Common_polycomb_promoter_df_3 = Common_polycomb_promoter_df_3[["chr", "start", "end"]]
Common_polycomb_promoter_df_3["id"] = range(1, 1 + len(Common_polycomb_promoter_df_3))
Common_polycomb_promoter_df_3["id"] = "Common_" + Common_polycomb_promoter_df_3["id"].astype(str)
Common_polycomb_promoter_df = pd.concat([Common_polycomb_promoter_df_1,Common_polycomb_promoter_df_2,Common_polycomb_promoter_df_3])
Common_polycomb_promoter_df = Common_polycomb_promoter_df.sort_values(by='id')
Common_polycomb_promoter_df = Common_polycomb_promoter_df.reset_index()
Common_polycomb_promoter_df = Common_polycomb_promoter_df[["chr", "start", "end", "id"]]
Common_polycomb_promoter_df = Common_polycomb_promoter_df.groupby(['chr','id']).agg({'start': ['min'],'end': ['max']} ).reset_index()
Common_polycomb_promoter_df.columns = ['chr','id', 'start', 'end']
Common_polycomb_promoter_df = Common_polycomb_promoter_df[['chr','start','end','id']]
display(Common_polycomb_promoter_df)

#Common active_enhancer
Common_active_enhancer = Primary_active_enhancer.intersect(ER_active_enhancer, wa=True, wb=True, f=0.1, r=True)
Common_active_enhancer = Common_active_enhancer.intersect(TN_active_enhancer, wa=True, wb=True, f=0.1, r=True)
Common_active_enhancer_df = pd.read_table(Common_active_enhancer.fn,header=None)
Common_active_enhancer_df = Common_active_enhancer_df.drop(Common_active_enhancer_df.columns[[3,7,11]],axis = 1)
Common_active_enhancer_df_1 = Common_active_enhancer_df.iloc[:,0:3]
Common_active_enhancer_df_1.columns = ["chr", "start", "end"]
Common_active_enhancer_df_1 = Common_active_enhancer_df_1.reset_index()
Common_active_enhancer_df_1 = Common_active_enhancer_df_1[["chr", "start", "end"]]
Common_active_enhancer_df_1["id"] = range(1, 1 + len(Common_active_enhancer_df_1))
Common_active_enhancer_df_1["id"] = "Common_" + Common_active_enhancer_df_1["id"].astype(str)
Common_active_enhancer_df_2 = Common_active_enhancer_df.iloc[:,3:6]
Common_active_enhancer_df_2.columns = ["chr", "start", "end"]
Common_active_enhancer_df_2 = Common_active_enhancer_df_2.reset_index()
Common_active_enhancer_df_2 = Common_active_enhancer_df_2[["chr", "start", "end"]]
Common_active_enhancer_df_2["id"] = range(1, 1 + len(Common_active_enhancer_df_2))
Common_active_enhancer_df_2["id"] = "Common_" + Common_active_enhancer_df_2["id"].astype(str)
Common_active_enhancer_df_3 = Common_active_enhancer_df.iloc[:,6:10]
Common_active_enhancer_df_3.columns = ["chr", "start", "end"]
Common_active_enhancer_df_3 = Common_active_enhancer_df_3.reset_index()
Common_active_enhancer_df_3 = Common_active_enhancer_df_3[["chr", "start", "end"]]
Common_active_enhancer_df_3["id"] = range(1, 1 + len(Common_active_enhancer_df_3))
Common_active_enhancer_df_3["id"] = "Common_" + Common_active_enhancer_df_3["id"].astype(str)
Common_active_enhancer_df = pd.concat([Common_active_enhancer_df_1,Common_active_enhancer_df_2,Common_active_enhancer_df_3])
Common_active_enhancer_df = Common_active_enhancer_df.sort_values(by='id')
Common_active_enhancer_df = Common_active_enhancer_df.reset_index()
Common_active_enhancer_df = Common_active_enhancer_df[["chr", "start", "end", "id"]]
Common_active_enhancer_df = Common_active_enhancer_df.groupby(['chr','id']).agg({'start': ['min'],'end': ['max']} ).reset_index()
Common_active_enhancer_df.columns = ['chr','id', 'start', 'end']
Common_active_enhancer_df = Common_active_enhancer_df[['chr','start','end','id']]
display(Common_active_enhancer_df)

#Common super_enhancer
Common_super_enhancer = Primary_super_enhancer.intersect(ER_super_enhancer, wa=True, wb=True, f=0.1, r=True)
Common_super_enhancer = Common_super_enhancer.intersect(TN_super_enhancer, wa=True, wb=True, f=0.1, r=True)
Common_super_enhancer_df = pd.read_table(Common_super_enhancer.fn,header=None)
Common_super_enhancer_df = Common_super_enhancer_df.drop(Common_super_enhancer_df.columns[[3,7,11]],axis = 1)
Common_super_enhancer_df_1 = Common_super_enhancer_df.iloc[:,0:3]
Common_super_enhancer_df_1.columns = ["chr", "start", "end"]
Common_super_enhancer_df_1 = Common_super_enhancer_df_1.reset_index()
Common_super_enhancer_df_1 = Common_super_enhancer_df_1[["chr", "start", "end"]]
Common_super_enhancer_df_1["id"] = range(1, 1 + len(Common_super_enhancer_df_1))
Common_super_enhancer_df_1["id"] = "Common_" + Common_super_enhancer_df_1["id"].astype(str)
Common_super_enhancer_df_2 = Common_super_enhancer_df.iloc[:,3:6]
Common_super_enhancer_df_2.columns = ["chr", "start", "end"]
Common_super_enhancer_df_2 = Common_super_enhancer_df_2.reset_index()
Common_super_enhancer_df_2 = Common_super_enhancer_df_2[["chr", "start", "end"]]
Common_super_enhancer_df_2["id"] = range(1, 1 + len(Common_super_enhancer_df_2))
Common_super_enhancer_df_2["id"] = "Common_" + Common_super_enhancer_df_2["id"].astype(str)
Common_super_enhancer_df_3 = Common_super_enhancer_df.iloc[:,6:10]
Common_super_enhancer_df_3.columns = ["chr", "start", "end"]
Common_super_enhancer_df_3 = Common_super_enhancer_df_3.reset_index()
Common_super_enhancer_df_3 = Common_super_enhancer_df_3[["chr", "start", "end"]]
Common_super_enhancer_df_3["id"] = range(1, 1 + len(Common_super_enhancer_df_3))
Common_super_enhancer_df_3["id"] = "Common_" + Common_super_enhancer_df_3["id"].astype(str)
Common_super_enhancer_df = pd.concat([Common_super_enhancer_df_1,Common_super_enhancer_df_2,Common_super_enhancer_df_3])
Common_super_enhancer_df = Common_super_enhancer_df.sort_values(by='id')
Common_super_enhancer_df = Common_super_enhancer_df.reset_index()
Common_super_enhancer_df = Common_super_enhancer_df[["chr", "start", "end", "id"]]
Common_super_enhancer_df = Common_super_enhancer_df.groupby(['chr','id']).agg({'start': ['min'],'end': ['max']} ).reset_index()
Common_super_enhancer_df.columns = ['chr','id', 'start', 'end']
Common_super_enhancer_df = Common_super_enhancer_df[['chr','start','end','id']]
display(Common_super_enhancer_df)
# Out:
#         chr      start        end            id
# 0      chr1     900901     904038      Common_1
# 1      chr1  202317303  202319373     Common_10
# 2      chr1  207488907  207498227    Common_100
# 3      chr1   63152601   63156735   Common_1000
# 4      chr1   63248745   63251039   Common_1001
# ...     ...        ...        ...           ...
# 18420  chrX  154297574  154301244  Common_18421
# 18421  chrX  154297574  154301244  Common_18422
# 18422  chrX  154611282  154614343  Common_18423
# 18423  chrX  154686339  154688773  Common_18424
# 18424  chrX  155109929  155112028  Common_18425
#
# [18425 rows x 4 columns]
#       chr      start        end          id
# 0    chr1   48174026   48176386    Common_1
# 1    chr1  107682246  107686067   Common_10
# 2    chr1  112531352  112534353   Common_11
# 3    chr1  112531352  112534353   Common_12
# 4    chr1  116380167  116384714   Common_13
# ..    ...        ...        ...         ...
# 531  chrX   71524097   71527867  Common_532
# ...

# %%
#Primary unique
Primary_regs_df = pd.read_table("/home/darragh/New/Regulatory_elements/Primary_reg_elements.txt",header=None)
Primary_regs_df.columns = ['chr', 'start', 'end', 'annotation']
#dfs
Primary_active_promoter_df = Primary_regs_df.loc[Primary_regs_df['annotation'] == "Primary_active_promoter"]
Primary_polycomb_promoter_df = Primary_regs_df.loc[Primary_regs_df['annotation'] == "Primary_polycomb_promoter"]
Primary_active_enhancer_df = Primary_regs_df.loc[Primary_regs_df['annotation'] == "Primary_active_enhancer"]
Primary_super_enhancer_df = Primary_regs_df.loc[Primary_regs_df['annotation'] == "Primary_super_enhancer"]

#beds
Primary_active_promoter = pybed.BedTool.from_dataframe(Primary_active_promoter_df)
Primary_polycomb_promoter = pybed.BedTool.from_dataframe(Primary_polycomb_promoter_df)
Primary_active_enhancer = pybed.BedTool.from_dataframe(Primary_active_enhancer_df)
Primary_super_enhancer = pybed.BedTool.from_dataframe(Primary_super_enhancer_df)


Primary_active_promoter = Primary_active_promoter.subtract(H3K27ac_peak_MCF7, A=True)
Primary_active_promoter = Primary_active_promoter.subtract(H3K27ac_peak_T47D, A=True)
Primary_active_promoter = Primary_active_promoter.subtract(H3K27ac_peak_MDAMB231, A=True)
Primary_active_promoter = Primary_active_promoter.subtract(H3K27ac_peak_MDAMB436, A=True)
Primary_active_promoter = Primary_active_promoter.subtract(H3K27ac_peak_MDAMB468, A=True)
Primary_active_promoter = Primary_active_promoter.subtract(H3K27ac_peak_BT549, A=True)
Primary_active_promoter_unique = pd.read_table(Primary_active_promoter.fn, header=None)
display(Primary_active_promoter_unique)

Primary_active_enhancer = Primary_active_enhancer.subtract(H3K27ac_peak_MCF7, A=True)
Primary_active_enhancer = Primary_active_enhancer.subtract(H3K27ac_peak_T47D, A=True)
Primary_active_enhancer = Primary_active_enhancer.subtract(H3K27ac_peak_MDAMB231, A=True)
Primary_active_enhancer = Primary_active_enhancer.subtract(H3K27ac_peak_MDAMB436, A=True)
Primary_active_enhancer = Primary_active_enhancer.subtract(H3K27ac_peak_MDAMB468, A=True)
Primary_active_enhancer = Primary_active_enhancer.subtract(H3K27ac_peak_BT549, A=True)
Primary_active_enhancer_unique = pd.read_table(Primary_active_enhancer.fn, header=None)
display(Primary_active_enhancer_unique)

Primary_super_enhancer = Primary_super_enhancer.subtract(H3K27ac_peak_MCF7, A=True)
Primary_super_enhancer = Primary_super_enhancer.subtract(H3K27ac_peak_T47D, A=True)
Primary_super_enhancer = Primary_super_enhancer.subtract(H3K27ac_peak_MDAMB231, A=True)
Primary_super_enhancer = Primary_super_enhancer.subtract(H3K27ac_peak_MDAMB436, A=True)
Primary_super_enhancer = Primary_super_enhancer.subtract(H3K27ac_peak_MDAMB468, A=True)
Primary_super_enhancer = Primary_super_enhancer.subtract(H3K27ac_peak_BT549, A=True)
Primary_super_enhancer_unique = pd.read_table(Primary_super_enhancer.fn, header=None)
display(Primary_super_enhancer_unique)

Primary_polycomb_promoter = Primary_polycomb_promoter.subtract(SUZ12_peak_MCF7, A=True)
Primary_polycomb_promoter = Primary_polycomb_promoter.subtract(SUZ12_peak_MDAMB468, A=True)
Primary_polycomb_promoter_unique = pd.read_table(Primary_polycomb_promoter.fn, header=None)
display(Primary_polycomb_promoter_unique)
# Out:
#         0          1          2                        3
# 0    chr1  205195196  205196089  Primary_active_promoter
# 1    chr1    1356462    1357179  Primary_active_promoter
# 2    chr1   23491845   23492358  Primary_active_promoter
# 3    chr1   25762278   25762574  Primary_active_promoter
# 4    chr1   62660246   62661568  Primary_active_promoter
# ..    ...        ...        ...                      ...
# 126  chr9   95298125   95299153  Primary_active_promoter
# 127  chr9  127212243  127213594  Primary_active_promoter
# 128  chrX   40976187   40976654  Primary_active_promoter
# 129  chrX   65857964   65859033  Primary_active_promoter
# 130  chrX   78620877   78623277  Primary_active_promoter
#
# [131 rows x 4 columns]
#           0          1          2                        3
# 0     chr12    4592649    4594266  Primary_active_enhancer
# 1      chr2  238939448  238943032  Primary_active_enhancer
# 2      chr2  238939448  238943083  Primary_active_enhancer
# ...
