# %%
library(peakC)

# %% [markdown]
# # ATM

# %%
# HMEC rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/HMEC_rep1/pipe4c/WIG/HMEC_ATM_rep1_WIN21.mod.wig", vp.pos =108093794, window=700e3)
res = single.analysis(data$data, vp.pos=108093794)
plot_C(res,y.max=75)
# Out:
# plot without title

# %%
# HMEC rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/HMEC_rep2/pipe4c/WIG/HMEC_ATM_rep2_WIN21.mod.wig", vp.pos =108093794, window=700e3)
res = single.analysis(data$data, vp.pos=108093794)
plot_C(res,y.max=75)

peaks = as.data.frame(res$peak)
peaks$chr = "chr11"
colnames(peaks) = c("start", "chr")
peaks$end = peaks$start
peaks = peaks[,c("chr", "start", "end")]
write.table(peaks, '/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/HMEC_rep2/pipe4c/WIG/peaks.bed',row.names = F, col.names =F, sep = "\t", quote = FALSE)
head(peaks)
# Out:
#   chr   start     end
# 1 chr11 107671411 107671411
# 2 chr11 107768884 107768884
# 3 chr11 107828860 107828860
# 4 chr11 108034045 108034045
# 5 chr11 108443241 108443241
# 6 chr11 108443320 108443320
# plot without title

# %%
#HMEC rep1 &rep2
library(peakC)
viewpoint = 108093794
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/HMEC_rep1/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=25)
# Out:
# plot without title

# %%
peaks = as.data.frame(res$peak)
peaks$chr = "chr11"
colnames(peaks) = c("start", "chr")
peaks$end = peaks$start
peaks = peaks[,c("chr", "start", "end")]
write.table(peaks, '/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/HMEC_rep1/peakcalling/peaks.bed',row.names = F, col.names =F, sep = "\t", quote = FALSE)
head(peaks)
# Out:
#   chr   start     end
# 1 chr11 107764994 107764994
# 2 chr11 107764999 107764999
# 3 chr11 107765010 107765010
# 4 chr11 107765015 107765015
# 5 chr11 107765025 107765025
# 6 chr11 107765030 107765030

# %%
# MCF7 rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/MCF7_R1_ATM_47/pipe4c/WIG/MCF7_ATM_rep1_WIN21.mod.wig", vp.pos =108093794, window=700e3)
res = single.analysis(data$data, vp.pos=108093794)
plot_C(res,y.max=75)
# Out:
# plot without title

# %%
# MCF7 rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/MCF7_R2_ATM_48/pipe4c/WIG/MCF7_ATM_rep2_WIN21.mod.wig", vp.pos =108093794, window=700e3)
res = single.analysis(data$data, vp.pos=108093794)
plot_C(res,y.max=75)
# Out:
# plot without title

# %%
# MCF7 rep1 &rep2
viewpoint = 108093794
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/MCF7_R1_ATM_47/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=25)
# Out:
# plot without title

# %%
# MDAMB rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/MDAM_R1_ATM_49/pipe4c/WIG/MDAMB468_ATM_rep1_WIN21.mod.wig", vp.pos =108093794, window=700e3)
res = single.analysis(data$data, vp.pos=108093794)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# MDAMB rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/MDAM_R2_ATM_50/pipe4c/WIG/MDAMB468_ATM_rep2_WIN21.mod.wig", vp.pos =108093794, window=700e3)
res = single.analysis(data$data, vp.pos=108093794)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# MDAMB rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/MDAM_R3_ATM_51/pipe4c/WIG/MDAMB468_ATM_rep3_WIN21.mod.wig", vp.pos =108093794, window=700e3)
res = single.analysis(data$data, vp.pos=108093794)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# MDAMB rep1 & rep2 & rep3
viewpoint = 108093794
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_ATM/MDAM_R1_ATM_49/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %% [markdown]
# # BARD1

# %%
#HMEC rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/HMEC_rep1/pipe4c/WIG/HMEC_R1_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=25)
# Out:
# plot without title

# %%
# HMEC rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/HMEC_R2_BARD1_20/pipe4c/WIG/HMEC_R2_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=25)
# Out:
# plot without title

# %%
# HMEC rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/HMEC_rep3/pipe4c/WIG/HMEC_R3_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=25)
# Out:
# plot without title

# %%
#HMEC rep1 & rep2 & rep3
viewpoint = 215675269
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/HMEC_rep1/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=25)

peaks = as.data.frame(res$peak)
peaks$chr = "chr2"
colnames(peaks) = c("start", "chr")
peaks$end = peaks$start
peaks = peaks[,c("chr", "start", "end")]
write.table(peaks, '/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/HMEC_rep1/peakcalling/peaks.bed',row.names = F, col.names =F, sep = "\t", quote = FALSE)
head(peaks)
# Out:
#   chr  start     end
# 1 chr2 215189968 215189968
# 2 chr2 215189973 215189973
# 3 chr2 215189978 215189978
# 4 chr2 215190559 215190559
# 5 chr2 215190564 215190564
# 6 chr2 215190865 215190865
# plot without title

# %%
# MCF7 rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/MCF7_R1_BARD1_17/pipe4c/WIG/MCF7_R1_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# MCF7 rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/MCF7_R2_BARD1_18/pipe4c/WIG/MCF7_R2_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=25)
# Out:
# plot without title

# %%
# MCF7 rep4
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/MCF7_rep4/pipe4c/WIG/MCF7_R4_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
#MCF7 rep1 & rep2 & rep3
viewpoint = 215675269
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/MCF7_R1_BARD1_17/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
# MDAMB rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/MDAM_R2_BARD1_19/pipe4c/WIG/MDAMB468_R3_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
# MDAMB rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/MDAMB_rep3/pipe4c/WIG/MDAMB468_R1_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=100)
# Out:
# plot without title

# %%
# MDAMB468 rep4
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/MDAMB_rep4/pipe4c/WIG/MDAMB468_R2_BARD1_WIN21.mod.wig", vp.pos =215675269, window=700e3)
res = single.analysis(data$data, vp.pos=215675269)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
#MDAMB rep1 & rep2 & rep3
viewpoint = 215675269
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BARD1/MDAM_R2_BARD1_19/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %% [markdown]
# # BRCA2

# %%
# HMEC rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/HMEC_R1_BRCA2_8/pipe4c/WIG/HMEC_R1_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
# HMEC rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/HMEC_R2_BRCA2_9/pipe4c/WIG/HMEC_R2_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
# HMEC rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/HMEC_rep3/pipe4c/WIG/HMEC_R3_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
# HMEC rep4
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/HMEC_rep4/pipe4c/WIG/HMEC_R4_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
#HMEC rep1 & rep2 & rep3

viewpoint = 32890117
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/HMEC_R1_BRCA2_8/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)

peaks = as.data.frame(res$peak)
peaks$chr = "chr13"
colnames(peaks) = c("start", "chr")
peaks$end = peaks$start
peaks = peaks[,c("chr", "start", "end")]
write.table(peaks, '/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/HMEC_R1_BRCA2_8/peaks.bed',row.names = F, col.names =F, sep = "\t", quote = FALSE)
head(peaks)
# Out:
# Warning message in merge.data.frame(data.m, data[[i]], by = 1):
# “column names ‘frag_score.x’, ‘frag_score.y’ are duplicated in the result”
#   chr   start    end
# 1 chr13 32202242 32202242
# 2 chr13 32202247 32202247
# 3 chr13 32202265 32202265
# 4 chr13 32278163 32278163
# 5 chr13 32278168 32278168
# 6 chr13 32278202 32278202
# plot without title

# %%
# MCF10A rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MCF10A_rep3/pipe4c/WIG/MCF10A_R3_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=200)
# Out:
# Loading required package: isotone
# plot without title

# %%
# MCF10A rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MCF10_R1_BRCA2_10/pipe4c/WIG/MCF10A_R1_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
# MCF10A rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MCF10_R2_BRCA2_11/pipe4c/WIG/MCF10A_R2_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
#MCF10A rep1 & rep2
viewpoint = 32890117
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MCF10_R1_BRCA2_10/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
# MCF7 rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MCF7_R1_BRCA2_12/pipe4c/WIG/MCF7_R1_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
# MCF7 rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MCF7_R2_BRCA2_13/pipe4c/WIG/MCF7_R2_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
#MCF7 rep1 & rep2
viewpoint = 32890117
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MCF7_R1_BRCA2_12/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=25)
# Out:
# plot without title

# %%
# MCF7 rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MCF7_rep3/pipe4c/WIG/MCF7_R3_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=400)
# Out:
# plot without title

# %%
# MDAMB rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MDAMB_rep1/pipe4c/WIG/MDAMB_R1_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=400)
# Out:
# plot without title

# %%
# MDAMB rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MDAM_R2_BRCA2_14/pipe4c/WIG/MDAMB_R2_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=100)
# Out:
# plot without title

# %%
# MDAMB rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MDAM_R3_BRCA2_15/pipe4c/WIG/MDAMB_R3_BRCA2_WIN21.mod.wig", vp.pos =32890117, window=700e3)
res = single.analysis(data$data, vp.pos=32890117)
plot_C(res,y.max=100)
# Out:
# plot without title

# %%
#MDAMB rep2 & rep3
viewpoint = 32890117
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_BRCA2/MDAM_R2_BRCA2_14/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=25)
# Out:
# plot without title

# %% [markdown]
# # MYC

# %%
# HMEC rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/HMEC_R1_MYC_3/pipe4c/WIG/HMEC_R1_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# HMEC rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/HMEC_R3_MYC_4/pipe4c/WIG/HMEC_R2_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# HMEC rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/HMEC_rep2/pipe4c/WIG/HMEC_R3_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# HMEC rep4
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/HMEC_rep4/pipe4c/WIG/HMEC_R4_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
#HMEC [rep1, rep2, rep3, rep4]
viewpoint = 128748106
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/HMEC_R1_MYC_3/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)

peaks = as.data.frame(res$peak)
peaks$chr = "chr8"
colnames(peaks) = c("start", "chr")
peaks$end = peaks$start
peaks = peaks[,c("chr", "start", "end")]
write.table(peaks, '/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/HMEC_R1_MYC_3/peaks.bed',row.names = F, col.names =F, sep = "\t", quote = FALSE)
head(peaks)
# Out:
# Warning message in merge.data.frame(data.m, data[[i]], by = 1):
# “column names ‘frag_score.x’, ‘frag_score.y’ are duplicated in the result”
#   chr  start     end
# 1 chr8 128048112 128048112
# 2 chr8 128048117 128048117
# 3 chr8 128048176 128048176
# 4 chr8 128048181 128048181
# 5 chr8 128048188 128048188
# 6 chr8 128048189 128048189
# plot without title

# %%
# MCF10A rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MCF10A_R2_MYC_5/pipe4c/WIG/MCF10A_R2_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# MCF10A rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MCF10A_rep3/pipe4c/WIG/HMEC_R3_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=25)
# Out:
# plot without title

# %%
# MCF10A rep4
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MCF10A_rep4/pipe4c/WIG/HMEC_R4_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=400)
# Out:
# plot without title

# %%
#MCF10A [rep2, rep3, rep4]
viewpoint = 128748106
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MCF10A_R2_MYC_5/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
# MCF7 rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MCF7_R2_MYC_6/pipe4c/WIG/MCF7_R1_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# MCF7 rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MCF7_rep3/pipe4c/WIG/MCF7_R3_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
# MCF7 rep4
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MCF7_rep4/pipe4c/WIG/MCF7_R4_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=150)
# Out:
# plot without title

# %%
#MCF7 [rep3, rep4]
viewpoint = 128748106
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MCF7_rep3/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
# MDAMB rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MDAMB_rep3/pipe4c/WIG/MDAMB_R3_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=300)
# Out:
# plot without title

# %%
# MDAMB rep4
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MDAMB_rep4/pipe4c/WIG/MDAMB_R4_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=300)
# Out:
# plot without title

# %%
# MDAMB rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MDAM_R2_MYC_7/pipe4c/WIG/MDAMB_R2_MYC_WIN21.mod.wig", vp.pos =128748106, window=700e3)
res = single.analysis(data$data, vp.pos=128748106)
plot_C(res,y.max=300)
# Out:
# plot without title

# %%
#MDAMB [rep3, rep4]
viewpoint = 128748106
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_MYC/MDAMB_rep3/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %% [markdown]
# # PIK3CA

# %%
#HMEC rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/HMEC_rep1/pipe4c/WIG/HMEC_R1_PIK3CA_WIN21.mod.wig", vp.pos =178864881, window=700e3)
res = single.analysis(data$data, vp.pos=178864881)
plot_C(res,y.max=300)
# Out:
# plot without title

# %%
#HMEC rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/HMEC_rep2/pipe4c/WIG/HMEC_R2_PIK3CA_WIN21.mod.wig", vp.pos =178864881, window=700e3)
res = single.analysis(data$data, vp.pos=178864881)
plot_C(res,y.max=100)
# Out:
# plot without title

# %%
#HMEC rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/HMEC_rep3/pipe4c/WIG/HMEC_R3_PIK3CA_WIN21.mod.wig", vp.pos =178864881, window=700e3)
res = single.analysis(data$data, vp.pos=178864881)
plot_C(res,y.max=100)
# Out:
# plot without title

# %%
#HMEC [rep1, rep2,rep3]
viewpoint = 178864881
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/HMEC_rep1/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
#MCF7 rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/MCF7_rep2/pipe4c/WIG/MCF7_R2_PIK3CA_WIN21.mod.wig", vp.pos =178864881, window=700e3)
res = single.analysis(data$data, vp.pos=178864881)
plot_C(res,y.max=100)
# Out:
# plot without title

# %%
#MCF7 rep4
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/MCF7_rep4/pipe4c/WIG/HMEC_R4_PIK3CA_WIN21.mod.wig", vp.pos =178864881, window=700e3)
res = single.analysis(data$data, vp.pos=178864881)
plot_C(res,y.max=100)
# Out:
# plot without title

# %%
#MCF7 [rep2, rep4]
viewpoint = 178864881
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/MCF7_rep2/peakcalling", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title

# %%
#MDAMB rep1
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/MDAMB_rep1/pipe4c/WIG/MDAMB_R1_PIK3CA_WIN21.mod.wig", vp.pos =178864881, window=700e3)
res = single.analysis(data$data, vp.pos=178864881)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
#MDAMB rep3
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/MDAMB_rep3/pipe4c/WIG/MDAMB_R3_PIK3CA_WIN21.mod.wig", vp.pos =178864881, window=700e3)
res = single.analysis(data$data, vp.pos=178864881)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
#MDAMB rep2
data = readqWig("/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/MDAM_R2_PIK3CA_25/pipe4c/WIG/MDAMB_rep2_PIK3CA_WIN21.mod.wig", vp.pos =178864881, window=700e3)
res = single.analysis(data$data, vp.pos=178864881)
plot_C(res,y.max=200)
# Out:
# plot without title

# %%
#MDAMB [rep1, rep2, rep3]
viewpoint = 178864881
files = dir(path="/home/darragh/New/4C/_2/FASTQ_ALL/processed/4C_PIK3CA/MDAM_R2_PIK3CA_25/peakcalling/", pattern="*.mod.wig", full=T)
data=readMultipleWig(files,vp.pos=viewpoint)
res = combined.analysis(data, vp.pos = viewpoint, minDist = 5000, alphaFDR = 0.25)
plot_C(res,y.max=50)
# Out:
# plot without title
